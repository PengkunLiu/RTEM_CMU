# %% [markdown]
# # Time Series Analysis Examples
# In this notebook we will be transforming and exploring time-series data from Onboard API. Make sure to run the following chunk of code first in order to install it.
#
# How to query time-series from data points, process and visually explore them. This notebook is outlined in several YouTube videos that discuss:
# - how [to load and filter time-series data](https://youtu.be/KDThdyes8kc) from sensors
# - [resample and transform time-series data](https://youtu.be/VlQNGwiSSKM)
# - and [create heat maps and boxplots of data](https://youtu.be/QMr0y9LOlr8) for exploration

# %%
import pandas as pd
from onboard.client import RtemClient

# %% [markdown]
# # Create the client

# %% [markdown]
# For this notebook, you need to use the API Key with acces to the general scope and building:read scope. Let's create the client:

# %%
api_key = 'ob-p-_KnPccpVFOwKvS5u_SpKixHjKKq6H1JvrzwjxISOfPiNKKZ56_EeE5ORVJOGGtx0d_k'

# %%
client = RtemClient(api_key=api_key)

# %% [markdown]
# # Load & filter data

# %% [markdown]
# We will be using the metadata file we obtained from Onboard API in the previous notebook. Of course you can query these points again, but let's learn how to load and filter the data using *pandas*:

# %%
metadata = pd.read_csv("./rtem_all_points_metadata.csv")

# %% [markdown]
# Let's check the data types:

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44390 entries, 0 to 44389
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_point          44390 non-null  int64
#  1   building_id       44390 non-null  int64
#  2   last_updated      44342 non-null  float64
#  3   first_updated     44342 non-null  float64
#  4   device            0 non-null      float64
#  5   objectId          0 non-null      float64
#  6   name_point        14658 non-null  object
#  7   description       31843 non-null  object
#  8   units             31687 non-null  object
#  9   tagged_units      14654 non-null  object
#  10  raw_unit_id       44390 non-null  int64
#  11  value             44274 non-null  object
#  12  type              44390 non-null  object
#  13  point_type_id     44390 non-null  int64
#  14  measurement_id    44390 non-null  int64
#  15  datasource_hash   44390 non-null  object
#  16  topic             44390 non-null  object
#  17  equip_id          44390 non-null  int64
#  18  id_bdg            44390 non-null  int64
#  19  name_bdg          44390 non-null  int64
#  20  equip_type_abbr   44390 non-null  object
#  21  equip_type_name   44390 non-null  object
#  22  area_served_desc  0 non-null      float64
#  23  tags              44390 non-null  object
# dtypes: float64(5), int64(8), object(11)
# memory usage: 8.1+ MB

# %%
metadata.head()
# Out:
#    id_point  building_id  last_updated  first_updated  device  objectId  \
# 0    310029          441  1.560571e+12   1.550542e+12     NaN       NaN
# 1    310009          441  1.560485e+12   1.550701e+12     NaN       NaN
# 2    310010          441  1.560571e+12   1.550504e+12     NaN       NaN
# 3    310011          441  1.560485e+12   1.550504e+12     NaN       NaN
# 4    310012          441  1.560485e+12   1.550504e+12     NaN       NaN
#
#                               name_point description units tagged_units  ...  \
# 0    245 E 149th St. Boiler-1 Fault Code         NaN     ?            ?  ...
# 1  225 E 149th St. Boiler-1 Exhaust Temp         NaN     F            f  ...
# 2    225 E 149th St. Boiler-1 Fault Code         NaN     ?            ?  ...
# 3     225 E 149th St. Boiler-1 FFWD Temp         NaN     ?            ?  ...
# 4  225 E 149th St. Boiler-1 Fire Rate In         NaN     ?            ?  ...
#
#    measurement_id                   datasource_hash  \
# 0              18  b115b5053493748f7076ad09f69c4456
# 1               1  4a1a11502acee3078352da312c40c262
# 2              18  55882633fe8fb5aac7dac643c99b1af5
# 3              18  831a8df09b848f53e807fa0204c45eaa
# 4              18  aa147c829c7ed55b6e93cdbbb8b43d55
#
#                                                topic  equip_id  id_bdg  \
# 0  nyserda+0000088737+boiler-1+245 E 149th St. Bo...     28797     441
# 1  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 2  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 3  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 4  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
#
#   name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 0    88737             BLR           Boiler               NaN
# 1    88737             BLR           Boiler               NaN
# 2    88737             BLR           Boiler               NaN
# 3    88737             BLR           Boiler               NaN
# 4    88737             BLR           Boiler               NaN
#
#                  tags
# 0  ['boiler', 'hvac']
# 1  ['boiler', 'hvac']
# 2  ['boiler', 'hvac']
# 3  ['boiler', 'hvac']
# 4  ['boiler', 'hvac']
#
# [5 rows x 24 columns]

# %% [markdown]
# We have a lot of points here:

# %%
len(metadata.id_point)
# Out:
# 44390

# %% [markdown]
# Let's filter out only the Zone Temperature sensors -that's the `type_id` 77, you can confirm this querying the ontology data, like we did in the previous notebook ;)- and that are Fan Coil Units:

# %%
Site_sensor_data = metadata[(metadata.equip_type_name == "Site Sensors")]

# %%
Site_sensor_data['equip_id'].unique()
# Out:
# array([28813, 18917, 19446, 19644, 19648, 28505, 20343, 20509, 21097,
#        34990, 25961, 22331, 31248, 26970, 26597, 26598, 26599, 26600,
#        26601, 26602, 26603, 26604, 26605, 26606, 26607, 26608, 26609,
#        26610, 26611, 26612, 26613, 26614, 26615, 26616, 26617, 26618,
#        26619, 26620, 26621, 26622, 26623, 26624, 26625, 26626, 26627,
#        26628, 26629, 26630, 26631, 26632, 26633, 26634, 26635, 26636,
#        26637, 26638, 26639, 26640, 26641, 26642, 26643, 26644, 26645,
#        26646, 26647, 26648, 26649, 26650, 26651, 26652, 26653, 26654,
#        26655, 26656, 26657, 26658, 26659, 26660, 26661, 26662, 26663,
#        26664, 26665, 26666, 26667, 26668, 26669, 26670, 26671, 26672,
#        26673, 26674, 26675, 26676, 26677, 26678, 26679, 26680, 26681,
#        26682, 26683, 26684, 26685, 26686, 26687, 26688, 26689, 26690,
#        26691, 26692, 26693, 26694, 26695, 26696, 26697, 26698, 26699,
#        26700, 26701, 26702, 26703, 26716, 26717, 26718, 26719, 26720,
#        26721, 26722, 26734, 26735, 31244, 30422, 17264, 17281, 17292,
#        17302, 17313, 33142, 29835, 33983, 30458, 31504, 29567, 31798,
#        29579, 31844, 32167, 30298, 31518, 17862, 31247, 30381, 30466,
#        31665, 31666, 31689, 31696, 31697, 31698, 31699, 16903, 31541,
#        31242, 17916, 33326, 18060, 33263, 17158, 26335, 36552, 30469,
#        26342, 33956, 33938, 17323, 30394, 31936, 33272, 33304, 17366,
#        17329, 30304, 19773, 33347, 31969, 17372, 17558, 32382, 17669,
#        17718, 17719, 17720, 17721, 17722, 17723, 17724, 17725, 17726,
#        17727, 17728, 17729, 17730, 17731, 17732, 17733, 17734, 17735,
#        17736, 17737, 17738, 17739, 17740, 17741, 17742, 17743, 17744,
#        17745, 17746, 17747, 17748, 17749, 17750, 17751, 17752, 17753,
#        17754, 17755, 17756, 17757, 17758, 17759, 17760, 17761, 17762,
#        17763, 17784, 17785, 17799, 31994, 17360, 27035, 18232, 18241,
#        17385, 17414, 17854, 32123, 30525, 17919, 17850, 32047, 18085,
#        17871, 18163, 18210, 18219, 18553, 18169, 18307, 18332, 18333,
#        18334, 18335, 18336, 18337, 18338, 18339, 18340, 18341, 18342,
#        18343, 18344, 18345, 18346, 18347, 18348, 18349, 18486, 18501,
#        18556, 18562, 18515, 18287, 18588, 18529, 18489, 18606, 33978,
#        18924, 18928, 18598, 18622, 18676, 18786, 18794, 18852, 18853,
#        18854, 18855, 18856, 18857, 18858, 34986, 19062, 19110, 19218,
#        19220, 19250, 19283, 19285, 19293, 19548, 19467, 33922, 19685,
#        30570, 19972, 19973, 19974, 19975, 19976, 19977, 19978, 19979,
#        36559, 20076, 20119, 20129, 20136, 20237, 20243, 20271, 20080,
#        20483, 20493, 20517, 20684, 20842, 35005, 20895, 21109, 21165,
#        21168, 21498, 21576, 21579, 21602, 21986, 22269, 22262, 22372,
#        22384, 21811, 22501, 22510, 22553, 22582, 22627, 18246, 18254,
#        18267, 18508, 18678, 36558, 20057, 20908, 21595, 22257, 22392,
#        22732], dtype=int64)

# %%
"Outside Air Temperature" in metadata.type
# Out:
# False

# %%
OAT_mat_data = metadata[(metadata.type == "Outside Air Temperature")]
OAT_mat_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 362      310273          441  1.603907e+12   1.588306e+12     NaN       NaN
# 981      310902          441  1.609476e+12   1.570381e+12     NaN       NaN
# 982      310903          441  1.609476e+12   1.570403e+12     NaN       NaN
# 1313     198145          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1325     198135          140  1.551416e+12   1.509509e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 44192    230936          398  1.577768e+12   1.571951e+12     NaN       NaN
# 44196    230960          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44241    230976          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44272    231006          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44289    231037          398  1.577768e+12   1.554932e+12     NaN       NaN
#
#                                               name_point  \
# 362    225 E 149th St. Controller [Tekmar 284] Outdoo...
# 981    245 E 149th St. Controller [Tekmar 284] BAS Ou...
# 982    245 E 149th St. Controller [Tekmar 284] Outdoo...
# 1313                                                 NaN
# 1325                                                 NaN
# ...                                                  ...
# 44192                                                NaN
# 44196                                                NaN
# 44241                                                NaN
# 44272                                                NaN
# 44289                                                NaN
#
#                                          description units tagged_units  ...  \
# 362                                              NaN     F            f  ...
# 981                                              NaN     F            f  ...
# 982                                              NaN     F            f  ...
# 1313            UPCM-1 AH-1 Gallery_Outdoor Air Temp     F          NaN  ...
# 1325   UPCM-1 AH-1 Gallery_OA Temp (Reference value)     F          NaN  ...
# ...                                              ...   ...          ...  ...
# 44192            Outdoor Conditions (CRAC 5-1)_OaTmp     F          NaN  ...
# 44196                                  AC-12-4_OaTmp     F          NaN  ...
# 44241                                  AC-25-1_OaTmp     F          NaN  ...
# 44272                                   AC-4-1_OaTmp     F          NaN  ...
# 44289                                   AC-9-1_OaTmp     F          NaN  ...
#
#        measurement_id                   datasource_hash  \
# 362                 1  a4657d74835d29be77eae1b80865ef3c
# 981                 1  04bc1a21b80440e5d67e05569c010a1c
# 982                 1  2278e1c5c7803bbafe675cd9219e67eb
# 1313                1  d4f8e8a9f1eebcf2ea5c08a68096aee0
# 1325                1  10bd646990542556aa86d3a9236a128e
# ...               ...                               ...
# 44192               1  54fa4adcf5c857b6e4279594fb24263b
# 44196               1  42c03637a3e2efa6703f514f66954564
# 44241               1  18896da3dc788a9de84f2c5e9bcfb49a
# 44272               1  bb8550c34feb8bfd3baa72726bc77e2d
# 44289               1  4bbf038bd272bb068799072af9e7a03e
#
#                                                    topic  equip_id  id_bdg  \
# 362    nyserda+0000088737+site-Sensor+225 E 149th St....     28813     441
# 981    nyserda+0000088737+site-Sensor+245 E 149th St....     28813     441
# 982    nyserda+0000088737+site-Sensor+245 E 149th St....     28813     441
# 1313   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# 1325   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# ...                                                  ...       ...     ...
# 44192  nyserda+0000109188+Site-Sensor+Outdoor Conditi...     22732     398
# 44196            nyserda+0000109188+ac12-4+AC-12-4_OaTmp     22733     398
# 44241            nyserda+0000109188+ac25-1+AC-25-1_OaTmp     22734     398
# 44272              nyserda+0000109188+ac4-1+AC-4-1_OaTmp     22735     398
# 44289              nyserda+0000109188+ac9-1+AC-9-1_OaTmp     22736     398
#
#       name_bdg equip_type_abbr    equip_type_name  area_served_desc  \
# 362      88737            SITE       Site Sensors               NaN
# 981      88737            SITE       Site Sensors               NaN
# 982      88737            SITE       Site Sensors               NaN
# 1313     83483             AHU  Air Handling Unit               NaN
# 1325     83483             AHU  Air Handling Unit               NaN
# ...        ...             ...                ...               ...
# 44192   109188            SITE       Site Sensors               NaN
# 44196   109188             AHU  Air Handling Unit               NaN
# 44241   109188             AHU  Air Handling Unit               NaN
# 44272   109188             AHU  Air Handling Unit               NaN
# 44289   109188             AHU  Air Handling Unit               NaN
#
#                   tags
# 362           ['site']
# 981           ['site']
# 982           ['site']
# 1313   ['ahu', 'hvac']
# 1325   ['ahu', 'hvac']
# ...                ...
# 44192         ['site']
# 44196  ['ahu', 'hvac']
# 44241  ['ahu', 'hvac']
# 44272  ['ahu', 'hvac']
# 44289  ['ahu', 'hvac']
#
# [797 rows x 24 columns]

# %%
RAT_mat_data = metadata[(metadata.type == "Return Air Temperature")]
RAT_mat_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1309     198149          140  1.551416e+12   1.536258e+12     NaN       NaN
# 1361     198188          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1382     198237          140  1.551416e+12   1.536258e+12     NaN       NaN
# 1446     198277          140  1.551416e+12   1.536592e+12     NaN       NaN
# 1717     208322          248  1.585055e+12   1.581703e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 44220    230982          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44253    231012          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44284    231043          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44314    231060          398  1.577768e+12   1.572568e+12     NaN       NaN
# 44321    231070          398  1.577768e+12   1.572568e+12     NaN       NaN
#
#       name_point                               description units tagged_units  \
# 1309         NaN       UPCM-1 AH-1 Gallery_Return Air Temp     F          NaN
# 1361         NaN                AH-1 Lobby_Return Air Temp     F          NaN
# 1382         NaN     UPCM-2 AH-2 2nd Floor_Return Air Temp     F          NaN
# 1446         NaN             AHU-2-6TH-FLR_Return Air Temp     F          NaN
# 1717         NaN  Mid Zone 1 Tank Return Temp Sensor_Value     F          NaN
# ...          ...                                       ...   ...          ...
# 44220        NaN                             AC-25-1_RaTmp     F          NaN
# 44253        NaN                              AC-4-1_RaTmp     F          NaN
# 44284        NaN                              AC-9-1_RaTmp     F          NaN
# 44314        NaN                           AHU_26_02_RATmp     F          NaN
# 44321        NaN                           AHU_27_02_RATmp     F          NaN
#
#        ...  measurement_id                   datasource_hash  \
# 1309   ...               1  29a9514ea653ed9afbc43704e1230efd
# 1361   ...               1  4d7c35460b418684bd7545239e72876c
# 1382   ...               1  6b9e0ebbd36ba727bdeb4437b012b877
# 1446   ...               1  7ab8209ec890801c848af3ee4b601155
# 1717   ...               1  c82e7194c4eb3a129c08d26450b8ab3c
# ...    ...             ...                               ...
# 44220  ...               1  95c8e3cbbd6081be1f8cb78a8e60f330
# 44253  ...               1  7354b6fd64a4fac76eeb68382dee5a42
# 44284  ...               1  e78398b47be19242f5e1a90d1ba3f96a
# 44314  ...               1  bfffc10825012d93407e03a93fab5a77
# 44321  ...               1  00803ac45269e9c456ebaf9e121796a2
#
#                                                    topic  equip_id  id_bdg  \
# 1309   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# 1361   nyserda+0000083483+ahu1-lobby+AH-1 Lobby_Retur...     18093     140
# 1382   nyserda+0000083483+ahu2-floor2+UPCM-2 AH-2 2nd...     18094     140
# 1446   nyserda+0000083483+ahu2-floor6+AHU-2-6TH-FLR_R...     18095     140
# 1717   nyserda+0000116742+Site-Sensor+Mid Zone 1 Tank...     19644     248
# ...                                                  ...       ...     ...
# 44220            nyserda+0000109188+ac25-1+AC-25-1_RaTmp     22734     398
# 44253              nyserda+0000109188+ac4-1+AC-4-1_RaTmp     22735     398
# 44284              nyserda+0000109188+ac9-1+AC-9-1_RaTmp     22736     398
# 44314        nyserda+0000109188+ahu26-02+AHU_26_02_RATmp     22737     398
# 44321        nyserda+0000109188+ahu27-02+AHU_27_02_RATmp     22738     398
#
#       name_bdg equip_type_abbr    equip_type_name  area_served_desc  \
# 1309     83483             AHU  Air Handling Unit               NaN
# 1361     83483             AHU  Air Handling Unit               NaN
# 1382     83483             AHU  Air Handling Unit               NaN
# 1446     83483             AHU  Air Handling Unit               NaN
# 1717    116742            SITE       Site Sensors               NaN
# ...        ...             ...                ...               ...
# 44220   109188             AHU  Air Handling Unit               NaN
# 44253   109188             AHU  Air Handling Unit               NaN
# 44284   109188             AHU  Air Handling Unit               NaN
# 44314   109188             AHU  Air Handling Unit               NaN
# 44321   109188             AHU  Air Handling Unit               NaN
#
#                   tags
# 1309   ['ahu', 'hvac']
# 1361   ['ahu', 'hvac']
# 1382   ['ahu', 'hvac']
# 1446   ['ahu', 'hvac']
# 1717          ['site']
# ...                ...
# 44220  ['ahu', 'hvac']
# 44253  ['ahu', 'hvac']
# 44284  ['ahu', 'hvac']
# 44314  ['ahu', 'hvac']
# 44321  ['ahu', 'hvac']
#
# [474 rows x 24 columns]

# %%
shared_OAT_mat_data = OAT_mat_data[OAT_mat_data["building_id"].isin(RAT_mat_data["building_id"])]
shared_RAT_mat_data  = RAT_mat_data[RAT_mat_data["building_id"].isin(OAT_mat_data["building_id"])]

# %%
shared_OAT_mat_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1313     198145          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1325     198135          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1367     198182          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1385     198233          140  1.551416e+12   1.518620e+12     NaN       NaN
# 1394     198224          140  1.551416e+12   1.509509e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 44192    230936          398  1.577768e+12   1.571951e+12     NaN       NaN
# 44196    230960          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44241    230976          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44272    231006          398  1.577768e+12   1.554932e+12     NaN       NaN
# 44289    231037          398  1.577768e+12   1.554932e+12     NaN       NaN
#
#       name_point                                      description units  \
# 1313         NaN             UPCM-1 AH-1 Gallery_Outdoor Air Temp     F
# 1325         NaN    UPCM-1 AH-1 Gallery_OA Temp (Reference value)     F
# 1367         NaN             AH-1 Lobby_OA Temp (Reference value)     F
# 1385         NaN           UPCM-2 AH-2 2nd Floor_Outdoor Air Temp     F
# 1394         NaN  UPCM-2 AH-2 2nd Floor_OA Temp (Reference value)     F
# ...          ...                                              ...   ...
# 44192        NaN              Outdoor Conditions (CRAC 5-1)_OaTmp     F
# 44196        NaN                                    AC-12-4_OaTmp     F
# 44241        NaN                                    AC-25-1_OaTmp     F
# 44272        NaN                                     AC-4-1_OaTmp     F
# 44289        NaN                                     AC-9-1_OaTmp     F
#
#       tagged_units  ...  measurement_id                   datasource_hash  \
# 1313           NaN  ...               1  d4f8e8a9f1eebcf2ea5c08a68096aee0
# 1325           NaN  ...               1  10bd646990542556aa86d3a9236a128e
# 1367           NaN  ...               1  21615a28c7a99344f59571bd65b9eaca
# 1385           NaN  ...               1  82fd8b24d7f37657c33d17d2eb362b9c
# 1394           NaN  ...               1  c26204f12acb843e13f3f98b98edb4ea
# ...            ...  ...             ...                               ...
# 44192          NaN  ...               1  54fa4adcf5c857b6e4279594fb24263b
# 44196          NaN  ...               1  42c03637a3e2efa6703f514f66954564
# 44241          NaN  ...               1  18896da3dc788a9de84f2c5e9bcfb49a
# 44272          NaN  ...               1  bb8550c34feb8bfd3baa72726bc77e2d
# 44289          NaN  ...               1  4bbf038bd272bb068799072af9e7a03e
#
#                                                    topic  equip_id  id_bdg  \
# 1313   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# 1325   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# 1367   nyserda+0000083483+ahu1-lobby+AH-1 Lobby_OA Te...     18093     140
# 1385   nyserda+0000083483+ahu2-floor2+UPCM-2 AH-2 2nd...     18094     140
# 1394   nyserda+0000083483+ahu2-floor2+UPCM-2 AH-2 2nd...     18094     140
# ...                                                  ...       ...     ...
# 44192  nyserda+0000109188+Site-Sensor+Outdoor Conditi...     22732     398
# 44196            nyserda+0000109188+ac12-4+AC-12-4_OaTmp     22733     398
# 44241            nyserda+0000109188+ac25-1+AC-25-1_OaTmp     22734     398
# 44272              nyserda+0000109188+ac4-1+AC-4-1_OaTmp     22735     398
# 44289              nyserda+0000109188+ac9-1+AC-9-1_OaTmp     22736     398
#
#       name_bdg equip_type_abbr    equip_type_name  area_served_desc  \
# 1313     83483             AHU  Air Handling Unit               NaN
# 1325     83483             AHU  Air Handling Unit               NaN
# 1367     83483             AHU  Air Handling Unit               NaN
# 1385     83483             AHU  Air Handling Unit               NaN
# 1394     83483             AHU  Air Handling Unit               NaN
# ...        ...             ...                ...               ...
# 44192   109188            SITE       Site Sensors               NaN
# 44196   109188             AHU  Air Handling Unit               NaN
# 44241   109188             AHU  Air Handling Unit               NaN
# 44272   109188             AHU  Air Handling Unit               NaN
# 44289   109188             AHU  Air Handling Unit               NaN
#
#                   tags
# 1313   ['ahu', 'hvac']
# 1325   ['ahu', 'hvac']
# 1367   ['ahu', 'hvac']
# 1385   ['ahu', 'hvac']
# 1394   ['ahu', 'hvac']
# ...                ...
# 44192         ['site']
# 44196  ['ahu', 'hvac']
# 44241  ['ahu', 'hvac']
# 44272  ['ahu', 'hvac']
# 44289  ['ahu', 'hvac']
#
# [392 rows x 24 columns]

# %%
shared_RAT_mat_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1309     198149          140  1.551416e+12   1.536258e+12     NaN       NaN
# 1361     198188          140  1.551416e+12   1.509509e+12     NaN       NaN
# 1382     198237          140  1.551416e+12   1.536258e+12     NaN       NaN
# 1446     198277          140  1.551416e+12   1.536592e+12     NaN       NaN
# 1939     210910          271  1.551416e+12   1.527826e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 44220    230982          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44253    231012          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44284    231043          398  1.577768e+12   1.554845e+12     NaN       NaN
# 44314    231060          398  1.577768e+12   1.572568e+12     NaN       NaN
# 44321    231070          398  1.577768e+12   1.572568e+12     NaN       NaN
#
#       name_point                            description units tagged_units  \
# 1309         NaN    UPCM-1 AH-1 Gallery_Return Air Temp     F          NaN
# 1361         NaN             AH-1 Lobby_Return Air Temp     F          NaN
# 1382         NaN  UPCM-2 AH-2 2nd Floor_Return Air Temp     F          NaN
# 1446         NaN          AHU-2-6TH-FLR_Return Air Temp     F          NaN
# 1939         NaN             3RD FL CSC_Return Air Temp     F          NaN
# ...          ...                                    ...   ...          ...
# 44220        NaN                          AC-25-1_RaTmp     F          NaN
# 44253        NaN                           AC-4-1_RaTmp     F          NaN
# 44284        NaN                           AC-9-1_RaTmp     F          NaN
# 44314        NaN                        AHU_26_02_RATmp     F          NaN
# 44321        NaN                        AHU_27_02_RATmp     F          NaN
#
#        ...  measurement_id                   datasource_hash  \
# 1309   ...               1  29a9514ea653ed9afbc43704e1230efd
# 1361   ...               1  4d7c35460b418684bd7545239e72876c
# 1382   ...               1  6b9e0ebbd36ba727bdeb4437b012b877
# 1446   ...               1  7ab8209ec890801c848af3ee4b601155
# 1939   ...               1  efd7b65c5c1670952dea0f90a6d509d4
# ...    ...             ...                               ...
# 44220  ...               1  95c8e3cbbd6081be1f8cb78a8e60f330
# 44253  ...               1  7354b6fd64a4fac76eeb68382dee5a42
# 44284  ...               1  e78398b47be19242f5e1a90d1ba3f96a
# 44314  ...               1  bfffc10825012d93407e03a93fab5a77
# 44321  ...               1  00803ac45269e9c456ebaf9e121796a2
#
#                                                    topic  equip_id  id_bdg  \
# 1309   nyserda+0000083483+ahu1-gallery+UPCM-1 AH-1 Ga...     18092     140
# 1361   nyserda+0000083483+ahu1-lobby+AH-1 Lobby_Retur...     18093     140
# 1382   nyserda+0000083483+ahu2-floor2+UPCM-2 AH-2 2nd...     18094     140
# 1446   nyserda+0000083483+ahu2-floor6+AHU-2-6TH-FLR_R...     18095     140
# 1939   nyserda+0000080324+csc3+3RD FL CSC_Return Air ...     20109     271
# ...                                                  ...       ...     ...
# 44220            nyserda+0000109188+ac25-1+AC-25-1_RaTmp     22734     398
# 44253              nyserda+0000109188+ac4-1+AC-4-1_RaTmp     22735     398
# 44284              nyserda+0000109188+ac9-1+AC-9-1_RaTmp     22736     398
# 44314        nyserda+0000109188+ahu26-02+AHU_26_02_RATmp     22737     398
# 44321        nyserda+0000109188+ahu27-02+AHU_27_02_RATmp     22738     398
#
#       name_bdg equip_type_abbr    equip_type_name  area_served_desc  \
# 1309     83483             AHU  Air Handling Unit               NaN
# 1361     83483             AHU  Air Handling Unit               NaN
# 1382     83483             AHU  Air Handling Unit               NaN
# 1446     83483             AHU  Air Handling Unit               NaN
# 1939     80324             AHU  Air Handling Unit               NaN
# ...        ...             ...                ...               ...
# 44220   109188             AHU  Air Handling Unit               NaN
# 44253   109188             AHU  Air Handling Unit               NaN
# 44284   109188             AHU  Air Handling Unit               NaN
# 44314   109188             AHU  Air Handling Unit               NaN
# 44321   109188             AHU  Air Handling Unit               NaN
#
#                   tags
# 1309   ['ahu', 'hvac']
# 1361   ['ahu', 'hvac']
# 1382   ['ahu', 'hvac']
# 1446   ['ahu', 'hvac']
# 1939   ['ahu', 'hvac']
# ...                ...
# 44220  ['ahu', 'hvac']
# 44253  ['ahu', 'hvac']
# 44284  ['ahu', 'hvac']
# 44314  ['ahu', 'hvac']
# 44321  ['ahu', 'hvac']
#
# [304 rows x 24 columns]

# %%
RASP_mat_data = metadata[(metadata.type == "Relief Air Static Pressure")]
RASP_mat_data
# Out:
# Empty DataFrame
# Columns: [id_point, building_id, last_updated, first_updated, device, objectId, name_point, description, units, tagged_units, raw_unit_id, value, type, point_type_id, measurement_id, datasource_hash, topic, equip_id, id_bdg, name_bdg, equip_type_abbr, equip_type_name, area_served_desc, tags]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# # Querying time-series: Boiler Heating Hot Water Supply Temp

# %% [markdown]
# Now that we have our metadata filtered it's time to get the time-series of those points. Let's import the libraries we will be using:

# %%
from datetime import datetime, timezone, timedelta
import pytz
from onboard.client.models import TimeseriesQuery, PointData
from onboard.client.dataframes import points_df_from_streaming_timeseries

# %% [markdown]
# First, create a list with the points to query. We already filtered our dataset, so it's all the points there:

# %%
OAT_points = list(shared_OAT_mat_data.id_point)
RAT_points = list(shared_RAT_mat_data.id_point)

# %% [markdown]
# Let's inspect the datetime period we are working with; we have to convert the `first_updated` and `last_updated` from unix timestamp to a datetime (like we learned in a previous notebook).

# %%
shared_OAT_mat_data.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2017-03-22 04:00:00+0000', tz='UTC')

# %%
shared_OAT_mat_data.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2022-01-06 23:45:00+0000', tz='UTC')

# %% [markdown]
# Ok, 2017-2018. Let's select a year of data; we are using the [python library datetime](https://docs.python.org/3/library/datetime.html) to create datetime objects. Remember that all the data from the API is in UTC, you have to localize all your datetimes using [PyTZ](https://pythonhosted.org/pytz/) a library designed for that purpose.

# %%
# Select your timezone
tz = pytz.timezone('UTC')

# Select your date and time (time is optional)
start = datetime(2017,3,22,0,0,0).replace(tzinfo=tz)
end = datetime(2022,1,6,0,0,0).replace(tzinfo=tz)

print(f"from {start} to {end}")
# Out:
# from 2017-03-22 00:00:00+00:00 to 2022-01-06 00:00:00+00:00

# %% [markdown]
# And create the query with all the parameters. Here we are saying "give me the readings fron 20 january 2017 to 20 january 2018 of the points in `points`":

# %%
timeseries_query_OAT = TimeseriesQuery(point_ids = OAT_points, start = start, end = end)
timeseries_query_RAT = TimeseriesQuery(point_ids = RAT_points, start = start, end = end)

# %% [markdown]
# Time to get the data!

# %%
# Exceute query (will return and object)
query_results_OAT = client.stream_point_timeseries(timeseries_query_OAT)
query_results_RAT = client.stream_point_timeseries(timeseries_query_RAT)

# Convert to dataframe
data_OAT = points_df_from_streaming_timeseries(query_results_OAT)
data_RAT = points_df_from_streaming_timeseries(query_results_RAT)

# %%
data_OAT
# Out:
#                    timestamp  231006  231037  198135 198145  198182 198233  \
# 0       2017-03-22T04:00:00Z     NaN     NaN     NaN   None     NaN   None
# 1       2017-03-22T05:00:00Z     NaN     NaN     NaN   None     NaN   None
# 2       2017-03-22T06:00:00Z     NaN     NaN     NaN   None     NaN   None
# 3       2017-03-22T07:00:00Z     NaN     NaN     NaN   None     NaN   None
# 4       2017-03-22T08:00:00Z     NaN     NaN     NaN   None     NaN   None
# ...                      ...     ...     ...     ...    ...     ...    ...
# 472749  2022-01-05T22:45:00Z     NaN     NaN     NaN   None     NaN   None
# 472750  2022-01-05T23:00:00Z     NaN     NaN     NaN   None     NaN   None
# 472751  2022-01-05T23:15:00Z     NaN     NaN     NaN   None     NaN   None
# 472752  2022-01-05T23:30:00Z     NaN     NaN     NaN   None     NaN   None
# 472753  2022-01-05T23:45:00Z     NaN     NaN     NaN   None     NaN   None
#
#         198224  198271  198308  ...  230921  230927  230918  230924  230912  \
# 0          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...  ...     ...     ...     ...     ...     ...
# 472749     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 472750     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 472751     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 472752     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 472753     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#         230915  230936  230945  230960  230976
# 0          NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...     ...     ...
# 472749     NaN     NaN     NaN     NaN     NaN
# 472750     NaN     NaN     NaN     NaN     NaN
# 472751     NaN     NaN     NaN     NaN     NaN
# 472752     NaN     NaN     NaN     NaN     NaN
# 472753     NaN     NaN     NaN     NaN     NaN
#
# [472754 rows x 393 columns]

# %%
data_RAT
# Out:
#                    timestamp  231060  231070  198149  198188  198237  198277  \
# 0       2017-06-05T14:30:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 1       2017-06-05T15:00:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 2       2017-06-05T15:15:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 3       2017-06-05T15:30:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 4       2017-06-05T15:45:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# ...                      ...     ...     ...     ...     ...     ...     ...
# 803342  2022-01-05T22:45:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 803343  2022-01-05T23:00:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 803344  2022-01-05T23:15:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 803345  2022-01-05T23:30:00Z     NaN     NaN     NaN     NaN     NaN     NaN
# 803346  2022-01-05T23:45:00Z     NaN     NaN     NaN     NaN     NaN     NaN
#
#         210910  210932  210955  ...  210670  230426  217132  217138  217142  \
# 0          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...  ...     ...     ...     ...     ...     ...
# 803342     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 803343     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 803344     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 803345     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 803346     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#         228106  228160  230982  231012  231043
# 0          NaN     NaN     NaN     NaN     NaN
# 1          NaN     NaN     NaN     NaN     NaN
# 2          NaN     NaN     NaN     NaN     NaN
# 3          NaN     NaN     NaN     NaN     NaN
# 4          NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...     ...     ...
# 803342     NaN     NaN     NaN     NaN     NaN
# 803343     NaN     NaN     NaN     NaN     NaN
# 803344     NaN     NaN     NaN     NaN     NaN
# 803345     NaN     NaN     NaN     NaN     NaN
# 803346     NaN     NaN     NaN     NaN     NaN
#
# [803347 rows x 305 columns]

# %% [markdown]
# Took some time to retreive that data, is a big dataset. Let's export the csv:

# %%
data_OAT.to_csv("Outdoor_air_temperature_time_series.csv", index=False)
data_RAT.to_csv("Return_air_temperature_time_series.csv", index=False)

# %% [markdown]
# # Resampling

# %% [markdown]
# Let's load the dataset we just exported just to learn one more trick:

# %%
data_DSP = pd.read_csv("./Outdoor_air_temperature_time_series.csv")
data_DSP_setpoint = pd.read_csv("./Return_air_temperature_time_series.csv")

# %%
data_DSP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472754 entries, 0 to 472753
# Columns: 393 entries, timestamp to 230976
# dtypes: float64(392), object(1)
# memory usage: 1.4+ GB

# %%
data_DSP_setpoint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803347 entries, 0 to 803346
# Columns: 305 entries, timestamp to 231043
# dtypes: float64(304), object(1)
# memory usage: 1.8+ GB

# %% [markdown]
# The timestamp there is not a datetime object yet. We could have parsed it as date [using the parameter `parse_dates` while reading](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) the csv or we can do the following:

# %%
data_DSP["timestamp"] = pd.to_datetime(data_DSP['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')
data_DSP_setpoint["timestamp"] = pd.to_datetime(data_DSP_setpoint['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
type(data_DSP.timestamp[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data_DSP.head(10)
# Out:
#                   timestamp  231006  231037  198135  198145  198182  198233  \
# 0 2017-03-22 04:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1 2017-03-22 05:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2 2017-03-22 06:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 3 2017-03-22 07:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 4 2017-03-22 08:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 5 2017-03-22 09:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 6 2017-03-22 10:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 7 2017-03-22 11:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 8 2017-03-22 12:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 9 2017-03-22 13:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#    198224  198271  198308  ...  230921  230927  230918  230924  230912  \
# 0     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    230915  230936  230945  230960  230976
# 0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN     NaN     NaN
#
# [10 rows x 393 columns]

# %%
data_DSP_setpoint.head(10)
# Out:
#                   timestamp  231060  231070  198149  198188  198237  198277  \
# 0 2017-06-05 14:30:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1 2017-06-05 15:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2 2017-06-05 15:15:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 3 2017-06-05 15:30:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 4 2017-06-05 15:45:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 5 2017-06-05 16:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 6 2017-06-05 16:15:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 7 2017-06-05 16:30:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 8 2017-06-05 16:45:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 9 2017-06-05 17:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#    210910  210932  210955  ...  210670  230426  217132  217138  217142  \
# 0     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    228106  228160  230982  231012  231043
# 0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN     NaN     NaN
#
# [10 rows x 305 columns]

# %%
data_DSP.resample('D', on="timestamp").mean()
# Out:
#                            231006  231037  198135  198145  198182  198233  \
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# ...                           ...     ...     ...     ...     ...     ...
# 2022-01-01 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-02 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-03 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-04 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            198224  198271  198308  198383  ...  230921  \
# timestamp                                                  ...
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# ...                           ...     ...     ...     ...  ...     ...
# 2022-01-01 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-02 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-03 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-04 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-05 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
#
#                            230927  230918  230924  230912  230915  230936  \
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# ...                           ...     ...     ...     ...     ...     ...
# 2022-01-01 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-02 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-03 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-04 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            230945  230960  230976
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN
# ...                           ...     ...     ...
# 2022-01-01 00:00:00+00:00     NaN     NaN     NaN
# 2022-01-02 00:00:00+00:00     NaN     NaN     NaN
# 2022-01-03 00:00:00+00:00     NaN     NaN     NaN
# 2022-01-04 00:00:00+00:00     NaN     NaN     NaN
# 2022-01-05 00:00:00+00:00     NaN     NaN     NaN
#
# [1751 rows x 392 columns]

# %% [markdown]
# And you can do it with the frequency you want. Let's try 1 Hour ("H" is 1 Hour):

# %%
data_DSP.resample('H', on="timestamp").mean()
# Out:
#                            231006  231037  198135  198145  198182  198233  \
# timestamp
# 2017-03-22 04:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 05:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 06:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 07:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 08:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# ...                           ...     ...     ...     ...     ...     ...
# 2022-01-05 19:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 20:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 21:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 22:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 23:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            198224  198271  198308  198383  ...  230921  \
# timestamp                                                  ...
# 2017-03-22 04:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-22 05:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-22 06:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-22 07:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-22 08:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# ...                           ...     ...     ...     ...  ...     ...
# 2022-01-05 19:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-05 20:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-05 21:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-05 22:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2022-01-05 23:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
#
#                            230927  230918  230924  230912  230915  230936  \
# timestamp
# 2017-03-22 04:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 05:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 06:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 07:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-22 08:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# ...                           ...     ...     ...     ...     ...     ...
# 2022-01-05 19:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 20:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 21:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 22:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-01-05 23:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            230945  230960  230976
# timestamp
# 2017-03-22 04:00:00+00:00     NaN     NaN     NaN
# 2017-03-22 05:00:00+00:00     NaN     NaN     NaN
# 2017-03-22 06:00:00+00:00     NaN     NaN     NaN
# 2017-03-22 07:00:00+00:00     NaN     NaN     NaN
# 2017-03-22 08:00:00+00:00     NaN     NaN     NaN
# ...                           ...     ...     ...
# 2022-01-05 19:00:00+00:00     NaN     NaN     NaN
# 2022-01-05 20:00:00+00:00     NaN     NaN     NaN
# 2022-01-05 21:00:00+00:00     NaN     NaN     NaN
# 2022-01-05 22:00:00+00:00     NaN     NaN     NaN
# 2022-01-05 23:00:00+00:00     NaN     NaN     NaN
#
# [42020 rows x 392 columns]

# %% [markdown]
# That weird "T" -that means "minutes"- is an [offset alias. You can check all of them out here](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases).

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lineplots

# %% [markdown]
# We are going to explore our sensors data with some simple lineplots. We are going to use [*Seaborn*](https://seaborn.pydata.org/) which works on [*Matplotlib*](https://matplotlib.org/stable/users/index.html). Let's import them:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# This is for the visual stype, I like "ggplot"
plt.style.use('ggplot')

# This for the figure size
plt.rcParams["figure.figsize"] = (20,9)

# %% [markdown]
# Let's plot the raw data of our sensors:

# %%
# These are the sensors, one per column (first one is the timestamp)
cols = data_DSP.columns[1:]
cols
# Out:
# Index(['231006', '231037', '198135', '198145', '198182', '198233', '198224',
#        '198271', '198308', '198383',
#        ...
#        '230921', '230927', '230918', '230924', '230912', '230915', '230936',
#        '230945', '230960', '230976'],
#       dtype='object', length=392)

# %%
for col in cols:
    plt.figure()
    sns.lineplot(data=data_DSP, x="timestamp", y=col)
# Out:
# C:\Users\lpk19\AppData\Local\Temp\ipykernel_25032\4204628427.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25032\4204628427.py in <module>
#       1 for col in cols:
#       2     plt.figure()
# ----> 3     sns.lineplot(data=data_DSP, x="timestamp", y=col)
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     672         self.plot_data = plot_data
#     673         self.variables = variables
# --> 674         self.var_types = {
#     675             v: variable_type(
#     676                 plot_data[v],
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_core.py in <dictcomp>(.0)
#     673         self.variables = variables
#     674         self.var_types = {
# --> 675             v: variable_type(
#     676                 plot_data[v],
#     677                 boolean_type="numeric" if v in "xy" else "categorical"
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_core.py in variable_type(vector, boolean_type)
#    1273         return True
#    1274
# -> 1275     if all_datetime(vector):
#    1276         return "datetime"
#    1277
#
# ~\anaconda3\envs\log\lib\site-packages\seaborn\_core.py in all_datetime(x)
#    1268
#    1269     def all_datetime(x):
# -> 1270         for x_i in x:
#    1271             if not isinstance(x_i, (datetime, np.datetime64)):
#    1272                 return False
#
# ~\anaconda3\envs\log\lib\site-packages\pandas\core\arrays\datetimes.py in __iter__(self)
#     618                     start_i = i * chunksize
#     619                     end_i = min((i + 1) * chunksize, length)
# --> 620                     converted = ints_to_pydatetime(
#     621                         data[start_i:end_i], tz=self.tz, freq=self.freq, box="timestamp"
#     622                     )
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001CA943CF160> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\log\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     494     try:
# --> 495         fh = fp.fileno()
#     496         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\envs\log\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\envs\log\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\log\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     539         """
#     540         FigureCanvasAgg.draw(self)
# --> 541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\envs\log\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~\anaconda3\envs\log\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2210
#    2211         try:
# -> 2212             save_handler(self, fp, filename)
#    2213         finally:
#    2214             # do what we can to clean up
#
# ~\anaconda3\envs\log\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1346         _write_multiple_frames(im, fp, chunk, rawmode)
#    1347     else:
# -> 1348         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1349
#    1350     if info:
#
# ~\anaconda3\envs\log\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     507             else:
#     508                 while True:
# --> 509                     l, s, d = e.encode(bufsize)
#     510                     fp.write(d)
#     511                     if s:
#
# KeyboardInterrupt:

# %%
# These are the sensors, one per column (first one is the timestamp)
cols = data_DSP_setpoint.columns[1:]
cols

# %%
for col in cols:
    plt.figure()
    sns.lineplot(data=data_DSP_setpoint, x="timestamp", y=col)

# %%
data_DSP_hour = data_DSP.resample('1H', on="timestamp").mean()
data_DSP_hour.head()

data_DSP_setpoint_hour = data_DSP_setpoint.resample('1H', on="timestamp").mean()
data_DSP_setpoint_hour.head()
# Out:
#                            231060  231070  198149  198188  198237  198277  \
# timestamp
# 2017-06-05 14:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 15:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 16:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 17:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 18:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            210910  210932  210955  211012  ...  210670  \
# timestamp                                                  ...
# 2017-06-05 14:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-05 15:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-05 16:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-05 17:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-05 18:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
#
#                            230426  217132  217138  217142  228106  228160  \
# timestamp
# 2017-06-05 14:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 15:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 16:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 17:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-05 18:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            230982  231012  231043
# timestamp
# 2017-06-05 14:00:00+00:00     NaN     NaN     NaN
# 2017-06-05 15:00:00+00:00     NaN     NaN     NaN
# 2017-06-05 16:00:00+00:00     NaN     NaN     NaN
# 2017-06-05 17:00:00+00:00     NaN     NaN     NaN
# 2017-06-05 18:00:00+00:00     NaN     NaN     NaN
#
# [5 rows x 304 columns]

# %%
fig = sns.lineplot(data=data_DSP_hour)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %%
fig = sns.lineplot(data=data_DSP_setpoint_hour)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %%
data_DSP_day = data_DSP.resample('24H', on="timestamp").mean()
data_DSP_day.head()
# Out:
#                            231006  231037  198135  198145  198182  198233  \
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            198224  198271  198308  198383  ...  230921  \
# timestamp                                                  ...
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
#
#                            230927  230918  230924  230912  230915  230936  \
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            230945  230960  230976
# timestamp
# 2017-03-22 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-23 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-24 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-25 00:00:00+00:00     NaN     NaN     NaN
# 2017-03-26 00:00:00+00:00     NaN     NaN     NaN
#
# [5 rows x 392 columns]

# %%
sns.lineplot(data=data_DSP_day)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %%
data_DSP_setpoint_day = data_DSP_setpoint.resample('24H', on="timestamp").mean()
data_DSP_setpoint_day.head()
# Out:
#                            231060  231070  198149  198188  198237  198277  \
# timestamp
# 2017-06-05 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-06 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-07 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-08 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-09 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            210910  210932  210955  211012  ...  210670  \
# timestamp                                                  ...
# 2017-06-05 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-06 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-07 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-08 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
# 2017-06-09 00:00:00+00:00     NaN     NaN     NaN     NaN  ...     NaN
#
#                            230426  217132  217138  217142  228106  228160  \
# timestamp
# 2017-06-05 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-06 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-07 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-08 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2017-06-09 00:00:00+00:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            230982  231012  231043
# timestamp
# 2017-06-05 00:00:00+00:00     NaN     NaN     NaN
# 2017-06-06 00:00:00+00:00     NaN     NaN     NaN
# 2017-06-07 00:00:00+00:00     NaN     NaN     NaN
# 2017-06-08 00:00:00+00:00     NaN     NaN     NaN
# 2017-06-09 00:00:00+00:00     NaN     NaN     NaN
#
# [5 rows x 304 columns]

# %%
sns.lineplot(data=data_DSP_setpoint_day)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %%
sns.lineplot(data=data_DSP_day['216816'])
sns.lineplot(data=data_DSP_setpoint_day['216817'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\log\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\log\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\log\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '216816'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25032\658249017.py in <module>
# ----> 1 sns.lineplot(data=data_DSP_day['216816'])
#       2 sns.lineplot(data=data_DSP_setpoint_day['216817'])
#
# ~\anaconda3\envs\log\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\log\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '216816'

# %%
sns.lineplot(data=data_DSP_day['216834'])
sns.lineplot(data=data_DSP_setpoint_day['216835'])

# %%
sns.lineplot(data=data_DSP_day['414666'])
sns.lineplot(data=data_DSP_setpoint_day['414667'])

# %%
sns.lineplot(data=data_DSP_day['414694'])
sns.lineplot(data=data_DSP_setpoint_day['414695'])

# %%
sns.lineplot(data=data_DSP_day['414713'])
sns.lineplot(data=data_DSP_setpoint_day['414714'])

# %%
sns.lineplot(data=data_DSP_day['414721'])
sns.lineplot(data=data_DSP_setpoint_day['414722'])

# %%
shared_SASP_data_day = shared_SASP_data.resample('24H', on="timestamp").mean()
shared_SASP_data_day.head()

sns.lineplot(data=shared_SASP_data_day)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [125], in <module>
# ----> 1 shared_SASP_data_day = shared_SASP_data.resample('24H', on="timestamp").mean()
#       2 shared_SASP_data_day.head()
#       4 sns.lineplot(data=shared_SASP_data_day)
#
# File ~\anaconda3\envs\log\lib\site-packages\pandas\core\frame.py:10350, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10334 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10335 def resample(
#   10336     self,
#    (...)
#   10348     offset: TimedeltaConvertibleTypes | None = None,
#   10349 ) -> Resampler:
# > 10350     return super().resample(
#   10351         rule=rule,
#   10352         axis=axis,
#   10353         closed=closed,
#   10354         label=label,
#   10355         convention=convention,
#   10356         kind=kind,
#   10357         loffset=loffset,
#   10358         base=base,
#   10359         on=on,
#   10360         level=level,
#   10361         origin=origin,
#   10362         offset=offset,
#   10363     )
#
# File ~\anaconda3\envs\log\lib\site-packages\pandas\core\generic.py:8126, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8123 from pandas.core.resample import get_resampler
#    8125 axis = self._get_axis_number(axis)
# -> 8126 return get_resampler(
#    8127     self,
#    8128     freq=rule,
#    8129     label=label,
#    8130     closed=closed,
#    8131     axis=axis,
#    8132     kind=kind,
#    8133     loffset=loffset,
#    8134     convention=convention,
#    8135     base=base,
#    8136     key=on,
#    8137     level=level,
#    8138     origin=origin,
#    8139     offset=offset,
#    8140 )
#
# File ~\anaconda3\envs\log\lib\site-packages\pandas\core\resample.py:1382, in get_resampler(obj, kind, **kwds)
#    1378 """
#    1379 Create a TimeGrouper and return our resampler.
#    1380 """
#    1381 tg = TimeGrouper(**kwds)
# -> 1382 return tg._get_resampler(obj, kind=kind)
#
# File ~\anaconda3\envs\log\lib\site-packages\pandas\core\resample.py:1548, in TimeGrouper._get_resampler(self, obj, kind)
#    1529 def _get_resampler(self, obj, kind=None):
#    1530     """
#    1531     Return my resampler or raise if we have an invalid axis.
#    1532
#    (...)
#    1546
#    1547     """
# -> 1548     self._set_grouper(obj)
#    1550     ax = self.ax
#    1551     if isinstance(ax, DatetimeIndex):
#
# File ~\anaconda3\envs\log\lib\site-packages\pandas\core\groupby\grouper.py:372, in Grouper._set_grouper(self, obj, sort)
#     370     else:
#     371         if key not in obj._info_axis:
# --> 372             raise KeyError(f"The grouper name {key} is not found")
#     373         ax = Index(obj[key], name=key)
#     375 else:
#
# KeyError: 'The grouper name timestamp is not found'

# %% [markdown]
# ## Heatmaps

# %% [markdown]
# Lineplots are easy but still pretty diffcult to visualize. Instead, we can use [heatmaps](https://seaborn.pydata.org/generated/seaborn.heatmap.html), it's also really easy. Remember you can transpose your data to change the axis, like this:

# %% [markdown]
# And super-easy to plot:

# %%
sns.heatmap(data_DSP_hour.T, cmap="hot_r")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
sns.heatmap(data_DSP_setpoint_hour.T, cmap="hot_r")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
sns.heatmap(data_DSP_day.T, cmap="hot_r")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
sns.heatmap(data_DSP_setpoint_day.T, cmap="hot_r")
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# With this kind of plot is pretty evident where we have gaps with no-readings.

# %% [markdown]
# # Summary stats

# %% [markdown]
# Usually is useful to get some summary stats from our data. Fortunately, pandas has a simple method to obtain them:

# %%
data = data_DSP

# %%
data.describe()
# Out:
#              414713        414721        216816        414694        216834  \
# count  65356.000000  90202.000000  57084.000000  89608.000000  57094.000000
# mean       0.173344      0.615141      0.340732      0.492539      0.658277
# std        0.348432      0.749590      0.364250      1.447453      0.669857
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.025000      0.025000      0.025000
# 50%        0.000000      0.000000      0.025000      0.025000      0.025000
# 75%        0.000000      1.315000      0.680000      0.025000      1.330000
# max        1.730000      2.315000      1.490000      4.980000      2.090000
#
#              414666
# count  90118.000000
# mean       1.051036
# std        0.947365
# min        0.000000
# 25%        0.020000
# 50%        1.035000
# 75%        2.000000
# max        2.625000

# %% [markdown]
# These stats are usually visualizes in boxplot and histograms; these two plots can be easily obtained with the plotting libraries we are using. But first I suggest processing a little the dataframe to be able to plot all sensors in the same figure. We are using the pandas method [melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html). We have the data in this way right now:

# %%
data.head()
# Out:
#                   timestamp  414713  414721  216816  414694  216834  414666
# 0 2019-09-11 13:35:00+00:00     NaN     NaN     NaN     NaN   1.100     NaN
# 1 2019-09-11 13:40:00+00:00     NaN     NaN     NaN     NaN   1.160     NaN
# 2 2019-09-11 13:45:00+00:00     NaN     NaN     NaN     NaN   1.175     NaN
# 3 2019-09-11 13:50:00+00:00     NaN     NaN     NaN     NaN   1.440     NaN
# 4 2019-09-11 13:55:00+00:00     NaN     NaN     NaN     NaN   1.425     NaN

# %% [markdown]
# If we use the `melt` method we can convert our columns in rows, creating a new one that indicates which column it was. Is easier seeing the results, check it out:

# %%
melted_data = data.melt(id_vars="timestamp", var_name="sensor", value_name="pressure")
melted_data
# Out:
#                        timestamp  sensor  pressure
# 0      2019-09-11 13:35:00+00:00  414713       NaN
# 1      2019-09-11 13:40:00+00:00  414713       NaN
# 2      2019-09-11 13:45:00+00:00  414713       NaN
# 3      2019-09-11 13:50:00+00:00  414713       NaN
# 4      2019-09-11 13:55:00+00:00  414713       NaN
# ...                          ...     ...       ...
# 892717 2021-02-28 23:35:00+00:00  414666      0.02
# 892718 2021-02-28 23:40:00+00:00  414666      0.02
# 892719 2021-02-28 23:45:00+00:00  414666      0.02
# 892720 2021-02-28 23:50:00+00:00  414666      0.02
# 892721 2021-02-28 23:55:00+00:00  414666      0.02
#
# [892722 rows x 3 columns]

# %% [markdown]
# And now that we have the data in this shape, is easy to get a boxplot:

# %%
fig = sns.boxplot(y="pressure", x="sensor", data=melted_data)
labels = plt.xticks(rotation=90)

# %% [markdown]
# We can also plot an histogram, but with this number of sensors a boxplot is cleaner:

# %%
fig = sns.histplot(data=melted_data, x="pressure", hue="sensor", bins=20, kde=True, palette="Dark2")

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %% [markdown]
# Finally, let's create a dataset with the stats.

# %%
stats_data = data.describe()
stats_data
# Out:
#              414713        414721        216816        414694        216834  \
# count  65356.000000  90202.000000  57084.000000  89608.000000  57094.000000
# mean       0.173344      0.615141      0.340732      0.492539      0.658277
# std        0.348432      0.749590      0.364250      1.447453      0.669857
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.025000      0.025000      0.025000
# 50%        0.000000      0.000000      0.025000      0.025000      0.025000
# 75%        0.000000      1.315000      0.680000      0.025000      1.330000
# max        1.730000      2.315000      1.490000      4.980000      2.090000
#
#              414666
# count  90118.000000
# mean       1.051036
# std        0.947365
# min        0.000000
# 25%        0.020000
# 50%        1.035000
# 75%        2.000000
# max        2.625000

# %% [markdown]
# We are transposing it and reseting the index to keep a column with the point id (was the name of the column):

# %%
stats_data = stats_data.T.reset_index().rename(columns={"index":"id_point"})
stats_data
# Out:
#   id_point    count      mean       std  min    25%    50%    75%    max
# 0   414713  65356.0  0.173344  0.348432  0.0  0.000  0.000  0.000  1.730
# 1   414721  90202.0  0.615141  0.749590  0.0  0.000  0.000  1.315  2.315
# 2   216816  57084.0  0.340732  0.364250  0.0  0.025  0.025  0.680  1.490
# 3   414694  89608.0  0.492539  1.447453  0.0  0.025  0.025  0.025  4.980
# 4   216834  57094.0  0.658277  0.669857  0.0  0.025  0.025  1.330  2.090
# 5   414666  90118.0  1.051036  0.947365  0.0  0.020  1.035  2.000  2.625

# %% [markdown]
# And now let's convert the `id_point` column in our metadata set to string (is an int right now) so we are able to merge with `stats_data`:

# %%
metadata['id_point'] = metadata['id_point'].astype(str)

# %% [markdown]
# And merge!

# %%
stats_merged = pd.merge(stats_data, metadata, how="left", on="id_point")
stats_merged.head()
# Out:
#   id_point    count      mean       std  min    25%    50%    75%    max  \
# 0   414713  65356.0  0.173344  0.348432  0.0  0.000  0.000  0.000  1.730
# 1   414721  90202.0  0.615141  0.749590  0.0  0.000  0.000  1.315  2.315
# 2   216816  57084.0  0.340732  0.364250  0.0  0.025  0.025  0.680  1.490
# 3   414694  89608.0  0.492539  1.447453  0.0  0.025  0.025  0.025  4.980
# 4   216834  57094.0  0.658277  0.669857  0.0  0.025  0.025  1.330  2.090
#
#    building_id  ...  measurement_id                   datasource_hash  \
# 0          311  ...              37  b274d9d33df70a7e6d92986ee59def33
# 1          311  ...              37  843cb3422eeebc7f07a22f77fa8e16c4
# 2          311  ...              37  b75811d65e280a20a109d8c77e917812
# 3          311  ...              37  35c02370349a3de233e7874f3aae63cb
# 4          311  ...              37  753f71995678042e24ea004e7fba71af
#
#                                                topic  equip_id id_bdg  \
# 0     nyserda+0000124522+ahu-ac-23+AC-23_duct_sp_1_7     34998    311
# 1  nyserda+0000124522+ahu-ac-6+AC-6 (VAV6-8)_duct...     34999    311
# 2  nyserda+0000124522+ac-22+AC-22 (VAV22-7)_duct_...     34994    311
# 3     nyserda+0000124522+ahu-ac-20+AC-20_duct_sp_1_7     34993    311
# 4           nyserda+0000124522+ac-3+AC-3_duct_sp_1_7     34995    311
#
#   name_bdg equip_type_abbr    equip_type_name  area_served_desc  \
# 0   124522             AHU  Air Handling Unit               NaN
# 1   124522             AHU  Air Handling Unit               NaN
# 2   124522             AHU  Air Handling Unit               NaN
# 3   124522             AHU  Air Handling Unit               NaN
# 4   124522             AHU  Air Handling Unit               NaN
#
#               tags
# 0  ['ahu', 'hvac']
# 1  ['ahu', 'hvac']
# 2  ['ahu', 'hvac']
# 3  ['ahu', 'hvac']
# 4  ['ahu', 'hvac']
#
# [5 rows x 32 columns]

# %%
metadata.T
# Out:
#                                                               0      \
# id_point                                                     310029
# building_id                                                     441
# last_updated                                        1560571200000.0
# first_updated                                       1550541661000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                      245 E 149th St. Boiler-1 Fault Code
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                             0
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    b115b5053493748f7076ad09f69c4456
# topic             nyserda+0000088737+boiler-1+245 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               1      \
# id_point                                                     310009
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550700900000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                    225 E 149th St. Boiler-1 Exhaust Temp
# description                                                     NaN
# units                                                             F
# tagged_units                                                      f
# raw_unit_id                                                       2
# value                                                        183.55
# type                                        Exhaust Air Temperature
# point_type_id                                                    86
# measurement_id                                                    1
# datasource_hash                    4a1a11502acee3078352da312c40c262
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               2      \
# id_point                                                     310010
# building_id                                                     441
# last_updated                                        1560571200000.0
# first_updated                                       1550503775000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                      225 E 149th St. Boiler-1 Fault Code
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                             0
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    55882633fe8fb5aac7dac643c99b1af5
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               3      \
# id_point                                                     310011
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550503800000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                       225 E 149th St. Boiler-1 FFWD Temp
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                         46.90
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    831a8df09b848f53e807fa0204c45eaa
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               4      \
# id_point                                                     310012
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550503800000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                    225 E 149th St. Boiler-1 Fire Rate In
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                            91
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    aa147c829c7ed55b6e93cdbbb8b43d55
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               5      \
# id_point                                                     310013
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550504100000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                   225 E 149th St. Boiler-1 Fire Rate Out
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                            43
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    94e005810a3b3f40e0d79da131f92dd1
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               6      \
# id_point                                                     310014
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550504100000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                  225 E 149th St. Boiler-1 Flame Strength
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                           100
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    fef287ecfa709e93cc710c59530bbc50
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               7      \
# id_point                                                     310015
# building_id                                                     441
# last_updated                                        1560485100000.0
# first_updated                                       1550504100000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                      225 E 149th St. Boiler-1 Inlet Temp
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                         43.45
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    8e01bcb1c52c045a7a8c02c67efd76b2
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               8      \
# id_point                                                     310016
# building_id                                                     441
# last_updated                                        1550528400000.0
# first_updated                                       1550504100000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                225 E 149th St. Boiler-1 Net Remote Setpt
# description                                                     NaN
# units                                                             ?
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                        175.02
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    2ffd47ad64bb5dedfa759fc12d8c7708
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...
# equip_id                                                      28797
# id_bdg                                                          441
# name_bdg                                                      88737
# equip_type_abbr                                                 BLR
# equip_type_name                                              Boiler
# area_served_desc                                                NaN
# tags                                             ['boiler', 'hvac']
#
#                                                               9      ...  \
# id_point                                                     310017  ...
# building_id                                                     441  ...
# last_updated                                        1560485100000.0  ...
# first_updated                                       1550504100000.0  ...
# device                                                          NaN  ...
# objectId                                                        NaN  ...
# name_point                     225 E 149th St. Boiler-1 Outlet Temp  ...
# description                                                     NaN  ...
# units                                                             ?  ...
# tagged_units                                                      ?  ...
# raw_unit_id                                                      23  ...
# value                                                         50.59  ...
# type                                                        Virtual  ...
# point_type_id                                                   434  ...
# measurement_id                                                   18  ...
# datasource_hash                    4860056a8af0ab12798d3e5bc8735002  ...
# topic             nyserda+0000088737+boiler-1+225 E 149th St. Bo...  ...
# equip_id                                                      28797  ...
# id_bdg                                                          441  ...
# name_bdg                                                      88737  ...
# equip_type_abbr                                                 BLR  ...
# equip_type_name                                              Boiler  ...
# area_served_desc                                                NaN  ...
# tags                                             ['boiler', 'hvac']  ...
#
#                                                               44380  \
# id_point                                                     231135
# building_id                                                     399
# last_updated                                        1596253500000.0
# first_updated                                       1529335800000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                               CWST_value
# description                                              CWST_value
# units                                                             F
# tagged_units                                                      f
# raw_unit_id                                                       2
# value                                                             0
# type                             Condenser Water Supply Temperature
# point_type_id                                                   392
# measurement_id                                                    1
# datasource_hash                    fcac5c7059376b78df9a21cb1a3f04a1
# topic             nyserda+0000097151+condenserWaterSystem+CWST_v...
# equip_id                                                      32356
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                                COND
# equip_type_name                                           Condenser
# area_served_desc                                                NaN
# tags                                          ['hvac', 'condenser']
#
#                                                               44381  \
# id_point                                                     231134
# building_id                                                     399
# last_updated                                        1596253500000.0
# first_updated                                       1543640400000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                              CWRT_status
# description                                             CWRT_status
# units                                                           NaN
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                          down
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    0329bda745d746d11b00ae54567fb370
# topic             nyserda+0000097151+condenserWaterSystem+CWRT_s...
# equip_id                                                      32356
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                                COND
# equip_type_name                                           Condenser
# area_served_desc                                                NaN
# tags                                          ['hvac', 'condenser']
#
#                                                               44382  \
# id_point                                                     231133
# building_id                                                     399
# last_updated                                        1596253500000.0
# first_updated                                       1529335800000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                               CWRT_value
# description                                              CWRT_value
# units                                                             F
# tagged_units                                                      f
# raw_unit_id                                                       2
# value                                                             0
# type                             Condenser Water Return Temperature
# point_type_id                                                   388
# measurement_id                                                    1
# datasource_hash                    d3726f27eb53db8171dae73040bc7259
# topic             nyserda+0000097151+condenserWaterSystem+CWRT_v...
# equip_id                                                      32356
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                                COND
# equip_type_name                                           Condenser
# area_served_desc                                                NaN
# tags                                          ['hvac', 'condenser']
#
#                                                               44383  \
# id_point                                                     231132
# building_id                                                     399
# last_updated                                        1559360700000.0
# first_updated                                       1543640400000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                         CWP Power_status
# description                                        CWP Power_status
# units                                                           NaN
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                            ok
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    b41abef8998411543bb651e7a95f376d
# topic             nyserda+0000097151+condenserWaterSystem+CWP Po...
# equip_id                                                      32357
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                                PUMP
# equip_type_name                                                Pump
# area_served_desc                                                NaN
# tags                         ['pump', 'hvac', 'condenserWaterPump']
#
#                                                               44384  \
# id_point                                                     231131
# building_id                                                     399
# last_updated                                        1559360700000.0
# first_updated                                       1527825600000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                          CWP Power_value
# description                                         CWP Power_value
# units                                                            kW
# tagged_units                                                     kw
# raw_unit_id                                                      17
# value                                                             0
# type                                                     Real Power
# point_type_id                                                   221
# measurement_id                                                   13
# datasource_hash                    2ae169b58e208a9b9e3df87072bdafed
# topic             nyserda+0000097151+condenserWaterSystem+CWP Po...
# equip_id                                                      32357
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                                PUMP
# equip_type_name                                                Pump
# area_served_desc                                                NaN
# tags                         ['pump', 'hvac', 'condenserWaterPump']
#
#                                                               44385  \
# id_point                                                     359906
# building_id                                                     399
# last_updated                                        1596253500000.0
# first_updated                                       1580533200000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                         Main Meter kW_v1
# description                                                     NaN
# units                                                           NaN
# tagged_units                                                     kw
# raw_unit_id                                                      17
# value                                                        114.08
# type                                                     Real Power
# point_type_id                                                   221
# measurement_id                                                   13
# datasource_hash                    66e321814268c37187fe46120a91ea01
# topic             nyserda+0000097151+elecMeter-site+Main Meter k...
# equip_id                                                      32358
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                               METER
# equip_type_name                                               Meter
# area_served_desc                                                NaN
# tags                                         ['meter', 'elecMeter']
#
#                                                               44386  \
# id_point                                                     359905
# building_id                                                     399
# last_updated                                        1589532300000.0
# first_updated                                       1580533200000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                         Main Meter kW_v0
# description                                                     NaN
# units                                                           NaN
# tagged_units                                                     kw
# raw_unit_id                                                      17
# value                                                         86.69
# type                                                     Real Power
# point_type_id                                                   221
# measurement_id                                                   13
# datasource_hash                    0d67a5188df9184da502b013c6d9ae11
# topic             nyserda+0000097151+elecMeter-site+Main Meter k...
# equip_id                                                      32358
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                               METER
# equip_type_name                                               Meter
# area_served_desc                                                NaN
# tags                                         ['meter', 'elecMeter']
#
#                                                               44387  \
# id_point                                                     231120
# building_id                                                     399
# last_updated                                        1543639500000.0
# first_updated                                       1528909200000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                    Building Demand_value
# description                                   Building Demand_value
# units                                                            kW
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                        108.71
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    26ace99b6d6d2692b3d5ae723f489241
# topic             nyserda+0000097151+Site-Sensor+Building Demand...
# equip_id                                                      32358
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                               METER
# equip_type_name                                               Meter
# area_served_desc                                                NaN
# tags                                         ['meter', 'elecMeter']
#
#                                                               44388  \
# id_point                                                     231119
# building_id                                                     399
# last_updated                                        1559360700000.0
# first_updated                                       1543640400000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                       Building Demand_v1
# description                                      Building Demand_v1
# units                                                            kW
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                         97.55
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    0cb2239dcfc357e1c3a34d3e0401fe19
# topic             nyserda+0000097151+Site-Sensor+Building Demand_v1
# equip_id                                                      32358
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                               METER
# equip_type_name                                               Meter
# area_served_desc                                                NaN
# tags                                         ['meter', 'elecMeter']
#
#                                                               44389
# id_point                                                     231118
# building_id                                                     399
# last_updated                                        1552639500000.0
# first_updated                                       1546232400000.0
# device                                                          NaN
# objectId                                                        NaN
# name_point                                       Building Demand_v0
# description                                      Building Demand_v0
# units                                                            kW
# tagged_units                                                      ?
# raw_unit_id                                                      23
# value                                                         84.67
# type                                                        Virtual
# point_type_id                                                   434
# measurement_id                                                   18
# datasource_hash                    85480508025745f21f3724ad592405fa
# topic             nyserda+0000097151+Site-Sensor+Building Demand_v0
# equip_id                                                      32358
# id_bdg                                                          399
# name_bdg                                                      97151
# equip_type_abbr                                               METER
# equip_type_name                                               Meter
# area_served_desc                                                NaN
# tags                                         ['meter', 'elecMeter']
#
# [24 rows x 44390 columns]

# %% [markdown]
# Finally, plot! we want to visualize the mean temperature of the points, colored by the building name.

# %%
fig = sns.barplot(data=stats_merged, x="id_point", y="mean", hue="name_bdg", dodge=False)
labels = plt.xticks(rotation=90)
