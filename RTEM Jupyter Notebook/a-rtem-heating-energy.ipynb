# %% [markdown]
# # Time Series Analysis Examples
# In this notebook we will be transforming and exploring time-series data from Onboard API. Make sure to run the following chunk of code first in order to install it.
#
# How to query time-series from data points, process and visually explore them. This notebook is outlined in several YouTube videos that discuss:
# - how [to load and filter time-series data](https://youtu.be/KDThdyes8kc) from sensors
# - [resample and transform time-series data](https://youtu.be/VlQNGwiSSKM)
# - and [create heat maps and boxplots of data](https://youtu.be/QMr0y9LOlr8) for exploration

# %%
import pandas as pd
from onboard.client import RtemClient

# %%
from datetime import datetime, timezone, timedelta
import pytz
from onboard.client.models import TimeseriesQuery, PointData
from onboard.client.dataframes import points_df_from_streaming_timeseries

# %% [markdown]
# # Create the client

# %% [markdown]
# For this notebook, you need to use the API Key with acces to the general scope and building:read scope. Let's create the client:

# %%
api_key = 'ob-p-_KnPccpVFOwKvS5u_SpKixHjKKq6H1JvrzwjxISOfPiNKKZ56_EeE5ORVJOGGtx0d_k'

# %%
client = RtemClient(api_key=api_key)

# %% [markdown]
# # Load & filter data

# %% [markdown]
# We will be using the metadata file we obtained from Onboard API in the previous notebook. Of course you can query these points again, but let's learn how to load and filter the data using *pandas*:

# %%
metadata = pd.read_csv("./rtem_all_points_metadata.csv")

# %% [markdown]
# Let's check the data types:

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44390 entries, 0 to 44389
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_point          44390 non-null  int64
#  1   building_id       44390 non-null  int64
#  2   last_updated      44342 non-null  float64
#  3   first_updated     44342 non-null  float64
#  4   device            0 non-null      float64
#  5   objectId          0 non-null      float64
#  6   name_point        14658 non-null  object
#  7   description       31843 non-null  object
#  8   units             31687 non-null  object
#  9   tagged_units      14654 non-null  object
#  10  raw_unit_id       44390 non-null  int64
#  11  value             44274 non-null  object
#  12  type              44390 non-null  object
#  13  point_type_id     44390 non-null  int64
#  14  measurement_id    44390 non-null  int64
#  15  datasource_hash   44390 non-null  object
#  16  topic             44390 non-null  object
#  17  equip_id          44390 non-null  int64
#  18  id_bdg            44390 non-null  int64
#  19  name_bdg          44390 non-null  int64
#  20  equip_type_abbr   44390 non-null  object
#  21  equip_type_name   44390 non-null  object
#  22  area_served_desc  0 non-null      float64
#  23  tags              44390 non-null  object
# dtypes: float64(5), int64(8), object(11)
# memory usage: 8.1+ MB

# %%
metadata.head()
# Out:
#    id_point  building_id  last_updated  first_updated  device  objectId  \
# 0    310029          441  1.560571e+12   1.550542e+12     NaN       NaN
# 1    310009          441  1.560485e+12   1.550701e+12     NaN       NaN
# 2    310010          441  1.560571e+12   1.550504e+12     NaN       NaN
# 3    310011          441  1.560485e+12   1.550504e+12     NaN       NaN
# 4    310012          441  1.560485e+12   1.550504e+12     NaN       NaN
#
#                               name_point description units tagged_units  ...  \
# 0    245 E 149th St. Boiler-1 Fault Code         NaN     ?            ?  ...
# 1  225 E 149th St. Boiler-1 Exhaust Temp         NaN     F            f  ...
# 2    225 E 149th St. Boiler-1 Fault Code         NaN     ?            ?  ...
# 3     225 E 149th St. Boiler-1 FFWD Temp         NaN     ?            ?  ...
# 4  225 E 149th St. Boiler-1 Fire Rate In         NaN     ?            ?  ...
#
#    measurement_id                   datasource_hash  \
# 0              18  b115b5053493748f7076ad09f69c4456
# 1               1  4a1a11502acee3078352da312c40c262
# 2              18  55882633fe8fb5aac7dac643c99b1af5
# 3              18  831a8df09b848f53e807fa0204c45eaa
# 4              18  aa147c829c7ed55b6e93cdbbb8b43d55
#
#                                                topic  equip_id  id_bdg  \
# 0  nyserda+0000088737+boiler-1+245 E 149th St. Bo...     28797     441
# 1  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 2  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 3  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 4  nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
#
#   name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 0    88737             BLR           Boiler               NaN
# 1    88737             BLR           Boiler               NaN
# 2    88737             BLR           Boiler               NaN
# 3    88737             BLR           Boiler               NaN
# 4    88737             BLR           Boiler               NaN
#
#                  tags
# 0  ['boiler', 'hvac']
# 1  ['boiler', 'hvac']
# 2  ['boiler', 'hvac']
# 3  ['boiler', 'hvac']
# 4  ['boiler', 'hvac']
#
# [5 rows x 24 columns]

# %% [markdown]
# We have a lot of points here:

# %%
len(metadata.id_point)
# Out:
# 44390

# %%
domestic = metadata[(metadata.name_point.str.contains('Domestic', regex=False) == True)]

# %%
domestic
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 2171     217178          317  1.598918e+12   1.571112e+12     NaN       NaN
# 2680     284534          375  1.590170e+12   1.577855e+12     NaN       NaN
# 2694     227351          375  1.577854e+12   1.556683e+12     NaN       NaN
# 5342     356061          467  1.598932e+12   1.577855e+12     NaN       NaN
# 5768     326009          445  1.598933e+12   1.583266e+12     NaN       NaN
# 7276     356102          468  1.598932e+12   1.587137e+12     NaN       NaN
# 7277     356101          468  1.588693e+12   1.587137e+12     NaN       NaN
# 10388    356126          469  1.598933e+12   1.589308e+12     NaN       NaN
# 11296    344414          461  1.598932e+12   1.577855e+12     NaN       NaN
# 12306    356024          466  1.598933e+12   1.585111e+12     NaN       NaN
# 19260    344452          462  1.598933e+12   1.582125e+12     NaN       NaN
# 22670    343366          451  1.592598e+12   1.577855e+12     NaN       NaN
# 29902    203687          197  1.598932e+12   1.569902e+12     NaN       NaN
# 31218    414611          180  1.598918e+12   1.598918e+12     NaN       NaN
# 31225    201418          180  1.577854e+12   1.556683e+12     NaN       NaN
# 32060    205073          216  1.598918e+12   1.548046e+12     NaN       NaN
# 32258    206334          232  1.598932e+12   1.541044e+12     NaN       NaN
# 34170    210757          263  1.577854e+12   1.567310e+12     NaN       NaN
# 43491    205027          214  1.577854e+12   1.559362e+12     NaN       NaN
#
#                                               name_point  \
# 2171   611 Academy Street Boiler Domestic Hot Water T...
# 2680   3400 Fort Independence Street Boiler 1 Domesti...
# 2694   3400 Fort Independence Boiler 1 Domestic Hot W...
# 5342   1710 Avenue H Boiler Domestic Hot Water Temper...
# 5768   450 W 147th Street Boiler Domestic Hot Water T...
# 7276   51 Cross Street Boiler Domestic Hot Water Temp...
# 7277   51 Cross Street Boiler Domestic Hot Water Heat...
# 10388  9-11 Greenridge Avenue Boiler Domestic Hot Wat...
# 11296  105 E 29th Street Boiler Domestic Hot Water Te...
# 12306  45-26 44th Street Boiler Domestic Hot Water Te...
# 19260  819 E 173rd Street Boiler Domestic Hot Water T...
# 22670  70 Prospect Park SW Boiler Domestic Hot Water ...
# 29902  718 Broadway Boiler Domestic Hot Water Tempera...
# 31218  304 St Johns Place Boiler Domestic Hot Water T...
# 31225  304 St Johns Boiler Domestic Hot Water Tempera...
# 32060  935 Ogden Avenue Boiler Domestic Hot Water Tem...
# 32258  100 Lawn Terrace Boiler Domestic Hot Water Tem...
# 34170  370 Westchester Avenue Boiler Domestic Hot Wat...
# 43491  151 E 43rd Street Boiler Domestic Hot Water Te...
#
#                                              description units tagged_units  \
# 2171   611 Academy Street Boiler Domestic Hot Water T...     F            f
# 2680                                                 NaN     F            f
# 2694   3400 Fort Independence Boiler 1 Domestic Hot W...     F            f
# 5342                                                 NaN   NaN            f
# 5768                                                 NaN     F            f
# 7276                                                 NaN   NaN            f
# 7277                                                 NaN   NaN       on/off
# 10388                                                NaN   NaN            f
# 11296                                                NaN     F            f
# 12306                                                NaN   NaN            f
# 19260                                                NaN     F            f
# 22670                                                NaN     F            f
# 29902  718 Broadway Boiler Domestic Hot Water Tempera...     F            f
# 31218                                                NaN   NaN            f
# 31225  304 St Johns Boiler Domestic Hot Water Tempera...     F            f
# 32060  935 Ogden Avenue Boiler Domestic Hot Water Tem...     F            f
# 32258  100 Lawn Terrace Boiler Domestic Hot Water Tem...     F            f
# 34170  370 Westchester Avenue Boiler Domestic Hot Wat...     F            f
# 43491  151 E 43rd Street Boiler Domestic Hot Water Te...     F            f
#
#        ...  measurement_id                   datasource_hash  \
# 2171   ...               1  4f3e88db37da368925572af3de0ea5c8
# 2680   ...               1  00d06c2f2495c313183aba4e8ce8d631
# 2694   ...               1  3bc0432ee68b75a591b9da0b3e90e56f
# 5342   ...               1  91cbcfca95ce91ae292d5f43491d8b4d
# 5768   ...               1  3eff5c7e60978d85278c59aaebbd6d70
# 7276   ...               1  e752fbe06e1de807c493f3a6f40dae58
# 7277   ...              11  c938c23ded7a9e83645db9fb6fd79ecb
# 10388  ...               1  1fe6180f5a0374bb4efbe119205df7cb
# 11296  ...               1  6d60b1a07e5a12747dd32ccb5300c52f
# 12306  ...               1  6f025880078d90420a2947748e10993f
# 19260  ...               1  ed0cad20ac06f25463da44433e537cc1
# 22670  ...               1  3f34517af7b1cad1fdce71c3a51fa699
# 29902  ...               1  29a66a29c65a7d9787d455f1c070deb4
# 31218  ...               1  64fcee39cd8ccd2351d829b2cd02933b
# 31225  ...               1  98999516bca1461906973d8540ce6fa2
# 32060  ...               1  dfcc3e2eb6ad95d8f749c157599df230
# 32258  ...               1  dbf94d4a0ae9983b2258b3efba706b9c
# 34170  ...               1  ff2c1e7f9fc467f7ea8c2c7f6c578aad
# 43491  ...               1  2fa035655824ad45c0d66ae474b13540
#
#                                                    topic  equip_id  id_bdg  \
# 2171   nyserda+0000128286+boiler+611 Academy Street B...     20946     317
# 2680   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 2694   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 5342   nyserda+0000139252+boiler-1+1710 Avenue H Boil...     31243     467
# 5768   nyserda+0000145732+boiler-1+450 W 147th Street...     29834     445
# 7276   nyserda+0000159109+boiler-1+51 Cross Street Bo...     31245     468
# 7277   nyserda+0000159109+boiler-1+51 Cross Street Bo...     31245     468
# 10388  nyserda+0000144601+boiler-1+9-11 Greenridge Av...     31246     469
# 11296  nyserda+0000137940+boiler-1+105 E 29th Street ...     30465     461
# 12306  nyserda+0000137257+boiler-1+45-26 44th Street ...     31241     466
# 19260  nyserda+0000144540+boiler-1+819 E 173rd Street...     30467     462
# 22670  nyserda+0000137244+boiler-1+70 Prospect Park S...     30303     451
# 29902  nyserda+0000136534+boiler+718 Broadway Boiler ...     33977     197
# 31218  nyserda+0000112065+boiler-1+304 St Johns Place...     34987     180
# 31225  nyserda+0000112065+boiler+304 St Johns Boiler ...     34987     180
# 32060  nyserda+0000099313+boiler+935 Ogden Avenue Boi...     34989     216
# 32258  nyserda+0000099291+boiler+100 Lawn Terrace Boi...     33923     232
# 34170  nyserda+0000133602+boiler+370 Westchester Aven...     36560     263
# 43491  nyserda+0000097593+hotWaterPlant+151 E 43rd St...     36556     214
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 2171    128286             BLR           Boiler               NaN
# 2680     97789             BLR           Boiler               NaN
# 2694     97789             BLR           Boiler               NaN
# 5342    139252             BLR           Boiler               NaN
# 5768    145732             BLR           Boiler               NaN
# 7276    159109             BLR           Boiler               NaN
# 7277    159109             BLR           Boiler               NaN
# 10388   144601             BLR           Boiler               NaN
# 11296   137940             BLR           Boiler               NaN
# 12306   137257             BLR           Boiler               NaN
# 19260   144540             BLR           Boiler               NaN
# 22670   137244             BLR           Boiler               NaN
# 29902   136534             BLR           Boiler               NaN
# 31218   112065             BLR           Boiler               NaN
# 31225   112065             BLR           Boiler               NaN
# 32060    99313             BLR           Boiler               NaN
# 32258    99291             BLR           Boiler               NaN
# 34170   133602             BLR           Boiler               NaN
# 43491    97593             BLR           Boiler               NaN
#
#                                        tags
# 2171                     ['boiler', 'hvac']
# 2680                     ['boiler', 'hvac']
# 2694                     ['boiler', 'hvac']
# 5342                     ['boiler', 'hvac']
# 5768                     ['boiler', 'hvac']
# 7276                     ['boiler', 'hvac']
# 7277                     ['boiler', 'hvac']
# 10388                    ['boiler', 'hvac']
# 11296                    ['boiler', 'hvac']
# 12306                    ['boiler', 'hvac']
# 19260                    ['boiler', 'hvac']
# 22670                    ['boiler', 'hvac']
# 29902                    ['boiler', 'hvac']
# 31218  ['boiler', 'hvac', 'hotWaterBoiler']
# 31225  ['boiler', 'hvac', 'hotWaterBoiler']
# 32060                    ['boiler', 'hvac']
# 32258                    ['boiler', 'hvac']
# 34170                    ['boiler', 'hvac']
# 43491                    ['boiler', 'hvac']
#
# [19 rows x 24 columns]

# %% [markdown]
# Let's filter out only the Zone Temperature sensors -that's the `type_id` 77, you can confirm this querying the ontology data, like we did in the previous notebook ;)- and that are Fan Coil Units:

# %%
# not used
pump_id = pump_data['equip_id'].unique()
pump_hhw = "'hotWaterPump'"
pump_hhw_data = pd.DataFrame()
for i in pump_id:
    df_curr = pump_data[pump_data['equip_id'] == i]
    curr_tag = df_curr['tags'].iloc[0]
    curr_tag_list = curr_tag.strip('[]').split(", ")
    if (pump_hhw in curr_tag_list):
        pump_hhw_data = pump_hhw_data.append(df_curr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # not used
# ----> 2 pump_id = pump_data['equip_id'].unique()
#       3 pump_hhw = "'hotWaterPump'"
#       4 pump_hhw_data = pd.DataFrame()
#
# NameError: name 'pump_data' is not defined

# %%
boiler_id = boiler_data['equip_id'].unique()
df_boiler_list = list()
for i in boiler_id:
    df_curr = boiler_data[boiler_data['equip_id'] == i]
    df_boiler_list.append(df_curr)
    filename = "./boiler/boiler_data_equip_" + str(i) +".csv"
    df_curr.to_csv(filename, index=False)

# %%
heating_plant_building_id = heating_plant_data['building_id'].unique()
df_heating_plant_list = list()
for i in heating_plant_building_id:
    df_curr = heating_plant_data[heating_plant_data['building_id'] == i]
    df_heating_plant_list.append(df_curr)
    filename = "./boiler/heating_plant_data_building_" + str(i) +".csv"
    df_curr.to_csv(filename, index=False)

# %% [markdown]
# # Load & filter heating hot water data

# %%
boiler_data = metadata[(metadata.equip_type_name == "Boiler")]
heating_plant_data = metadata[(metadata.equip_type_name == "Hot Water Plant")]
pump_data = metadata[(metadata.equip_type_name == "Pump")]

# %% [markdown]
# heating hot water plant

# %%
heating_plant_flow_data = heating_plant_data[(heating_plant_data.type == "Hot Water Supply Flow")]
heating_plant_flow_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 3868     283201          426  1.606798e+12   1.512104e+12     NaN       NaN
# 4112     283439          426  1.606798e+12   1.512104e+12     NaN       NaN
# 20071    343962          454  1.598933e+12   1.567310e+12     NaN       NaN
# 26372    344702          465  1.574203e+12   1.548997e+12     NaN       NaN
# 32368    208544          256  1.598889e+12   1.569428e+12     NaN       NaN
# 36035    215707          301  1.553918e+12   1.538280e+12     NaN       NaN
#
#                                               name_point  \
# 3868   480 W 42nd St - Signature Theatre DhwPlant DHW...
# 4112    480 W 42nd St - Signature Theatre HwPlant HWFlow
# 20071                                Primary HW Flow GPM
# 26372                         HWS - Boilers Loop_HWSFlow
# 32368                                                NaN
# 36035                                                NaN
#
#                                 description units tagged_units  ...  \
# 3868                                    NaN   gpm          gpm  ...
# 4112                                    NaN   gpm          gpm  ...
# 20071                                   NaN   gpm          gpm  ...
# 26372                                   NaN   NaN          gpm  ...
# 32368          B132 Plant Total FO Flow GPM   gpm          NaN  ...
# 36035  Roosevelt Landings eBX DHW HXCR Flow   gpm          NaN  ...
#
#        measurement_id                   datasource_hash  \
# 3868                5  309a6cf1e3cacabae12c3ae45eca8db2
# 4112                5  172610bd9df27d767c0a03f449abf05d
# 20071               5  3d5edef941aaebd5125523500f052581
# 26372               5  cf6f11643a8ad54b43816f4b16729b80
# 32368               5  d205e7c8d9326a61a07898ee801642ce
# 36035               5  48695cbc7391c0bf58caf9f48527fada
#
#                                                    topic  equip_id  id_bdg  \
# 3868   nyserda+000076513+domesticHotWaterPlant+480 W ...     26938     426
# 4112   nyserda+000076513+hotWaterPlant+480 W 42nd St ...     26961     426
# 20071  nyserda+0000155776+hotWaterPlant+Primary HW Fl...     30390     454
# 26372  nyserda+00000123771+hotWaterPlant+HWS - Boiler...     30491     465
# 32368  nyserda+0000135785+hotWaterPlant+B132 Plant To...     19740     256
# 36035  nyserda+0000099466+domesticHotWaterPlant+Roose...     20689     301
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 3868     76513             HWS  Hot Water Plant               NaN
# 4112     76513             HWS  Hot Water Plant               NaN
# 20071   155776             HWS  Hot Water Plant               NaN
# 26372   123771             HWS  Hot Water Plant               NaN
# 32368   135785             HWS  Hot Water Plant               NaN
# 36035    99466             HWS  Hot Water Plant               NaN
#
#                             tags
# 3868   ['hvac', 'hotWaterPlant']
# 4112   ['hvac', 'hotWaterPlant']
# 20071  ['hvac', 'hotWaterPlant']
# 26372  ['hvac', 'hotWaterPlant']
# 32368  ['hvac', 'hotWaterPlant']
# 36035  ['hvac', 'hotWaterPlant']
#
# [6 rows x 24 columns]

# %%
heating_plant_hhws_data = heating_plant_data[(heating_plant_data.type == "Hot Water Supply Temperature")]

# %%
heating_plant_hhwr_data = heating_plant_data[(heating_plant_data.type == "Hot Water Return Temperature")]

# %%
heating_plant_flow_equip = heating_plant_flow_data['equip_id']
heating_plant_hhws_equip = heating_plant_hhws_data['equip_id']
heating_plant_hhwr_equip = heating_plant_hhwr_data['equip_id']

# %%
df_temp = pd.merge(heating_plant_flow_equip, heating_plant_hhws_equip, how='inner')
heating_plant_equip = pd.merge(df_temp, heating_plant_hhwr_equip, how='inner')

# %%
hhwp_flow = heating_plant_flow_data[(heating_plant_flow_data['equip_id'].isin(heating_plant_equip["equip_id"]))]
hhwp_flow
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 4112     283439          426  1.606798e+12   1.512104e+12     NaN       NaN
# 20071    343962          454  1.598933e+12   1.567310e+12     NaN       NaN
# 26372    344702          465  1.574203e+12   1.548997e+12     NaN       NaN
#
#                                              name_point description units  \
# 4112   480 W 42nd St - Signature Theatre HwPlant HWFlow         NaN   gpm
# 20071                               Primary HW Flow GPM         NaN   gpm
# 26372                        HWS - Boilers Loop_HWSFlow         NaN   NaN
#
#       tagged_units  ...  measurement_id                   datasource_hash  \
# 4112           gpm  ...               5  172610bd9df27d767c0a03f449abf05d
# 20071          gpm  ...               5  3d5edef941aaebd5125523500f052581
# 26372          gpm  ...               5  cf6f11643a8ad54b43816f4b16729b80
#
#                                                    topic  equip_id  id_bdg  \
# 4112   nyserda+000076513+hotWaterPlant+480 W 42nd St ...     26961     426
# 20071  nyserda+0000155776+hotWaterPlant+Primary HW Fl...     30390     454
# 26372  nyserda+00000123771+hotWaterPlant+HWS - Boiler...     30491     465
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 4112     76513             HWS  Hot Water Plant               NaN
# 20071   155776             HWS  Hot Water Plant               NaN
# 26372   123771             HWS  Hot Water Plant               NaN
#
#                             tags
# 4112   ['hvac', 'hotWaterPlant']
# 20071  ['hvac', 'hotWaterPlant']
# 26372  ['hvac', 'hotWaterPlant']
#
# [3 rows x 24 columns]

# %%
hhwp_hhws = heating_plant_hhws_data[(heating_plant_hhws_data['equip_id'].isin(heating_plant_equip["equip_id"]))]
hhwp_hhws
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 4110     283441          426  1.606798e+12   1.512104e+12     NaN       NaN
# 20069    343964          454  1.598933e+12   1.567310e+12     NaN       NaN
# 26373    344701          465  1.574203e+12   1.548997e+12     NaN       NaN
#
#                                               name_point description units  \
# 4110   480 W 42nd St - Signature Theatre HwPlant HWSTemp         NaN     F
# 20069                            Primary HWS Temp Deg. F         NaN     F
# 26373                      HWS - Boilers Loop_ComPHWSTmp         NaN   NaN
#
#       tagged_units  ...  measurement_id                   datasource_hash  \
# 4110             f  ...               1  94350ac3b8cc2e5c0834b543fd1b15fc
# 20069            f  ...               1  d8db6eb2136c554f2e10adc9316aa2d1
# 26373            f  ...               1  1dc2d98109f6d229ea084d67fdb57363
#
#                                                    topic  equip_id  id_bdg  \
# 4110   nyserda+000076513+hotWaterPlant+480 W 42nd St ...     26961     426
# 20069  nyserda+0000155776+hotWaterPlant+Primary HWS T...     30390     454
# 26373  nyserda+00000123771+hotWaterPlant+HWS - Boiler...     30491     465
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 4110     76513             HWS  Hot Water Plant               NaN
# 20069   155776             HWS  Hot Water Plant               NaN
# 26373   123771             HWS  Hot Water Plant               NaN
#
#                             tags
# 4110   ['hvac', 'hotWaterPlant']
# 20069  ['hvac', 'hotWaterPlant']
# 26373  ['hvac', 'hotWaterPlant']
#
# [3 rows x 24 columns]

# %%
hhwp_hhwr = heating_plant_hhwr_data[(heating_plant_hhwr_data['equip_id'].isin(heating_plant_equip["equip_id"]))]
hhwp_hhwr
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 4111     283440          426  1.606798e+12   1.512104e+12     NaN       NaN
# 20070    343963          454  1.598933e+12   1.567310e+12     NaN       NaN
# 26374    344700          465  1.574203e+12   1.548997e+12     NaN       NaN
#
#                                               name_point description units  \
# 4111   480 W 42nd St - Signature Theatre HwPlant HWRTemp         NaN     F
# 20070                            Primary HWR Temp Deg. F         NaN     F
# 26374                      HWS - Boilers Loop_ComPHWRTmp         NaN   NaN
#
#       tagged_units  ...  measurement_id                   datasource_hash  \
# 4111             f  ...               1  63afce92bc4aec386394eac5725a86f0
# 20070            f  ...               1  504b57a1dafcdaaf33426b00b3738634
# 26374            f  ...               1  3bdddfd5b7898d5c2eb76fb2e1cd6776
#
#                                                    topic  equip_id  id_bdg  \
# 4111   nyserda+000076513+hotWaterPlant+480 W 42nd St ...     26961     426
# 20070  nyserda+0000155776+hotWaterPlant+Primary HWR T...     30390     454
# 26374  nyserda+00000123771+hotWaterPlant+HWS - Boiler...     30491     465
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 4111     76513             HWS  Hot Water Plant               NaN
# 20070   155776             HWS  Hot Water Plant               NaN
# 26374   123771             HWS  Hot Water Plant               NaN
#
#                             tags
# 4111   ['hvac', 'hotWaterPlant']
# 20070  ['hvac', 'hotWaterPlant']
# 26374  ['hvac', 'hotWaterPlant']
#
# [3 rows x 24 columns]

# %% [markdown]
# boiler

# %%
boiler_hhws_data = boiler_data[(boiler_data.type == "Hot Water Supply Temperature")]

# %%
boiler_hhwr_data = boiler_data[(boiler_data.type == "Hot Water Return Temperature")]

# %%
boiler_hhws_equip = boiler_hhws_data['equip_id']
boiler_hhwr_equip = boiler_hhwr_data['equip_id']

# %%
boiler_equip = pd.merge(boiler_hhws_equip, boiler_hhwr_equip, how='inner')
boiler_equip
# Out:
#      equip_id
# 0       28499
# 1       22333
# 2       22333
# 3       22333
# 4       31243
# ..        ...
# 100     21813
# 101     21813
# 102     22511
# 103     22513
# 104     22514
#
# [105 rows x 1 columns]

# %%
boiler_hhws = boiler_hhws_data[(boiler_hhws_data['equip_id'].isin(boiler_equip["equip_id"]))]
boiler_hhws
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1762     306129          434  1.609476e+12   1.582827e+12     NaN       NaN
# 2680     284534          375  1.590170e+12   1.577855e+12     NaN       NaN
# 2692     227353          375  1.577854e+12   1.556683e+12     NaN       NaN
# 2694     227351          375  1.577854e+12   1.556683e+12     NaN       NaN
# 5337     356066          467  1.598932e+12   1.577855e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 41326    224516          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41330    224524          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41402    228709          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41434    228743          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41445    228755          387  1.554090e+12   1.553719e+12     NaN       NaN
#
#                                               name_point  \
# 1762   333 Lenox Road Penthouse Boiler Room Loop Hot ...
# 2680   3400 Fort Independence Street Boiler 1 Domesti...
# 2692   3400 Fort Independence Boiler 1 Hot Water Coil...
# 2694   3400 Fort Independence Boiler 1 Domestic Hot W...
# 5337     1710 Avenue H Boiler Hot Water Coil Temperature
# ...                                                  ...
# 41326                                                NaN
# 41330                                                NaN
# 41402                                                NaN
# 41434                                                NaN
# 41445                                                NaN
#
#                                              description units tagged_units  \
# 1762                                                 NaN     F            f
# 2680                                                 NaN     F            f
# 2692   3400 Fort Independence Boiler 1 Hot Water Coil...     F            f
# 2694   3400 Fort Independence Boiler 1 Domestic Hot W...     F            f
# 5337                                                 NaN   NaN            f
# ...                                                  ...   ...          ...
# 41326  905 Palmer Avenue Boiler Domestic Hot Water Te...     F          NaN
# 41330  905 Palmer Avenue Boiler Hot Water Supply Temp...     F          NaN
# 41402                  Boiler 1_Heating HW Temp: Leaving     F          NaN
# 41434                  Boiler 2_Heating HW Temp: Leaving     F          NaN
# 41445                  Boiler 3_Heating HW Temp: Leaving     F          NaN
#
#        ...  measurement_id                   datasource_hash  \
# 1762   ...               1  dfa7626aee100ae9acda1c02945dbbb0
# 2680   ...               1  00d06c2f2495c313183aba4e8ce8d631
# 2692   ...               1  de9e1289a32848b7f355d23b7a4b203e
# 2694   ...               1  3bc0432ee68b75a591b9da0b3e90e56f
# 5337   ...               1  6f361bf39291c77db8a67475547c6117
# ...    ...             ...                               ...
# 41326  ...               1  639e7bc2379b32d82dda43ad93887de0
# 41330  ...               1  c8474b7eecc39ce25d25dabe13d4a8ae
# 41402  ...               1  a27c23a6b13be8ffe04765f3ebc1c452
# 41434  ...               1  52c3c9de85d52fc51418ad1691e83696
# 41445  ...               1  ec43ca98a08f1c706391091f6b29516e
#
#                                                    topic  equip_id  id_bdg  \
# 1762   nyserda+0000129666+hotWaterBoiler-1+333 Lenox ...     28499     434
# 2680   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 2692   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 2694   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 5337   nyserda+0000139252+boiler-1+1710 Avenue H Boil...     31243     467
# ...                                                  ...       ...     ...
# 41326  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41330  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41402  nyserda+0000096580+boiler1+Boiler 1_Heating HW...     22511     387
# 41434  nyserda+0000096580+boiler2+Boiler 2_Heating HW...     22513     387
# 41445  nyserda+0000096580+boiler3+Boiler 3_Heating HW...     22514     387
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 1762    129666             BLR           Boiler               NaN
# 2680     97789             BLR           Boiler               NaN
# 2692     97789             BLR           Boiler               NaN
# 2694     97789             BLR           Boiler               NaN
# 5337    139252             BLR           Boiler               NaN
# ...        ...             ...              ...               ...
# 41326   129887             BLR           Boiler               NaN
# 41330   129887             BLR           Boiler               NaN
# 41402    96580             BLR           Boiler               NaN
# 41434    96580             BLR           Boiler               NaN
# 41445    96580             BLR           Boiler               NaN
#
#                                        tags
# 1762   ['boiler', 'hvac', 'hotWaterBoiler']
# 2680                     ['boiler', 'hvac']
# 2692                     ['boiler', 'hvac']
# 2694                     ['boiler', 'hvac']
# 5337                     ['boiler', 'hvac']
# ...                                     ...
# 41326                    ['boiler', 'hvac']
# 41330                    ['boiler', 'hvac']
# 41402                    ['boiler', 'hvac']
# 41434                    ['boiler', 'hvac']
# 41445                    ['boiler', 'hvac']
#
# [73 rows x 24 columns]

# %%
boiler_hhwr = boiler_hhwr_data[(boiler_hhwr_data['equip_id'].isin(boiler_equip["equip_id"]))]
boiler_hhwr
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1763     306128          434  1.609476e+12   1.582827e+12     NaN       NaN
# 2683     284531          375  1.596824e+12   1.585336e+12     NaN       NaN
# 5345     356058          467  1.598932e+12   1.577855e+12     NaN       NaN
# 7280     356098          468  1.598932e+12   1.587137e+12     NaN       NaN
# 10391    356123          469  1.598933e+12   1.589308e+12     NaN       NaN
# 11299    344411          461  1.598932e+12   1.577855e+12     NaN       NaN
# 12028    358998          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12033    359003          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12038    359008          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12310    356020          466  1.598934e+12   1.585111e+12     NaN       NaN
# 22430    194189          111  1.546996e+12   1.533009e+12     NaN       NaN
# 22673    343363          451  1.592598e+12   1.577855e+12     NaN       NaN
# 26107    199149          153  1.575764e+12   1.567310e+12     NaN       NaN
# 26109    199152          153  1.575764e+12   1.567310e+12     NaN       NaN
# 26548    344573          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26552    344583          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26559    344590          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26566    344597          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26573    344604          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26580    344611          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26587    344618          465  1.574203e+12   1.548997e+12     NaN       NaN
# 27436    198654          145  1.577854e+12   1.567310e+12     NaN       NaN
# 30112    201535          181  1.539696e+12   1.533095e+12     NaN       NaN
# 30113    201533          181  1.539696e+12   1.533095e+12     NaN       NaN
# 30120    201532          181  1.539696e+12   1.533095e+12     NaN       NaN
# 31216    414613          180  1.598918e+12   1.598918e+12     NaN       NaN
# 31224    201419          180  1.577854e+12   1.556683e+12     NaN       NaN
# 32254    206338          232  1.598932e+12   1.541044e+12     NaN       NaN
# 32682    209221          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32702    209233          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32708    209245          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32722    209257          259  1.535774e+12   1.517995e+12     NaN       NaN
# 34318    212165          278  1.577854e+12   1.567310e+12     NaN       NaN
# 34321    212162          278  1.577854e+12   1.567310e+12     NaN       NaN
# 36004    215184          298  1.577854e+12   1.567310e+12     NaN       NaN
# 36023    215694          301  1.553918e+12   1.538280e+12     NaN       NaN
# 36028    215698          301  1.553918e+12   1.538280e+12     NaN       NaN
# 36032    215702          301  1.553918e+12   1.538280e+12     NaN       NaN
# 38715    222745          354  1.535774e+12   1.519675e+12     NaN       NaN
# 41313    224520          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41315    224519          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41317    224518          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41318    224513          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41399    228708          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41437    228742          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41446    228754          387  1.554090e+12   1.553719e+12     NaN       NaN
#
#                                               name_point  \
# 1763   333 Lenox Road Penthouse Boiler Room Loop Hot ...
# 2683   3400 Fort Independence Street Boiler 1 Condens...
# 5345   1710 Avenue H Boiler Condensate Return Tempera...
# 7280   51 Cross Street Boiler Condensate Return Tempe...
# 10391  9-11 Greenridge Avenue Boiler Condensate Retur...
# 11299  105 E 29th Street Boiler Condensate Return Tem...
# 12028  MHS.Boiler 1_Boiler Hot Water Return Temperatu...
# 12033  MHS.Boiler 2_Boiler Hot Water Return Temperatu...
# 12038  MHS.Boiler 3_Boiler Hot Water Return Temperatu...
# 12310  45-26 44th Street Boiler Condensate Return Tem...
# 22430                                                NaN
# 22673  70 Prospect Park SW Boiler Condensate Return T...
# 26107                                                NaN
# 26109                                                NaN
# 26548          CB-29-1 (HWS - Boilers Loop)_B1.InletTemp
# 26552          CB-29-2 (HWS - Boilers Loop)_B2.InletTemp
# 26559          CB-29-3 (HWS - Boilers Loop)_B3.InletTemp
# 26566          CB-29-4 (HWS - Boilers Loop)_B4.InletTemp
# 26573          CB-29-5 (HWS - Boilers Loop)_B5.InletTemp
# 26580          CB-29-6 (HWS - Boilers Loop)_B6.InletTemp
# 26587          CB-29-7 (HWS - Boilers Loop)_B7.InletTemp
# 27436                                                NaN
# 30112                                                NaN
# 30113                                                NaN
# 30120                                                NaN
# 31216  304 St Johns Place Boiler Hot Water Return Tem...
# 31224   304 St Johns Boiler Hot Water Return Temperature
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...
# 32682                                                NaN
# 32702                                                NaN
# 32708                                                NaN
# 32722                                                NaN
# 34318                                                NaN
# 34321                                                NaN
# 36004                                                NaN
# 36023                                                NaN
# 36028                                                NaN
# 36032                                                NaN
# 38715                                                NaN
# 41313                                                NaN
# 41315                                                NaN
# 41317                                                NaN
# 41318                                                NaN
# 41399                                                NaN
# 41437                                                NaN
# 41446                                                NaN
#
#                                              description units tagged_units  \
# 1763                                                 NaN     F            f
# 2683                                                 NaN     F            f
# 5345                                                 NaN   NaN            f
# 7280                                                 NaN   NaN            f
# 10391                                                NaN   NaN            f
# 11299                                                NaN     F            f
# 12028                                                NaN   NaN            f
# 12033                                                NaN   NaN            f
# 12038                                                NaN   NaN            f
# 12310                                                NaN   NaN            f
# 22430  237 W 100th St Boiler Condensate Return Temper...     F          NaN
# 22673                                                NaN     F            f
# 26107  1898 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 26109  1898 Belmont Avenue Boiler Building Hot Water ...     F          NaN
# 26548                                                NaN   NaN            f
# 26552                                                NaN   NaN            f
# 26559                                                NaN   NaN            f
# 26566                                                NaN   NaN            f
# 26573                                                NaN   NaN            f
# 26580                                                NaN   NaN            f
# 26587                                                NaN   NaN            f
# 27436  1908 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 30112  220 East 54th St. Manhattan Boiler Plant Domes...     F          NaN
# 30113  220 East 54th St. Manhattan Boiler Plant Conde...     F          NaN
# 30120  220 East 54th St. Manhattan Boiler Plant Conde...     F          NaN
# 31216                                                NaN   NaN            f
# 31224   304 St Johns Boiler Hot Water Return Temperature     F            f
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...     F            f
# 32682                 Boiler 1_Heating HW Temp: Entering     F          NaN
# 32702                 Boiler 2_Heating HW Temp: Entering     F          NaN
# 32708                 Boiler 3_Heating HW Temp: Entering     F          NaN
# 32722                 Boiler 4_Heating HW Temp: Entering     F          NaN
# 34318  1871 7th Avenue Boiler Building Hot Water Retu...     F          NaN
# 34321  1871 7th Avenue Boiler Boiler Hot Water Return...     F          NaN
# 36004  1900 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 36023        Roosevelt Landings eBX Tecogen 1 Inlet Temp     F          NaN
# 36028        Roosevelt Landings eBX Tecogen 2 Inlet Temp     F          NaN
# 36032        Roosevelt Landings eBX Tecogen 3 Inlet Temp     F          NaN
# 38715                       Steam Plant_Dist Return Temp     F          NaN
# 41313  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41315  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41317  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41318  905 Palmer Avenue Boiler Boiler Hot Water Retu...     F          NaN
# 41399                 Boiler 1_Heating HW Temp: Entering     F          NaN
# 41437                 Boiler 2_Heating HW Temp: Entering     F          NaN
# 41446                 Boiler 3_Heating HW Temp: Entering     F          NaN
#
#        ...  measurement_id                   datasource_hash  \
# 1763   ...               1  ee20afeb46f331d9b372ce27539df980
# 2683   ...               1  19ce83ab5a6ffd87e39b3976e03beb8f
# 5345   ...               1  9b9bcb429a4da328cb7366150084b068
# 7280   ...               1  1464a6ce6c17f17345ce25af1e98bf1c
# 10391  ...               1  16b953b4ed1e9cd0698bf483137c6d7b
# 11299  ...               1  abcb804f4ed57c71e79fc8d3d13d8892
# 12028  ...               1  2604227047eeaa4a0386e9b43b8ad7b7
# 12033  ...               1  3da7f8a153c337687ddf8f6a9224a4b4
# 12038  ...               1  231ed6924be115d3dccd74fdc79b3889
# 12310  ...               1  0cc763e04e22cc4e1da2dbf784c8e624
# 22430  ...               1  789c0476644d57cf082e0db087a10edf
# 22673  ...               1  266493231e6e65c701670ef427d76e6c
# 26107  ...               1  9590ce9b909f2f0cdc08f163aa121665
# 26109  ...               1  0804cf3f64c3b8ff1f50e9a1bc91c9df
# 26548  ...               1  1a7afbeb9630a91786a017dc2b05ed95
# 26552  ...               1  166d53e1f8be371f015559d0addbedfa
# 26559  ...               1  05a371b989b064d155d43dd50dd14743
# 26566  ...               1  05409b6774c80e406e08155138099228
# 26573  ...               1  119c98455e8419e3751ac6e1be15b83c
# 26580  ...               1  97756ca500a1cfc7880592d176470bb4
# 26587  ...               1  ce84da8221d121efcc30082eaf0ccd62
# 27436  ...               1  a8357abd2cf333583b897309a2085e3e
# 30112  ...               1  38e1eb34ebf1b167f3a964cf0556884e
# 30113  ...               1  5c9660d447e16ee426cf156eb77a6a95
# 30120  ...               1  7f80d7cbb91dc6e65bee7883cce145f7
# 31216  ...               1  eea3332846758f362b69caad6109c50f
# 31224  ...               1  9ff53b5835aa326d51d5473c4b95826f
# 32254  ...               1  27785ba499ee882d04cedec3e6b0afab
# 32682  ...               1  d767061b5385702216b67abfa16d0a3f
# 32702  ...               1  8a6ac1ce808bf996ce0bc4227e7e02c7
# 32708  ...               1  89ac0473385e8db6a6f922b0dcd818c7
# 32722  ...               1  409bf6ca4f82363d1dbffd621c1fc993
# 34318  ...               1  fba2b4f184799618c4e291309258e4f0
# 34321  ...               1  fda775415472f1f843b3915ccc45f9b5
# 36004  ...               1  a6b008d1c89ff24f626ed749406ed0db
# 36023  ...               1  d164e4e6da3636df651e557f138fcef4
# 36028  ...               1  34a190bd4e7ce6d7169212cfd8f6c71e
# 36032  ...               1  3cf770b406fc3770842c1e2e4f3ea41e
# 38715  ...               1  723e2ff27ad108da07554cd4e980ccf0
# 41313  ...               1  1767d978fce23302bb41ac88f04d1b60
# 41315  ...               1  9232f19a49e7a610ad900267d1cee5b5
# 41317  ...               1  346900660de2422a27b5316dbe721ce7
# 41318  ...               1  506a120ff0d6551a82aa9f3430f9d3f2
# 41399  ...               1  588f3b866280ca9da1ab70f3e835a427
# 41437  ...               1  c14b8391c74952aa465784ec38105b47
# 41446  ...               1  d6dfed4a31a023b0dd664c3885452988
#
#                                                    topic  equip_id  id_bdg  \
# 1763   nyserda+0000129666+hotWaterBoiler-1+333 Lenox ...     28499     434
# 2683   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 5345   nyserda+0000139252+boiler-1+1710 Avenue H Boil...     31243     467
# 7280   nyserda+0000159109+boiler-1+51 Cross Street Bo...     31245     468
# 10391  nyserda+0000144601+boiler-1+9-11 Greenridge Av...     31246     469
# 11299  nyserda+0000137940+boiler-1+105 E 29th Street ...     30465     461
# 12028  nyserda+0000163716+boiler-1+MHS.Boiler 1_Boile...     31871     479
# 12033  nyserda+0000163716+boiler-2+MHS.Boiler 2_Boile...     31872     479
# 12038  nyserda+0000163716+boiler-3+MHS.Boiler 3_Boile...     31873     479
# 12310  nyserda+0000137257+boiler-1+45-26 44th Street ...     31241     466
# 22430  nyserda+0000089522+boiler1+237 W 100th St Boil...     17367     111
# 22673  nyserda+0000137244+boiler-1+70 Prospect Park S...     30303     451
# 26107  nyserda+0000125921+boiler+1898 Belmont Avenue ...     18243     153
# 26109  nyserda+0000125921+boiler+1898 Belmont Avenue ...     18243     153
# 26548  nyserda+00000123771+boiler1+CB-29-1 (HWS - Boi...     30500     465
# 26552  nyserda+00000123771+boiler2+CB-29-2 (HWS - Boi...     30501     465
# 26559  nyserda+00000123771+boiler3+CB-29-3 (HWS - Boi...     30502     465
# 26566  nyserda+00000123771+boiler4+CB-29-4 (HWS - Boi...     30503     465
# 26573  nyserda+00000123771+boiler5+CB-29-5 (HWS - Boi...     30504     465
# 26580  nyserda+00000123771+boiler6+CB-29-6 (HWS - Boi...     30505     465
# 26587  nyserda+00000123771+boiler7+CB-29-7 (HWS - Boi...     30506     465
# 27436  nyserda+0000125854+boiler+1908 Belmont Avenue ...     18165     145
# 30112  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 30113  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 30120  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 31216  nyserda+0000112065+boiler-1+304 St Johns Place...     34987     180
# 31224  nyserda+0000112065+boiler+304 St Johns Boiler ...     34987     180
# 32254  nyserda+0000099291+boiler+100 Lawn Terrace Boi...     33923     232
# 32682  nyserda+0000082294+boiler1+Boiler 1_Heating HW...     19850     259
# 32702  nyserda+0000082294+boiler2+Boiler 2_Heating HW...     19851     259
# 32708  nyserda+0000082294+boiler3+Boiler 3_Heating HW...     19852     259
# 32722  nyserda+0000082294+boiler4+Boiler 4_Heating HW...     19853     259
# 34318  nyserda+0000125541+boiler+1871 7th Avenue Boil...     20245     278
# 34321  nyserda+0000125541+boiler+1871 7th Avenue Boil...     20245     278
# 36004  nyserda+0000125920+boiler+1900 Belmont Avenue ...     20519     298
# 36023  nyserda+0000099466+boiler-hotWaterPlant1+Roose...     20686     301
# 36028  nyserda+0000099466+boiler-hotWaterPlant2+Roose...     20687     301
# 36032  nyserda+0000099466+boiler-hotWaterPlant3+Roose...     20688     301
# 38715  nyserda+0000082140+boiler-steamPlant+Steam Pla...     21630     354
# 41313  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41315  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41317  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41318  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41399  nyserda+0000096580+boiler1+Boiler 1_Heating HW...     22511     387
# 41437  nyserda+0000096580+boiler2+Boiler 2_Heating HW...     22513     387
# 41446  nyserda+0000096580+boiler3+Boiler 3_Heating HW...     22514     387
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 1763    129666             BLR           Boiler               NaN
# 2683     97789             BLR           Boiler               NaN
# 5345    139252             BLR           Boiler               NaN
# 7280    159109             BLR           Boiler               NaN
# 10391   144601             BLR           Boiler               NaN
# 11299   137940             BLR           Boiler               NaN
# 12028   163716             BLR           Boiler               NaN
# 12033   163716             BLR           Boiler               NaN
# 12038   163716             BLR           Boiler               NaN
# 12310   137257             BLR           Boiler               NaN
# 22430    89522             BLR           Boiler               NaN
# 22673   137244             BLR           Boiler               NaN
# 26107   125921             BLR           Boiler               NaN
# 26109   125921             BLR           Boiler               NaN
# 26548   123771             BLR           Boiler               NaN
# 26552   123771             BLR           Boiler               NaN
# 26559   123771             BLR           Boiler               NaN
# 26566   123771             BLR           Boiler               NaN
# 26573   123771             BLR           Boiler               NaN
# 26580   123771             BLR           Boiler               NaN
# 26587   123771             BLR           Boiler               NaN
# 27436   125854             BLR           Boiler               NaN
# 30112    90423             BLR           Boiler               NaN
# 30113    90423             BLR           Boiler               NaN
# 30120    90423             BLR           Boiler               NaN
# 31216   112065             BLR           Boiler               NaN
# 31224   112065             BLR           Boiler               NaN
# 32254    99291             BLR           Boiler               NaN
# 32682    82294             BLR           Boiler               NaN
# 32702    82294             BLR           Boiler               NaN
# 32708    82294             BLR           Boiler               NaN
# 32722    82294             BLR           Boiler               NaN
# 34318   125541             BLR           Boiler               NaN
# 34321   125541             BLR           Boiler               NaN
# 36004   125920             BLR           Boiler               NaN
# 36023    99466             BLR           Boiler               NaN
# 36028    99466             BLR           Boiler               NaN
# 36032    99466             BLR           Boiler               NaN
# 38715    82140             BLR           Boiler               NaN
# 41313   129887             BLR           Boiler               NaN
# 41315   129887             BLR           Boiler               NaN
# 41317   129887             BLR           Boiler               NaN
# 41318   129887             BLR           Boiler               NaN
# 41399    96580             BLR           Boiler               NaN
# 41437    96580             BLR           Boiler               NaN
# 41446    96580             BLR           Boiler               NaN
#
#                                        tags
# 1763   ['boiler', 'hvac', 'hotWaterBoiler']
# 2683                     ['boiler', 'hvac']
# 5345                     ['boiler', 'hvac']
# 7280                     ['boiler', 'hvac']
# 10391                    ['boiler', 'hvac']
# 11299                    ['boiler', 'hvac']
# 12028                    ['boiler', 'hvac']
# 12033                    ['boiler', 'hvac']
# 12038                    ['boiler', 'hvac']
# 12310                    ['boiler', 'hvac']
# 22430                    ['boiler', 'hvac']
# 22673                    ['boiler', 'hvac']
# 26107                    ['boiler', 'hvac']
# 26109                    ['boiler', 'hvac']
# 26548                    ['boiler', 'hvac']
# 26552                    ['boiler', 'hvac']
# 26559                    ['boiler', 'hvac']
# 26566                    ['boiler', 'hvac']
# 26573                    ['boiler', 'hvac']
# 26580                    ['boiler', 'hvac']
# 26587                    ['boiler', 'hvac']
# 27436                    ['boiler', 'hvac']
# 30112                    ['boiler', 'hvac']
# 30113                    ['boiler', 'hvac']
# 30120                    ['boiler', 'hvac']
# 31216  ['boiler', 'hvac', 'hotWaterBoiler']
# 31224  ['boiler', 'hvac', 'hotWaterBoiler']
# 32254                    ['boiler', 'hvac']
# 32682                    ['boiler', 'hvac']
# 32702                    ['boiler', 'hvac']
# 32708                    ['boiler', 'hvac']
# 32722                    ['boiler', 'hvac']
# 34318                    ['boiler', 'hvac']
# 34321                    ['boiler', 'hvac']
# 36004                    ['boiler', 'hvac']
# 36023  ['boiler', 'hvac', 'hotWaterBoiler']
# 36028  ['boiler', 'hvac', 'hotWaterBoiler']
# 36032  ['boiler', 'hvac', 'hotWaterBoiler']
# 38715     ['boiler', 'hvac', 'steamBoiler']
# 41313                    ['boiler', 'hvac']
# 41315                    ['boiler', 'hvac']
# 41317                    ['boiler', 'hvac']
# 41318                    ['boiler', 'hvac']
# 41399                    ['boiler', 'hvac']
# 41437                    ['boiler', 'hvac']
# 41446                    ['boiler', 'hvac']
#
# [46 rows x 24 columns]

# %%
boiler_hhws = boiler_hhws[(boiler_hhws.name_point.str.contains('Domestic', regex=False) == False)]
boiler_hhws = boiler_hhws[(boiler_hhws.name_point.str.contains('Coil', regex=False) == False)]
boiler_hhws = boiler_hhws[(boiler_hhws.name_point.str.contains('SupTmp', regex=False) == False)]

# %%
boiler_hhws
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1762     306129          434  1.609476e+12   1.582827e+12     NaN       NaN
# 12027    358999          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12032    359004          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12037    359009          479  1.619841e+12   1.604203e+12     NaN       NaN
# 26546    344575          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26550    344585          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26557    344592          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26564    344599          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26571    344606          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26578    344613          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26585    344620          465  1.574203e+12   1.548997e+12     NaN       NaN
# 31214    414615          180  1.598918e+12   1.584691e+12     NaN       NaN
# 31222    201421          180  1.577854e+12   1.556683e+12     NaN       NaN
# 32253    206339          232  1.598932e+12   1.541044e+12     NaN       NaN
#
#                                               name_point  \
# 1762   333 Lenox Road Penthouse Boiler Room Loop Hot ...
# 12027  MHS.Boiler 1_Boiler Hot Water Supply Temperatu...
# 12032  MHS.Boiler 2_Boiler Hot Water Supply Temperatu...
# 12037  MHS.Boiler 3_Boiler Hot Water Supply Temperatu...
# 26546         CB-29-1 (HWS - Boilers Loop)_B1.OutletTemp
# 26550         CB-29-2 (HWS - Boilers Loop)_B2.OutletTemp
# 26557         CB-29-3 (HWS - Boilers Loop)_B3.OutletTemp
# 26564         CB-29-4 (HWS - Boilers Loop)_B4.OutletTemp
# 26571         CB-29-5 (HWS - Boilers Loop)_B5.OutletTemp
# 26578         CB-29-6 (HWS - Boilers Loop)_B6.OutletTemp
# 26585         CB-29-7 (HWS - Boilers Loop)_B7.OutletTemp
# 31214  304 St Johns Place Boiler Hot Water Supply Tem...
# 31222   304 St Johns Boiler Hot Water Supply Temperature
# 32253  100 Lawn Terrace Boiler Hot Water Supply Tempe...
#
#                                              description units tagged_units  \
# 1762                                                 NaN     F            f
# 12027                                                NaN   NaN            f
# 12032                                                NaN   NaN            f
# 12037                                                NaN   NaN            f
# 26546                                                NaN   NaN            f
# 26550                                                NaN   NaN            f
# 26557                                                NaN   NaN            f
# 26564                                                NaN   NaN            f
# 26571                                                NaN   NaN            f
# 26578                                                NaN   NaN            f
# 26585                                                NaN   NaN            f
# 31214                                                NaN   NaN            f
# 31222   304 St Johns Boiler Hot Water Supply Temperature     F            f
# 32253  100 Lawn Terrace Boiler Hot Water Supply Tempe...     F            f
#
#        ...  measurement_id                   datasource_hash  \
# 1762   ...               1  dfa7626aee100ae9acda1c02945dbbb0
# 12027  ...               1  66697f9024dff02bdabb55cc2607939e
# 12032  ...               1  ee5462192d580d6cc93189fc4939216f
# 12037  ...               1  548d6529086bb071998364ed28d9377f
# 26546  ...               1  242da8efd6b616fb8d75e67ffbd72e57
# 26550  ...               1  179d09fce29cedb240f816603d80d2cc
# 26557  ...               1  5b0eceeee6e85af7147a28854c6fe76d
# 26564  ...               1  d0daa96cb3fcb749b3f6832a53702ff7
# 26571  ...               1  fc41fd3db8852fc14127595659de2922
# 26578  ...               1  7641d39c62175155952049f739e230ba
# 26585  ...               1  252dd52b4a4ea92e31a18f7525ba7a7a
# 31214  ...               1  9ece5675c0268db1d8770972d1a0c142
# 31222  ...               1  c521548a5403b5369c961bf768021805
# 32253  ...               1  8c1c9ffaca3f6c449e42be3c64acbbc1
#
#                                                    topic  equip_id  id_bdg  \
# 1762   nyserda+0000129666+hotWaterBoiler-1+333 Lenox ...     28499     434
# 12027  nyserda+0000163716+boiler-1+MHS.Boiler 1_Boile...     31871     479
# 12032  nyserda+0000163716+boiler-2+MHS.Boiler 2_Boile...     31872     479
# 12037  nyserda+0000163716+boiler-3+MHS.Boiler 3_Boile...     31873     479
# 26546  nyserda+00000123771+boiler1+CB-29-1 (HWS - Boi...     30500     465
# 26550  nyserda+00000123771+boiler2+CB-29-2 (HWS - Boi...     30501     465
# 26557  nyserda+00000123771+boiler3+CB-29-3 (HWS - Boi...     30502     465
# 26564  nyserda+00000123771+boiler4+CB-29-4 (HWS - Boi...     30503     465
# 26571  nyserda+00000123771+boiler5+CB-29-5 (HWS - Boi...     30504     465
# 26578  nyserda+00000123771+boiler6+CB-29-6 (HWS - Boi...     30505     465
# 26585  nyserda+00000123771+boiler7+CB-29-7 (HWS - Boi...     30506     465
# 31214  nyserda+0000112065+boiler-1+304 St Johns Place...     34987     180
# 31222  nyserda+0000112065+boiler+304 St Johns Boiler ...     34987     180
# 32253  nyserda+0000099291+boiler+100 Lawn Terrace Boi...     33923     232
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 1762    129666             BLR           Boiler               NaN
# 12027   163716             BLR           Boiler               NaN
# 12032   163716             BLR           Boiler               NaN
# 12037   163716             BLR           Boiler               NaN
# 26546   123771             BLR           Boiler               NaN
# 26550   123771             BLR           Boiler               NaN
# 26557   123771             BLR           Boiler               NaN
# 26564   123771             BLR           Boiler               NaN
# 26571   123771             BLR           Boiler               NaN
# 26578   123771             BLR           Boiler               NaN
# 26585   123771             BLR           Boiler               NaN
# 31214   112065             BLR           Boiler               NaN
# 31222   112065             BLR           Boiler               NaN
# 32253    99291             BLR           Boiler               NaN
#
#                                        tags
# 1762   ['boiler', 'hvac', 'hotWaterBoiler']
# 12027                    ['boiler', 'hvac']
# 12032                    ['boiler', 'hvac']
# 12037                    ['boiler', 'hvac']
# 26546                    ['boiler', 'hvac']
# 26550                    ['boiler', 'hvac']
# 26557                    ['boiler', 'hvac']
# 26564                    ['boiler', 'hvac']
# 26571                    ['boiler', 'hvac']
# 26578                    ['boiler', 'hvac']
# 26585                    ['boiler', 'hvac']
# 31214  ['boiler', 'hvac', 'hotWaterBoiler']
# 31222  ['boiler', 'hvac', 'hotWaterBoiler']
# 32253                    ['boiler', 'hvac']
#
# [14 rows x 24 columns]

# %%
boiler_hhwr = boiler_hhwr[(boiler_hhwr['equip_id'].isin(boiler_hhws["equip_id"]))]
boiler_hhwr = boiler_hhwr[(boiler_hhwr.name_point.str.contains('Condensate', regex=False) == False)]
boiler_hhwr
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1763     306128          434  1.609476e+12   1.582827e+12     NaN       NaN
# 12028    358998          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12033    359003          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12038    359008          479  1.619841e+12   1.604203e+12     NaN       NaN
# 26548    344573          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26552    344583          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26559    344590          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26566    344597          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26573    344604          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26580    344611          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26587    344618          465  1.574203e+12   1.548997e+12     NaN       NaN
# 31216    414613          180  1.598918e+12   1.598918e+12     NaN       NaN
# 31224    201419          180  1.577854e+12   1.556683e+12     NaN       NaN
# 32254    206338          232  1.598932e+12   1.541044e+12     NaN       NaN
#
#                                               name_point  \
# 1763   333 Lenox Road Penthouse Boiler Room Loop Hot ...
# 12028  MHS.Boiler 1_Boiler Hot Water Return Temperatu...
# 12033  MHS.Boiler 2_Boiler Hot Water Return Temperatu...
# 12038  MHS.Boiler 3_Boiler Hot Water Return Temperatu...
# 26548          CB-29-1 (HWS - Boilers Loop)_B1.InletTemp
# 26552          CB-29-2 (HWS - Boilers Loop)_B2.InletTemp
# 26559          CB-29-3 (HWS - Boilers Loop)_B3.InletTemp
# 26566          CB-29-4 (HWS - Boilers Loop)_B4.InletTemp
# 26573          CB-29-5 (HWS - Boilers Loop)_B5.InletTemp
# 26580          CB-29-6 (HWS - Boilers Loop)_B6.InletTemp
# 26587          CB-29-7 (HWS - Boilers Loop)_B7.InletTemp
# 31216  304 St Johns Place Boiler Hot Water Return Tem...
# 31224   304 St Johns Boiler Hot Water Return Temperature
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...
#
#                                              description units tagged_units  \
# 1763                                                 NaN     F            f
# 12028                                                NaN   NaN            f
# 12033                                                NaN   NaN            f
# 12038                                                NaN   NaN            f
# 26548                                                NaN   NaN            f
# 26552                                                NaN   NaN            f
# 26559                                                NaN   NaN            f
# 26566                                                NaN   NaN            f
# 26573                                                NaN   NaN            f
# 26580                                                NaN   NaN            f
# 26587                                                NaN   NaN            f
# 31216                                                NaN   NaN            f
# 31224   304 St Johns Boiler Hot Water Return Temperature     F            f
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...     F            f
#
#        ...  measurement_id                   datasource_hash  \
# 1763   ...               1  ee20afeb46f331d9b372ce27539df980
# 12028  ...               1  2604227047eeaa4a0386e9b43b8ad7b7
# 12033  ...               1  3da7f8a153c337687ddf8f6a9224a4b4
# 12038  ...               1  231ed6924be115d3dccd74fdc79b3889
# 26548  ...               1  1a7afbeb9630a91786a017dc2b05ed95
# 26552  ...               1  166d53e1f8be371f015559d0addbedfa
# 26559  ...               1  05a371b989b064d155d43dd50dd14743
# 26566  ...               1  05409b6774c80e406e08155138099228
# 26573  ...               1  119c98455e8419e3751ac6e1be15b83c
# 26580  ...               1  97756ca500a1cfc7880592d176470bb4
# 26587  ...               1  ce84da8221d121efcc30082eaf0ccd62
# 31216  ...               1  eea3332846758f362b69caad6109c50f
# 31224  ...               1  9ff53b5835aa326d51d5473c4b95826f
# 32254  ...               1  27785ba499ee882d04cedec3e6b0afab
#
#                                                    topic  equip_id  id_bdg  \
# 1763   nyserda+0000129666+hotWaterBoiler-1+333 Lenox ...     28499     434
# 12028  nyserda+0000163716+boiler-1+MHS.Boiler 1_Boile...     31871     479
# 12033  nyserda+0000163716+boiler-2+MHS.Boiler 2_Boile...     31872     479
# 12038  nyserda+0000163716+boiler-3+MHS.Boiler 3_Boile...     31873     479
# 26548  nyserda+00000123771+boiler1+CB-29-1 (HWS - Boi...     30500     465
# 26552  nyserda+00000123771+boiler2+CB-29-2 (HWS - Boi...     30501     465
# 26559  nyserda+00000123771+boiler3+CB-29-3 (HWS - Boi...     30502     465
# 26566  nyserda+00000123771+boiler4+CB-29-4 (HWS - Boi...     30503     465
# 26573  nyserda+00000123771+boiler5+CB-29-5 (HWS - Boi...     30504     465
# 26580  nyserda+00000123771+boiler6+CB-29-6 (HWS - Boi...     30505     465
# 26587  nyserda+00000123771+boiler7+CB-29-7 (HWS - Boi...     30506     465
# 31216  nyserda+0000112065+boiler-1+304 St Johns Place...     34987     180
# 31224  nyserda+0000112065+boiler+304 St Johns Boiler ...     34987     180
# 32254  nyserda+0000099291+boiler+100 Lawn Terrace Boi...     33923     232
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 1763    129666             BLR           Boiler               NaN
# 12028   163716             BLR           Boiler               NaN
# 12033   163716             BLR           Boiler               NaN
# 12038   163716             BLR           Boiler               NaN
# 26548   123771             BLR           Boiler               NaN
# 26552   123771             BLR           Boiler               NaN
# 26559   123771             BLR           Boiler               NaN
# 26566   123771             BLR           Boiler               NaN
# 26573   123771             BLR           Boiler               NaN
# 26580   123771             BLR           Boiler               NaN
# 26587   123771             BLR           Boiler               NaN
# 31216   112065             BLR           Boiler               NaN
# 31224   112065             BLR           Boiler               NaN
# 32254    99291             BLR           Boiler               NaN
#
#                                        tags
# 1763   ['boiler', 'hvac', 'hotWaterBoiler']
# 12028                    ['boiler', 'hvac']
# 12033                    ['boiler', 'hvac']
# 12038                    ['boiler', 'hvac']
# 26548                    ['boiler', 'hvac']
# 26552                    ['boiler', 'hvac']
# 26559                    ['boiler', 'hvac']
# 26566                    ['boiler', 'hvac']
# 26573                    ['boiler', 'hvac']
# 26580                    ['boiler', 'hvac']
# 26587                    ['boiler', 'hvac']
# 31216  ['boiler', 'hvac', 'hotWaterBoiler']
# 31224  ['boiler', 'hvac', 'hotWaterBoiler']
# 32254                    ['boiler', 'hvac']
#
# [14 rows x 24 columns]

# %% [markdown]
# # Querying time-series: Boiler

# %%
boiler_hhws_points = list(boiler_hhws.id_point)
boiler_hhwr_points = list(boiler_hhwr.id_point)

# %%
boiler_hhws_data.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2018-02-07 09:15:00+0000', tz='UTC')

# %%
boiler_hhws_data.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2021-08-01 03:45:00+0000', tz='UTC')

# %%
# Select your timezone
tz = pytz.timezone('UTC')

# Select your date and time (time is optional)
start = datetime(2018,2,7,0,0,0).replace(tzinfo=tz)
end = datetime(2020,2,7,0,0,0).replace(tzinfo=tz)

print(f"from {start} to {end}")
# Out:
# from 2018-02-07 00:00:00+00:00 to 2020-02-07 00:00:00+00:00

# %%
timeseries_query_boiler_hhws = TimeseriesQuery(point_ids = boiler_hhws_points, start = start, end = end)
timeseries_query_boiler_hhwr = TimeseriesQuery(point_ids = boiler_hhwr_points, start = start, end = end)

# %%
# Exceute query (will return and object)
query_results_boiler_hhws = client.stream_point_timeseries(timeseries_query_boiler_hhws)
query_results_boiler_hhwr = client.stream_point_timeseries(timeseries_query_boiler_hhwr)
# Convert to dataframe
data_boiler_hhws = points_df_from_streaming_timeseries(query_results_boiler_hhws)
data_boiler_hhwr = points_df_from_streaming_timeseries(query_results_boiler_hhwr)

# %%
data_boiler_hhws.to_csv("rtem_boiler_hhws_time_series.csv", index=False)
data_boiler_hhwr.to_csv("rtem_boiler_hhwr_time_series.csv", index=False)

# %%
data_boiler_hhws["timestamp"] = pd.to_datetime(data_boiler_hhws['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')
data_boiler_hhwr["timestamp"] = pd.to_datetime(data_boiler_hhwr['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# This is for the visual stype, I like "ggplot"
plt.style.use('ggplot')

# This for the figure size
plt.rcParams["figure.figsize"] = (20,9)

# %%
# These are the sensors, one per column (first one is the timestamp)
data_boiler_delta_temp = data_boiler_hhws.copy()
# for col in cols:
#     plt.figure()
#     sns.lineplot(data=data_delta_temp, x="timestamp", y=col_s)

# These are the sensors, one per column (first one is the timestamp)
cols_s = data_boiler_hhws.columns[1:]
cols_r = data_boiler_hhwr.columns[1:]

for i in range(0, len(cols_s)):
    plt.figure()
    col_s = cols_s[i]
    col_r = cols_r[i]
    data_boiler_delta_temp[col_s] = data_boiler_hhws[col_s] - data_boiler_hhwr[col_r]
    sns.lineplot(data=data_boiler_delta_temp, x="timestamp", y=col_s)

# %% [markdown]
# # Building Info

# %%
bdgs = client.get_all_buildings()
bdgs_df = pd.DataFrame(bdgs)

# %%
bdgs_with_boilers = bdgs_df[(bdgs_df.id.isin(boiler_hhwr.building_id))]
bdgs_with_boilers
# Out:
#       id  org_id    name address     sq_ft image_src bms_manufacturer  \
# 11   434       5  129666    None   56090.0      None             None
# 49   479       5  163716    None       NaN      None             None
# 105  465       5  123771    None  470000.0      None             None
# 144  180       5  112065    None   12285.0      None             None
# 159  232       5   99291    None   50000.0      None             None
#
#     bms_product_name bms_version          timezone  \
# 11              None        None  America/New_York
# 49              None        None  America/New_York
# 105             None        None  America/New_York
# 144             None        None  America/New_York
# 159             None        None  America/New_York
#
#                                                   info status  equip_count  \
# 11   {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           12
# 49   {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           50
# 105  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           54
# 144  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            4
# 159  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            4
#
#      point_count
# 11           171
# 49           268
# 105          414
# 144           49
# 159           47

# %%
bdgs_df['info'][0]
bdgs
# Out:
# [{'id': 441,
#   'org_id': 5,
#   'name': '88737',
#   'address': None,
#   'sq_ft': 551143,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronx',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 20,
#   'point_count': 1293},
#  {'id': 140,
#   'org_id': 5,
#   'name': '83483',
#   'address': None,
#   'sq_ft': 21869,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 354},
#  {'id': 191,
#   'org_id': 5,
#   'name': '94414',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'Victor',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 19},
#  {'id': 231,
#   'org_id': 5,
#   'name': '89496',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': ''},
#   'status': 'LIVE',
#   'equip_count': 4,
#   'point_count': 51},
#  {'id': 248,
#   'org_id': 5,
#   'name': '116742',
#   'address': None,
#   'sq_ft': 127000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 34},
#  {'id': 249,
#   'org_id': 5,
#   'name': '90366',
#   'address': None,
#   'sq_ft': 120000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 6},
#  {'id': 271,
#   'org_id': 5,
#   'name': '80324',
#   'address': None,
#   'sq_ft': 32240,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00:00',
#    'satend': '23:00:00',
#    'sunend': '23:00:00',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '06:00:00',
#    'satstart': '06:00:00',
#    'sunstart': '06:00:00',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'College/University'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 182},
#  {'id': 285,
#   'org_id': 5,
#   'name': '94400',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'White Plains',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 17},
#  {'id': 297,
#   'org_id': 5,
#   'name': '94412',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'Watertown',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 8,
#   'point_count': 24},
#  {'id': 322,
#   'org_id': 5,
#   'name': '94411',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'New Hartford',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 19},
#  {'id': 317,
#   'org_id': 5,
#   'name': '128286',
#   'address': None,
#   'sq_ft': 35000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 38},
#  {'id': 434,
#   'org_id': 5,
#   'name': '129666',
#   'address': None,
#   'sq_ft': 56090,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 12,
#   'point_count': 171},
#  {'id': 419,
#   'org_id': 5,
#   'name': '116399',
#   'address': None,
#   'sq_ft': 130000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'College/University'},
#   'status': 'LIVE',
#   'equip_count': 32,
#   'point_count': 354},
#  {'id': 375,
#   'org_id': 5,
#   'name': '97789',
#   'address': None,
#   'sq_ft': 232808,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'BRONX',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 4,
#   'point_count': 159},
#  {'id': 470,
#   'org_id': 5,
#   'name': '164423',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 205,
#   'point_count': 1140},
#  {'id': 426,
#   'org_id': 5,
#   'name': '76513',
#   'address': None,
#   'sq_ft': 80000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 92,
#   'point_count': 959},
#  {'id': 423,
#   'org_id': 5,
#   'name': '124540',
#   'address': None,
#   'sq_ft': 119710,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Queens',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 139,
#   'point_count': 463},
#  {'id': 439,
#   'org_id': 5,
#   'name': '87722',
#   'address': None,
#   'sq_ft': 3000000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'NYC',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 1,
#   'point_count': 1},
#  {'id': 314,
#   'org_id': 5,
#   'name': '114460',
#   'address': None,
#   'sq_ft': 100000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 51},
#  {'id': 467,
#   'org_id': 5,
#   'name': '139252',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 41},
#  {'id': 455,
#   'org_id': 5,
#   'name': '164994',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Chemicals'},
#   'status': 'LIVE',
#   'equip_count': 30,
#   'point_count': 195},
#  {'id': 105,
#   'org_id': 5,
#   'name': '79789',
#   'address': None,
#   'sq_ft': 56000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Kingston',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Food/Beverage'},
#   'status': 'LIVE',
#   'equip_count': 14,
#   'point_count': 34},
#  {'id': 107,
#   'org_id': 5,
#   'name': '84869',
#   'address': None,
#   'sq_ft': 50000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'geoCity': 'New York',
#    'geoState': 'NY',
#    'geoCountry': 'US',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 42,
#   'point_count': 44},
#  {'id': 488,
#   'org_id': 5,
#   'name': '152000',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 39,
#   'point_count': 107},
#  {'id': 445,
#   'org_id': 5,
#   'name': '145732',
#   'address': None,
#   'sq_ft': 33220,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 36},
#  {'id': 417,
#   'org_id': 5,
#   'name': '78797',
#   'address': None,
#   'sq_ft': 1898155,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 45,
#   'point_count': 599},
#  {'id': 460,
#   'org_id': 5,
#   'name': '153255',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Flushing',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 2},
#  {'id': 472,
#   'org_id': 5,
#   'name': '130262',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Corning',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'College/University'},
#   'status': 'LIVE',
#   'equip_count': 14,
#   'point_count': 101},
#  {'id': 442,
#   'org_id': 5,
#   'name': '150388',
#   'address': None,
#   'sq_ft': 205000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Rye',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 26,
#   'point_count': 69},
#  {'id': 118,
#   'org_id': 5,
#   'name': '73107',
#   'address': None,
#   'sq_ft': 275000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 122,
#   'point_count': 258},
#  {'id': 477,
#   'org_id': 5,
#   'name': '159950',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 27,
#   'point_count': 331},
#  {'id': 443,
#   'org_id': 5,
#   'name': '149911',
#   'address': None,
#   'sq_ft': 600000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'College/University'},
#   'status': 'LIVE',
#   'equip_count': 10,
#   'point_count': 119},
#  {'id': 468,
#   'org_id': 5,
#   'name': '159109',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronxville',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 1,
#   'point_count': 24},
#  {'id': 438,
#   'org_id': 5,
#   'name': '116350',
#   'address': None,
#   'sq_ft': 1500000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 221,
#   'point_count': 1111},
#  {'id': 478,
#   'org_id': 5,
#   'name': '160783',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Rochester',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'K-12 School'},
#   'status': 'LIVE',
#   'equip_count': 48,
#   'point_count': 308},
#  {'id': 395,
#   'org_id': 5,
#   'name': '85481',
#   'address': None,
#   'sq_ft': 171129,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 86},
#  {'id': 485,
#   'org_id': 5,
#   'name': '133932',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 20,
#   'point_count': 53},
#  {'id': 418,
#   'org_id': 5,
#   'name': '110897',
#   'address': None,
#   'sq_ft': 2800000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {},
#   'status': 'LIVE',
#   'equip_count': 393,
#   'point_count': 586},
#  {'id': 450,
#   'org_id': 5,
#   'name': '131034',
#   'address': None,
#   'sq_ft': 665000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 19,
#   'point_count': 329},
#  {'id': 473,
#   'org_id': 5,
#   'name': '164864',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Warsaw',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'K-12 School'},
#   'status': 'LIVE',
#   'equip_count': 15,
#   'point_count': 106},
#  {'id': 230,
#   'org_id': 5,
#   'name': '111479',
#   'address': None,
#   'sq_ft': 1040873,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 91,
#   'point_count': 188},
#  {'id': 127,
#   'org_id': 5,
#   'name': '89089',
#   'address': None,
#   'sq_ft': 789079,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Flushing',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 11,
#   'point_count': 319},
#  {'id': 469,
#   'org_id': 5,
#   'name': '144601',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'White Plains',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 33},
#  {'id': 100,
#   'org_id': 5,
#   'name': '116723',
#   'address': None,
#   'sq_ft': 153750,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 8},
#  {'id': 452,
#   'org_id': 5,
#   'name': '128615',
#   'address': None,
#   'sq_ft': 1028336,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 189,
#   'point_count': 867},
#  {'id': 461,
#   'org_id': 5,
#   'name': '137940',
#   'address': None,
#   'sq_ft': 47092,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 38},
#  {'id': 489,
#   'org_id': 5,
#   'name': '163896',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 85,
#   'point_count': 113},
#  {'id': 99,
#   'org_id': 5,
#   'name': '113413',
#   'address': None,
#   'sq_ft': 869066,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 126,
#   'point_count': 262},
#  {'id': 98,
#   'org_id': 5,
#   'name': '68855',
#   'address': None,
#   'sq_ft': 2338000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '54',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '1973',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 38,
#   'point_count': 132},
#  {'id': 479,
#   'org_id': 5,
#   'name': '163716',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Pittsford',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'K-12 School'},
#   'status': 'LIVE',
#   'equip_count': 50,
#   'point_count': 268},
#  {'id': 474,
#   'org_id': 5,
#   'name': '164033',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'lewiston',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 22,
#   'point_count': 197},
#  {'id': 466,
#   'org_id': 5,
#   'name': '137257',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Long Island City',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 38},
#  {'id': 134,
#   'org_id': 5,
#   'name': '112620',
#   'address': None,
#   'sq_ft': 12000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 129,
#   'point_count': 264},
#  {'id': 131,
#   'org_id': 5,
#   'name': '128313',
#   'address': None,
#   'sq_ft': 205000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 4},
#  {'id': 130,
#   'org_id': 5,
#   'name': '104698',
#   'address': None,
#   'sq_ft': 145000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'K-12 School'},
#   'status': 'LIVE',
#   'equip_count': 16,
#   'point_count': 181},
#  {'id': 420,
#   'org_id': 5,
#   'name': '87261',
#   'address': None,
#   'sq_ft': 236000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 342,
#   'point_count': 6068},
#  {'id': 136,
#   'org_id': 5,
#   'name': '99315',
#   'address': None,
#   'sq_ft': 274096,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronx',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 26},
#  {'id': 475,
#   'org_id': 5,
#   'name': '158818',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Canandaigua',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'College/University'},
#   'status': 'LIVE',
#   'equip_count': 16,
#   'point_count': 145},
#  {'id': 373,
#   'org_id': 5,
#   'name': '96938',
#   'address': None,
#   'sq_ft': 127577,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 10},
#  {'id': 176,
#   'org_id': 5,
#   'name': '90367',
#   'address': None,
#   'sq_ft': 150000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 7},
#  {'id': 217,
#   'org_id': 5,
#   'name': '130079',
#   'address': None,
#   'sq_ft': 229154,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 23},
#  {'id': 490,
#   'org_id': 5,
#   'name': '124556',
#   'address': None,
#   'sq_ft': 782298,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 1,
#   'point_count': 73},
#  {'id': 103,
#   'org_id': 5,
#   'name': '75216',
#   'address': None,
#   'sq_ft': 563391,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '37',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '1969',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 16,
#   'point_count': 37},
#  {'id': 421,
#   'org_id': 5,
#   'name': '108774',
#   'address': None,
#   'sq_ft': 7960,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 30},
#  {'id': 476,
#   'org_id': 5,
#   'name': '122677',
#   'address': None,
#   'sq_ft': 110000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Woodside',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 3},
#  {'id': 142,
#   'org_id': 5,
#   'name': '82119',
#   'address': None,
#   'sq_ft': 2400000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 12,
#   'point_count': 42},
#  {'id': 462,
#   'org_id': 5,
#   'name': '144540',
#   'address': None,
#   'sq_ft': 76800,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronx',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 45},
#  {'id': 422,
#   'org_id': 5,
#   'name': '114249',
#   'address': None,
#   'sq_ft': 352360,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronx',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 16,
#   'point_count': 210},
#  {'id': 503,
#   'org_id': 5,
#   'name': '145813',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 35,
#   'point_count': 157},
#  {'id': 385,
#   'org_id': 5,
#   'name': '92344',
#   'address': None,
#   'sq_ft': 180000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 72},
#  {'id': 471,
#   'org_id': 5,
#   'name': '136558',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Rochester',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 43,
#   'point_count': 311},
#  {'id': 143,
#   'org_id': 5,
#   'name': '108998',
#   'address': None,
#   'sq_ft': 16903,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Manhattan',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 1,
#   'point_count': 13},
#  {'id': 454,
#   'org_id': 5,
#   'name': '155776',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 28},
#  {'id': 279,
#   'org_id': 5,
#   'name': '75620',
#   'address': None,
#   'sq_ft': 25000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {},
#   'status': 'LIVE',
#   'equip_count': 12,
#   'point_count': 415},
#  {'id': 108,
#   'org_id': 5,
#   'name': '86328',
#   'address': None,
#   'sq_ft': 43850,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Yonkers',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 96},
#  {'id': 481,
#   'org_id': 5,
#   'name': '124529',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Queens',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 27,
#   'point_count': 285},
#  {'id': 101,
#   'org_id': 5,
#   'name': '75049',
#   'address': None,
#   'sq_ft': 20000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 70,
#   'point_count': 1405},
#  {'id': 491,
#   'org_id': 5,
#   'name': '119313',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 45},
#  {'id': 492,
#   'org_id': 5,
#   'name': '122607',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 43,
#   'point_count': 182},
#  {'id': 111,
#   'org_id': 5,
#   'name': '89522',
#   'address': None,
#   'sq_ft': 13512,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 19},
#  {'id': 109,
#   'org_id': 5,
#   'name': '88776',
#   'address': None,
#   'sq_ft': 357001,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 31,
#   'point_count': 220},
#  {'id': 451,
#   'org_id': 5,
#   'name': '137244',
#   'address': None,
#   'sq_ft': 49428,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 2,
#   'point_count': 38},
#  {'id': 258,
#   'org_id': 5,
#   'name': '123183',
#   'address': None,
#   'sq_ft': 135000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York City',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 66,
#   'point_count': 176},
#  {'id': 112,
#   'org_id': 5,
#   'name': '92894',
#   'address': None,
#   'sq_ft': 210000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 34},
#  {'id': 440,
#   'org_id': 5,
#   'name': '93400',
#   'address': None,
#   'sq_ft': 268000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 18,
#   'point_count': 57},
#  {'id': 483,
#   'org_id': 5,
#   'name': '141633',
#   'address': None,
#   'sq_ft': None,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Flushing',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 28,
#   'point_count': 63},
#  {'id': 113,
#   'org_id': 5,
#   'name': '116888',
# ...
#   'equip_count': 12,
#   'point_count': 49},
#  {'id': 381,
#   'org_id': 5,
#   'name': '117228',
#   'address': None,
#   'sq_ft': 156250,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 8},
#  {'id': 396,
#   'org_id': 5,
#   'name': '91480',
#   'address': None,
#   'sq_ft': 22747,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Brooklyn',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 22,
#   'point_count': 272},
#  {'id': 357,
#   'org_id': 5,
#   'name': '129887',
#   'address': None,
#   'sq_ft': 150000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Mamaroneck',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 6,
#   'point_count': 53},
#  {'id': 386,
#   'org_id': 5,
#   'name': '94421',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'Kingston',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 29},
#  {'id': 387,
#   'org_id': 5,
#   'name': '96580',
#   'address': None,
#   'sq_ft': 259000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '22:00:00',
#    'satend': '19:00:00',
#    'sunend': '19:00:00',
#    'geoCity': 'Delmar',
#    'geoState': 'NY',
#    'm2fstart': '05:00:00',
#    'satstart': '06:30:00',
#    'sunstart': '06:30:00',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Not For Profit'},
#   'status': 'LIVE',
#   'equip_count': 38,
#   'point_count': 713},
#  {'id': 389,
#   'org_id': 5,
#   'name': '68985',
#   'address': None,
#   'sq_ft': 338424,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '00:00',
#    'satend': '00:00',
#    'sunend': '00:00',
#    'geoCity': 'New York',
#    'geoState': 'New York',
#    'm2fstart': '00:00',
#    'satstart': '00:00',
#    'sunstart': '00:00',
#    'yearBuilt': '1979',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 24,
#   'point_count': 384},
#  {'id': 390,
#   'org_id': 5,
#   'name': '114399',
#   'address': None,
#   'sq_ft': 8500,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bedford Hills',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Food/Beverage'},
#   'status': 'LIVE',
#   'equip_count': 5,
#   'point_count': 5},
#  {'id': 391,
#   'org_id': 5,
#   'name': '123698',
#   'address': None,
#   'sq_ft': 350000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Healthcare'},
#   'status': 'LIVE',
#   'equip_count': 35,
#   'point_count': 245},
#  {'id': 392,
#   'org_id': 5,
#   'name': '127525',
#   'address': None,
#   'sq_ft': 399613,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 6,
#   'point_count': 14},
#  {'id': 394,
#   'org_id': 5,
#   'name': '80880',
#   'address': None,
#   'sq_ft': 725000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '18:00:00',
#    'satend': '18:00:00',
#    'sunend': '18:00:00',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '06:00:00',
#    'satstart': '06:00:00',
#    'sunstart': '06:00:00',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 59,
#   'point_count': 386},
#  {'id': 393,
#   'org_id': 5,
#   'name': '145147',
#   'address': None,
#   'sq_ft': 1100000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 5,
#   'point_count': 12},
#  {'id': 384,
#   'org_id': 5,
#   'name': '111478',
#   'address': None,
#   'sq_ft': 1040873,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 84,
#   'point_count': 168},
#  {'id': 123,
#   'org_id': 5,
#   'name': '82176',
#   'address': None,
#   'sq_ft': 330000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '9',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 39,
#   'point_count': 45},
#  {'id': 154,
#   'org_id': 5,
#   'name': '90200',
#   'address': None,
#   'sq_ft': 357297,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 8,
#   'point_count': 26},
#  {'id': 155,
#   'org_id': 5,
#   'name': '108238',
#   'address': None,
#   'sq_ft': 144000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Troy',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 9,
#   'point_count': 24},
#  {'id': 157,
#   'org_id': 5,
#   'name': '79791',
#   'address': None,
#   'sq_ft': 56000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Syracuse',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Food/Beverage'},
#   'status': 'LIVE',
#   'equip_count': 13,
#   'point_count': 35},
#  {'id': 158,
#   'org_id': 5,
#   'name': '114403',
#   'address': None,
#   'sq_ft': 9000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Tarrytown',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Food/Beverage'},
#   'status': 'LIVE',
#   'equip_count': 5,
#   'point_count': 5},
#  {'id': 166,
#   'org_id': 5,
#   'name': '94423',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'Batavia',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 19},
#  {'id': 184,
#   'org_id': 5,
#   'name': '108764',
#   'address': None,
#   'sq_ft': 52782,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Manhattan',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 3,
#   'point_count': 34},
#  {'id': 214,
#   'org_id': 5,
#   'name': '97593',
#   'address': None,
#   'sq_ft': 12000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Multifamily'},
#   'status': 'LIVE',
#   'equip_count': 4,
#   'point_count': 72},
#  {'id': 239,
#   'org_id': 5,
#   'name': '86468',
#   'address': None,
#   'sq_ft': 450000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Bronx',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'K-12 School'},
#   'status': 'LIVE',
#   'equip_count': 11,
#   'point_count': 24},
#  {'id': 260,
#   'org_id': 5,
#   'name': '108227',
#   'address': None,
#   'sq_ft': 144000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Rome',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 8,
#   'point_count': 34},
#  {'id': 316,
#   'org_id': 5,
#   'name': '108232',
#   'address': None,
#   'sq_ft': 144000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'Blasdell',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 36,
#   'point_count': 59},
#  {'id': 353,
#   'org_id': 5,
#   'name': '94413',
#   'address': None,
#   'sq_ft': 198057,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '23:00',
#    'satend': '23:00',
#    'sunend': '23:00',
#    'geoCity': 'Henrietta',
#    'geoState': 'NY',
#    'm2fstart': '07:30',
#    'satstart': '07:30',
#    'sunstart': '07:30',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Retail'},
#   'status': 'LIVE',
#   'equip_count': 7,
#   'point_count': 19},
#  {'id': 370,
#   'org_id': 5,
#   'name': '95457',
#   'address': None,
#   'sq_ft': 421316,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Hospitality'},
#   'status': 'LIVE',
#   'equip_count': 5,
#   'point_count': 22},
#  {'id': 383,
#   'org_id': 5,
#   'name': '79528',
#   'address': None,
#   'sq_ft': 75000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '4',
#    'm2fend': '20:00:00',
#    'geoCity': 'Purchase',
#    'geoState': 'New York',
#    'm2fstart': '04:00:00',
#    'yearBuilt': '1971',
#    'geoCountry': 'US',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 11,
#   'point_count': 362},
#  {'id': 398,
#   'org_id': 5,
#   'name': '109188',
#   'address': None,
#   'sq_ft': 860000,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 67,
#   'point_count': 560},
#  {'id': 399,
#   'org_id': 5,
#   'name': '97151',
#   'address': None,
#   'sq_ft': 140400,
#   'image_src': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'timezone': 'America/New_York',
#   'info': {'floors': '',
#    'm2fend': '',
#    'satend': '',
#    'sunend': '',
#    'geoCity': 'New York',
#    'geoState': 'NY',
#    'm2fstart': '',
#    'satstart': '',
#    'sunstart': '',
#    'yearBuilt': '',
#    'geoCountry': 'US',
#    'weatherRef': '',
#    'customerType': 'Commercial Office'},
#   'status': 'LIVE',
#   'equip_count': 8,
#   'point_count': 23}]

# %%
bdgs_df['city'] = " "

# %%
for i in bdgs_df.index:
    info_dict = bdgs_df['info'][i]
    city_curr = info_dict.get('geoCity')
    bdgs_df['city'][i] = city_curr
bdgs_df
# Out:
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_48308/1271801466.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_df['city'][i] = city_curr
#       id  org_id    name address     sq_ft image_src bms_manufacturer  \
# 0    441       5   88737    None  551143.0      None             None
# 1    140       5   83483    None   21869.0      None             None
# 2    191       5   94414    None  198057.0      None             None
# 3    231       5   89496    None       NaN      None             None
# 4    248       5  116742    None  127000.0      None             None
# ..   ...     ...     ...     ...       ...       ...              ...
# 224  353       5   94413    None  198057.0      None             None
# 225  370       5   95457    None  421316.0      None             None
# 226  383       5   79528    None   75000.0      None             None
# 227  398       5  109188    None  860000.0      None             None
# 228  399       5   97151    None  140400.0      None             None
#
#     bms_product_name bms_version          timezone  \
# 0               None        None  America/New_York
# 1               None        None  America/New_York
# 2               None        None  America/New_York
# 3               None        None  America/New_York
# 4               None        None  America/New_York
# ..               ...         ...               ...
# 224             None        None  America/New_York
# 225             None        None  America/New_York
# 226             None        None  America/New_York
# 227             None        None  America/New_York
# 228             None        None  America/New_York
#
#                                                   info status  equip_count  \
# 0    {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           20
# 1    {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           13
# 2    {'floors': '', 'm2fend': '23:00', 'satend': '2...   LIVE            7
# 3    {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            4
# 4    {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            7
# ..                                                 ...    ...          ...
# 224  {'floors': '', 'm2fend': '23:00', 'satend': '2...   LIVE            7
# 225  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            5
# 226  {'floors': '4', 'm2fend': '20:00:00', 'geoCity...   LIVE           11
# 227  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           67
# 228  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            8
#
#      point_count       city
# 0           1293      Bronx
# 1            354   New York
# 2             19     Victor
# 3             51   New York
# 4             34   New York
# ..           ...        ...
# 224           19  Henrietta
# 225           22   New York
# 226          362   Purchase
# 227          560   New York
# 228           23   New York
#
# [229 rows x 15 columns]

# %%
bdgs_df['county'] = " "

# %%
# using my google api key for geocoder
import geocoder, os
os.environ["GOOGLE_API_KEY"] = "AIzaSyB0cbtOQn4FhnsSMVPtxzewy9u_-3cZx-Y"

# %%
NYC_alias = [None, 'New York', 'NYC', 'New York City']
for i in bdgs_df.index:
    city_name = bdgs_df['city'][i]
    if city_name in NYC_alias:
        city_name = 'Manhattan'
    req = city_name + ', NY'
    res = geocoder.google(req)
    bdgs_df['county'][i] = res.current_result.county
    print(bdgs_df['county'][i])
# Out:
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_48308/552143541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_df['county'][i] = res.current_result.county
# Bronx County
# New York County
# Ontario County
# New York County
# New York County
# New York County
# New York County
# Westchester County
# Jefferson County
# Oneida County
# New York County
# Kings County
# New York County
# Bronx County
# New York County
# New York County
# Queens County
# New York County
# New York County
# Kings County
# Kings County
# Ulster County
# New York County
# New York County
# New York County
# New York County
# Queens County
# Steuben County
# Westchester County
# New York County
# New York County
# New York County
# Westchester County
# New York County
# Monroe County
# New York County
# New York County
# New York County
# New York County
# Wyoming County
# New York County
# Queens County
# Westchester County
# New York County
# New York County
# New York County
# New York County
# Kings County
# New York County
# Monroe County
# Niagara County
# Queens County
# New York County
# Kings County
# New York County
# New York County
# Bronx County
# Ontario County
# New York County
# New York County
# New York County
# Kings County
# New York County
# New York County
# Queens County
# New York County
# Bronx County
# Bronx County
# New York County
# New York County
# Monroe County
# New York County
# New York County
# New York County
# Westchester County
# Queens County
# New York County
# New York County
# New York County
# New York County
# New York County
# Kings County
# New York County
# New York County
# New York County
# Queens County
# New York County
# Bronx County
# Kings County
# New York County
# New York County
# New York County
# New York County
# Orange County
# New York County
# New York County
# Rockland County
# Bronx County
# New York County
# Bronx County
# New York County
# Kings County
# Westchester County
# Bronx County
# New York County
# New York County
# Columbia County
# Queens County
# New York County
# New York County
# Bronx County
# Kings County
# Bronx County
# New York County
# Bronx County
# Niagara County
# New York County
# New York County
# New York County
# Columbia County
# New York County
# Monroe County
# Bronx County
# Onondaga County
# Richmond County
# Queens County
# Erie County
# Monroe County
# New York County
# Monroe County
# Kings County
# Jefferson County
# Dutchess County
# New York County
# Westchester County
# Bronx County
# New York County
# Erie County
# New York County
# Bronx County
# New York County
# Broome County
# Schenectady County
# Montgomery County
# Kings County
# Queens County
# New York County
# Albany County
# Rensselaer County
# Westchester County
# Saratoga County
# Queens County
# Bronx County
# Onondaga County
# Bronx County
# Chemung County
# Oneida County
# Onondaga County
# New York County
# Westchester County
# New York County
# New York County
# Kings County
# Queens County
# Rockland County
# New York County
# Fulton County
# New York County
# Westchester County
# Monroe County
# Queens County
# Erie County
# New York County
# Albany County
# New York County
# Tompkins County
# Saratoga County
# New York County
# Kings County
# Dutchess County
# Bronx County
# New York County
# New York County
# Monroe County
# New York County
# New York County
# New York County
# Bronx County
# New York County
# Westchester County
# Westchester County
# New York County
# Bronx County
# Westchester County
# Onondaga County
# Columbia County
# Monroe County
# Broome County
# New York County
# Saratoga County
# Chemung County
# Kings County
# Kings County
# Westchester County
# Ulster County
# Albany County
# New York County
# Westchester County
# New York County
# New York County
# New York County
# New York County
# New York County
# New York County
# New York County
# Rensselaer County
# Onondaga County
# Westchester County
# Genesee County
# New York County
# New York County
# Bronx County
# Oneida County
# Erie County
# Monroe County
# New York County
# Westchester County
# New York County
# New York County

# %%
bdgs_df['btu_sqft'] = np.nan

# %%
# ASHRAE Climate Zone List
CZ4 = ['Bronx County','Nassau County',
'Queens County','Suffolk County',
'Kings County','New York County',
'Richmond County','Westchester County',]
CZ5 = ['Albany County','Erie County',
'Ontario County','Saratoga County',
'Cayuga County','Genesee County',
'Orange County','Schenectady County',
'Chautauqua County','Greene County',
'Orleans County','Seneca County',
'Chemung County','Livingston County',
'Oswego County','Tioga County',
'Columbia County','Monroe County',
'Putnam County','Washington County',
'Cortland County','Niagara County',
'Rensselaer County','Wayne County',
'Dutchess County','Onondaga County',
'Rockland County','Yates County']
CZ6 = ['Allegany County','Franklin County',
'Montgomery County','Sullivan County',
'Broome County','Fulton County',
'Oneida County','Tompkins County',
'Cattaraugus County','Hamilton County',
'Otsego County','Ulster County',
'Chenango County','Herkimer County',
'Schoharie County','Warren County',
'Clinton County','Jefferson County',
'Schuyler County','Wyoming County',
'Delaware County','Lewis County',
'St. Lawrence County','Essex County',
'Madison County','Steuben County']

# %%
for i in bdgs_df.index:
    c = bdgs_df['county'][i]
    if c in CZ4:
        bdgs_df['btu_sqft'][i] = 45
    elif c in CZ5:
        bdgs_df['btu_sqft'][i] = 55
    elif c in CZ6:
        bdgs_df['btu_sqft'][i] = 60
# Out:
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_48308/1498665086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_df['btu_sqft'][i] = 45
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_48308/1498665086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_df['btu_sqft'][i] = 55
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_48308/1498665086.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_df['btu_sqft'][i] = 60
# 0      45.0
# 1      45.0
# 2      55.0
# 3      45.0
# 4      45.0
#        ...
# 224    55.0
# 225    45.0
# 226    45.0
# 227    45.0
# 228    45.0
# Name: btu_sqft, Length: 229, dtype: float64

# %%
# Pittsford Sutherland High School: building id 479
# Area estimated from Google Map: 165,000 sqft
bdgs_with_boilers.sq_ft[bdgs_with_boilers.id == 479] = 165000
# Out:
# /var/folders/0w/98g43rqs1psflll78k6ctzr00000gn/T/ipykernel_75162/2921849346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdgs_with_boilers.sq_ft[bdgs_with_boilers.id == 479] = 165000
#       id  org_id    name address     sq_ft image_src bms_manufacturer  \
# 11   434       5  129666    None   56090.0      None             None
# 49   479       5  163716    None  165000.0      None             None
# 105  465       5  123771    None  470000.0      None             None
# 144  180       5  112065    None   12285.0      None             None
# 159  232       5   99291    None   50000.0      None             None
#
#     bms_product_name bms_version          timezone  \
# 11              None        None  America/New_York
# 49              None        None  America/New_York
# 105             None        None  America/New_York
# 144             None        None  America/New_York
# 159             None        None  America/New_York
#
#                                                   info status  equip_count  \
# 11   {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           12
# 49   {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           50
# 105  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE           54
# 144  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            4
# 159  {'floors': '', 'm2fend': '', 'satend': '', 'su...   LIVE            4
#
#      point_count
# 11           171
# 49           268
# 105          414
# 144           49
# 159           47

# %% [markdown]
# # Load & filter gas data

# %%
gas_consumption_data = metadata[(metadata.type == "Gas Consumption")]
# drop zero column
gas_consumption_data = gas_consumption_data.loc[(gas_consumption_data['id_point'] != 205066)]
gas_consumption_data = gas_consumption_data.loc[(gas_consumption_data['id_point'] != 227943)]
gas_consumption_data = gas_consumption_data.loc[(gas_consumption_data['id_point'] != 227944)]
gas_consumption_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 6513     320457          442  1.601524e+12   1.594041e+12     NaN       NaN
# 6515     320455          442  1.620928e+12   1.601525e+12     NaN       NaN
# 6518     320458          442  1.606798e+12   1.601525e+12     NaN       NaN
# 25825    358166          110  1.609476e+12   1.601525e+12     NaN       NaN
#
#                                               name_point description   units  \
# 6513   Rye Terrace: 150 Building B Meter-Gas Therms T...         NaN     thm
# 6515   Rye Terrace: 150 Building B Meter-Gas Consumption         NaN     thm
# 6518   Rye Village: 160 Building B Meter-Gas Consumption         NaN     thm
# 25825                 Selfhelp K1 Meter-Gas Therms Total         NaN  Therms
#
#       tagged_units  ...  measurement_id                   datasource_hash  \
# 6513           thm  ...              14  818be0c8b660b5ba234d23f60287fe72
# 6515           thm  ...              14  aa59af505cf45bbfd9815aa5b56e009a
# 6518           thm  ...              14  89545ad3139c7533a173b78a1c70c392
# 25825          NaN  ...              14  b6577b83bd54db529b2bd82fac182e8f
#
#                                                    topic  equip_id  id_bdg  \
# 6513   nyserda+0000150388+gasMeterLoad-150+Rye Terrac...     29558     442
# 6515   nyserda+0000150388+gasMeterLoad-150+Rye Terrac...     29558     442
# 6518   nyserda+0000150388+gasMeterLoad-160+Rye Villag...     29559     442
# 25825  nyserda+0000089088+meter-gas+Selfhelp K1 Meter...     31776     110
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 6513    150388           METER            Meter               NaN
# 6515    150388           METER            Meter               NaN
# 6518    150388           METER            Meter               NaN
# 25825    89088           METER            Meter               NaN
#
#                         tags
# 6513   ['meter', 'gasMeter']
# 6515   ['meter', 'gasMeter']
# 6518   ['meter', 'gasMeter']
# 25825              ['meter']
#
# [4 rows x 24 columns]

# %%
gas_flow_data = metadata[(metadata.type == "Gas Flow")]
#drop percentage measurement
gas_flow_data = gas_flow_data.loc[(gas_flow_data['id_point'] != 194379)]
gas_flow_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 22990    359381          483  1.576990e+12   1.567312e+12     NaN       NaN
# 22993    359384          483  1.576990e+12   1.567312e+12     NaN       NaN
# 22995    359386          483  1.576990e+12   1.567312e+12     NaN       NaN
# 23036    194214          113  1.591761e+12   1.575868e+12     NaN       NaN
# 32360    208552          256  1.598889e+12   1.569428e+12     NaN       NaN
# 32361    208550          256  1.598889e+12   1.569428e+12     NaN       NaN
#
#                                name_point  \
# 22990  ANC Chiller 1 Gas Flow (SCFM) SCFM
# 22993   ANC Chiller 3 Gas Flow (SCFM) CFM
# 22995   ANC Chiller 4 Gas Flow (SCFM) CFM
# 23036                                 NaN
# 32360                                 NaN
# 32361                                 NaN
#
#                                description units tagged_units  ...  \
# 22990                                  NaN   NaN          cfm  ...
# 22993                                  NaN   NaN          cfm  ...
# 22995                                  NaN   NaN          cfm  ...
# 23036                House Gas Meter (cfm)   cfm          NaN  ...
# 32360  B133/B132 Total Boiler Gas Flow CFH   cfm          NaN  ...
# 32361           B133 Plant HP Gas Flow CFH   cfm          NaN  ...
#
#        measurement_id                   datasource_hash  \
# 22990              39  c7c156291d9eca1971f3bf2b5a4c9bc9
# 22993              39  8fe4d291f2c3b26d7f260a9e3e5729a0
# 22995              39  4ff786c357a682555e0ff7ae5bc5a339
# 23036              39  40e441e5bf69d0a7fbb942419d17b3c9
# 32360              39  970d72151b403d500effa57e5b0d5adb
# 32361              39  438cbadb4e3d9611892356025c44f913
#
#                                                    topic  equip_id  id_bdg  \
# 22990  nyserda+0000141633+chiller-1+ANC Chiller 1 Gas...     31956     483
# 22993  nyserda+0000141633+chiller-3+ANC Chiller 3 Gas...     31958     483
# 22995  nyserda+0000141633+chiller-4+ANC Chiller 4 Gas...     31959     483
# 23036  nyserda+0000116888+meter-gas+House Gas Meter (...     17381     113
# 32360  nyserda+0000135785+hotWaterPlant+B133/B132 Tot...     19740     256
# 32361  nyserda+0000135785+hotWaterPlant+B133 Plant HP...     19740     256
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 22990   141633              CH          Chiller               NaN
# 22993   141633              CH          Chiller               NaN
# 22995   141633              CH          Chiller               NaN
# 23036   116888           METER            Meter               NaN
# 32360   135785             HWS  Hot Water Plant               NaN
# 32361   135785             HWS  Hot Water Plant               NaN
#
#                             tags
# 22990        ['chiller', 'hvac']
# 22993        ['chiller', 'hvac']
# 22995        ['chiller', 'hvac']
# 23036      ['meter', 'gasMeter']
# 32360  ['hvac', 'hotWaterPlant']
# 32361  ['hvac', 'hotWaterPlant']
#
# [6 rows x 24 columns]

# %%
heating_plant_flow_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 3868     283201          426  1.606798e+12   1.512104e+12     NaN       NaN
# 4112     283439          426  1.606798e+12   1.512104e+12     NaN       NaN
# 20071    343962          454  1.598933e+12   1.567310e+12     NaN       NaN
# 26372    344702          465  1.574203e+12   1.548997e+12     NaN       NaN
# 32368    208544          256  1.598889e+12   1.569428e+12     NaN       NaN
# 36035    215707          301  1.553918e+12   1.538280e+12     NaN       NaN
#
#                                               name_point  \
# 3868   480 W 42nd St - Signature Theatre DhwPlant DHW...
# 4112    480 W 42nd St - Signature Theatre HwPlant HWFlow
# 20071                                Primary HW Flow GPM
# 26372                         HWS - Boilers Loop_HWSFlow
# 32368                                                NaN
# 36035                                                NaN
#
#                                 description units tagged_units  ...  \
# 3868                                    NaN   gpm          gpm  ...
# 4112                                    NaN   gpm          gpm  ...
# 20071                                   NaN   gpm          gpm  ...
# 26372                                   NaN   NaN          gpm  ...
# 32368          B132 Plant Total FO Flow GPM   gpm          NaN  ...
# 36035  Roosevelt Landings eBX DHW HXCR Flow   gpm          NaN  ...
#
#        measurement_id                   datasource_hash  \
# 3868                5  309a6cf1e3cacabae12c3ae45eca8db2
# 4112                5  172610bd9df27d767c0a03f449abf05d
# 20071               5  3d5edef941aaebd5125523500f052581
# 26372               5  cf6f11643a8ad54b43816f4b16729b80
# 32368               5  d205e7c8d9326a61a07898ee801642ce
# 36035               5  48695cbc7391c0bf58caf9f48527fada
#
#                                                    topic  equip_id  id_bdg  \
# 3868   nyserda+000076513+domesticHotWaterPlant+480 W ...     26938     426
# 4112   nyserda+000076513+hotWaterPlant+480 W 42nd St ...     26961     426
# 20071  nyserda+0000155776+hotWaterPlant+Primary HW Fl...     30390     454
# 26372  nyserda+00000123771+hotWaterPlant+HWS - Boiler...     30491     465
# 32368  nyserda+0000135785+hotWaterPlant+B132 Plant To...     19740     256
# 36035  nyserda+0000099466+domesticHotWaterPlant+Roose...     20689     301
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 3868     76513             HWS  Hot Water Plant               NaN
# 4112     76513             HWS  Hot Water Plant               NaN
# 20071   155776             HWS  Hot Water Plant               NaN
# 26372   123771             HWS  Hot Water Plant               NaN
# 32368   135785             HWS  Hot Water Plant               NaN
# 36035    99466             HWS  Hot Water Plant               NaN
#
#                             tags
# 3868   ['hvac', 'hotWaterPlant']
# 4112   ['hvac', 'hotWaterPlant']
# 20071  ['hvac', 'hotWaterPlant']
# 26372  ['hvac', 'hotWaterPlant']
# 32368  ['hvac', 'hotWaterPlant']
# 36035  ['hvac', 'hotWaterPlant']
#
# [6 rows x 24 columns]

# %% [markdown]
# Only building 465 and 301 have HHWS, HHWR, and flow rate.

# %% [markdown]
# Now that we have our metadata filtered it's time to get the time-series of those points. Let's import the libraries we will be using:

# %%
boiler_hhws_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 17       310025          441  1.603907e+12   1.588306e+12     NaN       NaN
# 35       310044          441  1.609476e+12   1.570372e+12     NaN       NaN
# 53       310061          441  1.603907e+12   1.588306e+12     NaN       NaN
# 89       310096          441  1.603907e+12   1.588306e+12     NaN       NaN
# 121      310134          441  1.589548e+12   1.588306e+12     NaN       NaN
# ...         ...          ...           ...            ...     ...       ...
# 41445    228755          387  1.554090e+12   1.553719e+12     NaN       NaN
# 43476    201603          184  1.577854e+12   1.548997e+12     NaN       NaN
# 43479    201605          184  1.577854e+12   1.548997e+12     NaN       NaN
# 43491    205027          214  1.577854e+12   1.559362e+12     NaN       NaN
# 43493    205019          214  1.577854e+12   1.559362e+12     NaN       NaN
#
#                                               name_point  \
# 17     225 E 149th St. Boiler Hot Water-1 Supply Temp...
# 35     245 E 149th St. Boiler Hot Water-1 Supply Temp...
# 53     225 E 149th St. Boiler Hot Water-2 Supply Temp...
# 89     225 E 149th St. Boiler Hot Water-3 Supply Temp...
# 121    225 E 149th St. Boiler Hot Water-4 Supply Temp...
# ...                                                  ...
# 41445                                                NaN
# 43476                                                NaN
# 43479                                                NaN
# 43491  151 E 43rd Street Boiler Domestic Hot Water Te...
# 43493  151 E 43rd Street Boiler Hot Water Coil Temper...
#
#                                              description units tagged_units  \
# 17                                                   NaN     F            f
# 35                                                   NaN     F            f
# 53                                                   NaN     F            f
# 89                                                   NaN     F            f
# 121                                                  NaN     F            f
# ...                                                  ...   ...          ...
# 41445                  Boiler 3_Heating HW Temp: Leaving     F          NaN
# 43476  447 Fort Washington Boiler Domestic Hot Water ...     F          NaN
# 43479  447 Fort Washington Boiler Hot Water Coil Temp...     F          NaN
# 43491  151 E 43rd Street Boiler Domestic Hot Water Te...     F            f
# 43493  151 E 43rd Street Boiler Hot Water Coil Temper...     F            f
#
#        ...  measurement_id                   datasource_hash  \
# 17     ...               1  854cf8294fc6a9caf07b027d83ca773b
# 35     ...               1  55ee899b0a1345f9074b7f221e5bbdf2
# 53     ...               1  8947cc3817208ef853874233f9c10baa
# 89     ...               1  d54a6fb5a9d430c8b5d306cd3779f1d8
# 121    ...               1  fc7f7676c2eedf065dfaa36a17327ed2
# ...    ...             ...                               ...
# 41445  ...               1  ec43ca98a08f1c706391091f6b29516e
# 43476  ...               1  f507da735afb6e016212b79eef6ffa54
# 43479  ...               1  2048aa690c763ac9f3fc14888e7884e1
# 43491  ...               1  2fa035655824ad45c0d66ae474b13540
# 43493  ...               1  09b965a70e2483be3573bf82e5cdda5c
#
#                                                    topic  equip_id  id_bdg  \
# 17     nyserda+0000088737+boiler-1+225 E 149th St. Bo...     28797     441
# 35     nyserda+0000088737+boiler-1+245 E 149th St. Bo...     28797     441
# 53     nyserda+0000088737+boiler-2+225 E 149th St. Bo...     28798     441
# 89     nyserda+0000088737+boiler-3+225 E 149th St. Bo...     28799     441
# 121    nyserda+0000088737+boiler-4+225 E 149th St. Bo...     28800     441
# ...                                                  ...       ...     ...
# 41445  nyserda+0000096580+boiler3+Boiler 3_Heating HW...     22514     387
# 43476  nyserda+0000108764+boiler+447 Fort Washington ...     18680     184
# 43479  nyserda+0000108764+boiler+447 Fort Washington ...     18680     184
# 43491  nyserda+0000097593+hotWaterPlant+151 E 43rd St...     36556     214
# 43493  nyserda+0000097593+boiler+151 E 43rd Street Bo...     36556     214
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 17       88737             BLR           Boiler               NaN
# 35       88737             BLR           Boiler               NaN
# 53       88737             BLR           Boiler               NaN
# 89       88737             BLR           Boiler               NaN
# 121      88737             BLR           Boiler               NaN
# ...        ...             ...              ...               ...
# 41445    96580             BLR           Boiler               NaN
# 43476   108764             BLR           Boiler               NaN
# 43479   108764             BLR           Boiler               NaN
# 43491    97593             BLR           Boiler               NaN
# 43493    97593             BLR           Boiler               NaN
#
#                      tags
# 17     ['boiler', 'hvac']
# 35     ['boiler', 'hvac']
# 53     ['boiler', 'hvac']
# 89     ['boiler', 'hvac']
# 121    ['boiler', 'hvac']
# ...                   ...
# 41445  ['boiler', 'hvac']
# 43476  ['boiler', 'hvac']
# 43479  ['boiler', 'hvac']
# 43491  ['boiler', 'hvac']
# 43493  ['boiler', 'hvac']
#
# [129 rows x 24 columns]

# %%
boiler_hhwr_data
# Out:
#        id_point  building_id  last_updated  first_updated  device  objectId  \
# 1763     306128          434  1.609476e+12   1.582827e+12     NaN       NaN
# 2683     284531          375  1.596824e+12   1.585336e+12     NaN       NaN
# 5345     356058          467  1.598932e+12   1.577855e+12     NaN       NaN
# 7280     356098          468  1.598932e+12   1.587137e+12     NaN       NaN
# 10391    356123          469  1.598933e+12   1.589308e+12     NaN       NaN
# 11299    344411          461  1.598932e+12   1.577855e+12     NaN       NaN
# 12028    358998          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12033    359003          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12038    359008          479  1.619841e+12   1.604203e+12     NaN       NaN
# 12310    356020          466  1.598934e+12   1.585111e+12     NaN       NaN
# 22430    194189          111  1.546996e+12   1.533009e+12     NaN       NaN
# 22673    343363          451  1.592598e+12   1.577855e+12     NaN       NaN
# 26107    199149          153  1.575764e+12   1.567310e+12     NaN       NaN
# 26109    199152          153  1.575764e+12   1.567310e+12     NaN       NaN
# 26548    344573          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26552    344583          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26559    344590          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26566    344597          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26573    344604          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26580    344611          465  1.574203e+12   1.548997e+12     NaN       NaN
# 26587    344618          465  1.574203e+12   1.548997e+12     NaN       NaN
# 27436    198654          145  1.577854e+12   1.567310e+12     NaN       NaN
# 29787    200969          169  1.573966e+12   1.542344e+12     NaN       NaN
# 29807    200991          169  1.573966e+12   1.542344e+12     NaN       NaN
# 29812    200995          169  1.573966e+12   1.542344e+12     NaN       NaN
# 30112    201535          181  1.539696e+12   1.533095e+12     NaN       NaN
# 30113    201533          181  1.539696e+12   1.533095e+12     NaN       NaN
# 30120    201532          181  1.539696e+12   1.533095e+12     NaN       NaN
# 31216    414613          180  1.598918e+12   1.598918e+12     NaN       NaN
# 31224    201419          180  1.577854e+12   1.556683e+12     NaN       NaN
# 32254    206338          232  1.598932e+12   1.541044e+12     NaN       NaN
# 32682    209221          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32702    209233          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32708    209245          259  1.535774e+12   1.520952e+12     NaN       NaN
# 32722    209257          259  1.535774e+12   1.517995e+12     NaN       NaN
# 34318    212165          278  1.577854e+12   1.567310e+12     NaN       NaN
# 34321    212162          278  1.577854e+12   1.567310e+12     NaN       NaN
# 36004    215184          298  1.577854e+12   1.567310e+12     NaN       NaN
# 36023    215694          301  1.553918e+12   1.538280e+12     NaN       NaN
# 36028    215698          301  1.553918e+12   1.538280e+12     NaN       NaN
# 36032    215702          301  1.553918e+12   1.538280e+12     NaN       NaN
# 38715    222745          354  1.535774e+12   1.519675e+12     NaN       NaN
# 41313    224520          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41315    224519          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41317    224518          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41318    224513          357  1.580532e+12   1.575176e+12     NaN       NaN
# 41399    228708          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41437    228742          387  1.554090e+12   1.553719e+12     NaN       NaN
# 41446    228754          387  1.554090e+12   1.553719e+12     NaN       NaN
#
#                                               name_point  \
# 1763   333 Lenox Road Penthouse Boiler Room Loop Hot ...
# 2683   3400 Fort Independence Street Boiler 1 Condens...
# 5345   1710 Avenue H Boiler Condensate Return Tempera...
# 7280   51 Cross Street Boiler Condensate Return Tempe...
# 10391  9-11 Greenridge Avenue Boiler Condensate Retur...
# 11299  105 E 29th Street Boiler Condensate Return Tem...
# 12028  MHS.Boiler 1_Boiler Hot Water Return Temperatu...
# 12033  MHS.Boiler 2_Boiler Hot Water Return Temperatu...
# 12038  MHS.Boiler 3_Boiler Hot Water Return Temperatu...
# 12310  45-26 44th Street Boiler Condensate Return Tem...
# 22430                                                NaN
# 22673  70 Prospect Park SW Boiler Condensate Return T...
# 26107                                                NaN
# 26109                                                NaN
# 26548          CB-29-1 (HWS - Boilers Loop)_B1.InletTemp
# 26552          CB-29-2 (HWS - Boilers Loop)_B2.InletTemp
# 26559          CB-29-3 (HWS - Boilers Loop)_B3.InletTemp
# 26566          CB-29-4 (HWS - Boilers Loop)_B4.InletTemp
# 26573          CB-29-5 (HWS - Boilers Loop)_B5.InletTemp
# 26580          CB-29-6 (HWS - Boilers Loop)_B6.InletTemp
# 26587          CB-29-7 (HWS - Boilers Loop)_B7.InletTemp
# 27436                                                NaN
# 29787                                                NaN
# 29807                                                NaN
# 29812                                                NaN
# 30112                                                NaN
# 30113                                                NaN
# 30120                                                NaN
# 31216  304 St Johns Place Boiler Hot Water Return Tem...
# 31224   304 St Johns Boiler Hot Water Return Temperature
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...
# 32682                                                NaN
# 32702                                                NaN
# 32708                                                NaN
# 32722                                                NaN
# 34318                                                NaN
# 34321                                                NaN
# 36004                                                NaN
# 36023                                                NaN
# 36028                                                NaN
# 36032                                                NaN
# 38715                                                NaN
# 41313                                                NaN
# 41315                                                NaN
# 41317                                                NaN
# 41318                                                NaN
# 41399                                                NaN
# 41437                                                NaN
# 41446                                                NaN
#
#                                              description units tagged_units  \
# 1763                                                 NaN     F            f
# 2683                                                 NaN     F            f
# 5345                                                 NaN   NaN            f
# 7280                                                 NaN   NaN            f
# 10391                                                NaN   NaN            f
# 11299                                                NaN     F            f
# 12028                                                NaN   NaN            f
# 12033                                                NaN   NaN            f
# 12038                                                NaN   NaN            f
# 12310                                                NaN   NaN            f
# 22430  237 W 100th St Boiler Condensate Return Temper...     F          NaN
# 22673                                                NaN     F            f
# 26107  1898 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 26109  1898 Belmont Avenue Boiler Building Hot Water ...     F          NaN
# 26548                                                NaN   NaN            f
# 26552                                                NaN   NaN            f
# 26559                                                NaN   NaN            f
# 26566                                                NaN   NaN            f
# 26573                                                NaN   NaN            f
# 26580                                                NaN   NaN            f
# 26587                                                NaN   NaN            f
# 27436  1908 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 29787                           Boiler 1 HWR_Temperature     F          NaN
# 29807                           Boiler 2 HWR_Temperature     F          NaN
# 29812                           Boiler 3 HWR_Temperature     F          NaN
# 30112  220 East 54th St. Manhattan Boiler Plant Domes...     F          NaN
# 30113  220 East 54th St. Manhattan Boiler Plant Conde...     F          NaN
# 30120  220 East 54th St. Manhattan Boiler Plant Conde...     F          NaN
# 31216                                                NaN   NaN            f
# 31224   304 St Johns Boiler Hot Water Return Temperature     F            f
# 32254  100 Lawn Terrace Boiler Hot Water Return Tempe...     F            f
# 32682                 Boiler 1_Heating HW Temp: Entering     F          NaN
# 32702                 Boiler 2_Heating HW Temp: Entering     F          NaN
# 32708                 Boiler 3_Heating HW Temp: Entering     F          NaN
# 32722                 Boiler 4_Heating HW Temp: Entering     F          NaN
# 34318  1871 7th Avenue Boiler Building Hot Water Retu...     F          NaN
# 34321  1871 7th Avenue Boiler Boiler Hot Water Return...     F          NaN
# 36004  1900 Belmont Avenue Boiler Boiler Hot Water Re...     F          NaN
# 36023        Roosevelt Landings eBX Tecogen 1 Inlet Temp     F          NaN
# 36028        Roosevelt Landings eBX Tecogen 2 Inlet Temp     F          NaN
# 36032        Roosevelt Landings eBX Tecogen 3 Inlet Temp     F          NaN
# 38715                       Steam Plant_Dist Return Temp     F          NaN
# 41313  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41315  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41317  905 Palmer Avenue Boiler Hot Water Return Temp...     F          NaN
# 41318  905 Palmer Avenue Boiler Boiler Hot Water Retu...     F          NaN
# 41399                 Boiler 1_Heating HW Temp: Entering     F          NaN
# 41437                 Boiler 2_Heating HW Temp: Entering     F          NaN
# 41446                 Boiler 3_Heating HW Temp: Entering     F          NaN
#
#        ...  measurement_id                   datasource_hash  \
# 1763   ...               1  ee20afeb46f331d9b372ce27539df980
# 2683   ...               1  19ce83ab5a6ffd87e39b3976e03beb8f
# 5345   ...               1  9b9bcb429a4da328cb7366150084b068
# 7280   ...               1  1464a6ce6c17f17345ce25af1e98bf1c
# 10391  ...               1  16b953b4ed1e9cd0698bf483137c6d7b
# 11299  ...               1  abcb804f4ed57c71e79fc8d3d13d8892
# 12028  ...               1  2604227047eeaa4a0386e9b43b8ad7b7
# 12033  ...               1  3da7f8a153c337687ddf8f6a9224a4b4
# 12038  ...               1  231ed6924be115d3dccd74fdc79b3889
# 12310  ...               1  0cc763e04e22cc4e1da2dbf784c8e624
# 22430  ...               1  789c0476644d57cf082e0db087a10edf
# 22673  ...               1  266493231e6e65c701670ef427d76e6c
# 26107  ...               1  9590ce9b909f2f0cdc08f163aa121665
# 26109  ...               1  0804cf3f64c3b8ff1f50e9a1bc91c9df
# 26548  ...               1  1a7afbeb9630a91786a017dc2b05ed95
# 26552  ...               1  166d53e1f8be371f015559d0addbedfa
# 26559  ...               1  05a371b989b064d155d43dd50dd14743
# 26566  ...               1  05409b6774c80e406e08155138099228
# 26573  ...               1  119c98455e8419e3751ac6e1be15b83c
# 26580  ...               1  97756ca500a1cfc7880592d176470bb4
# 26587  ...               1  ce84da8221d121efcc30082eaf0ccd62
# 27436  ...               1  a8357abd2cf333583b897309a2085e3e
# 29787  ...               1  4fcc2552269a54d587b38828c39654a2
# 29807  ...               1  285ff162579926be5f75323c241d7876
# 29812  ...               1  84ebfb1c9aae51cfd7d5a12fb9ffd3b7
# 30112  ...               1  38e1eb34ebf1b167f3a964cf0556884e
# 30113  ...               1  5c9660d447e16ee426cf156eb77a6a95
# 30120  ...               1  7f80d7cbb91dc6e65bee7883cce145f7
# 31216  ...               1  eea3332846758f362b69caad6109c50f
# 31224  ...               1  9ff53b5835aa326d51d5473c4b95826f
# 32254  ...               1  27785ba499ee882d04cedec3e6b0afab
# 32682  ...               1  d767061b5385702216b67abfa16d0a3f
# 32702  ...               1  8a6ac1ce808bf996ce0bc4227e7e02c7
# 32708  ...               1  89ac0473385e8db6a6f922b0dcd818c7
# 32722  ...               1  409bf6ca4f82363d1dbffd621c1fc993
# 34318  ...               1  fba2b4f184799618c4e291309258e4f0
# 34321  ...               1  fda775415472f1f843b3915ccc45f9b5
# 36004  ...               1  a6b008d1c89ff24f626ed749406ed0db
# 36023  ...               1  d164e4e6da3636df651e557f138fcef4
# 36028  ...               1  34a190bd4e7ce6d7169212cfd8f6c71e
# 36032  ...               1  3cf770b406fc3770842c1e2e4f3ea41e
# 38715  ...               1  723e2ff27ad108da07554cd4e980ccf0
# 41313  ...               1  1767d978fce23302bb41ac88f04d1b60
# 41315  ...               1  9232f19a49e7a610ad900267d1cee5b5
# 41317  ...               1  346900660de2422a27b5316dbe721ce7
# 41318  ...               1  506a120ff0d6551a82aa9f3430f9d3f2
# 41399  ...               1  588f3b866280ca9da1ab70f3e835a427
# 41437  ...               1  c14b8391c74952aa465784ec38105b47
# 41446  ...               1  d6dfed4a31a023b0dd664c3885452988
#
#                                                    topic  equip_id  id_bdg  \
# 1763   nyserda+0000129666+hotWaterBoiler-1+333 Lenox ...     28499     434
# 2683   nyserda+0000097789+boiler1+3400 Fort Independe...     22333     375
# 5345   nyserda+0000139252+boiler-1+1710 Avenue H Boil...     31243     467
# 7280   nyserda+0000159109+boiler-1+51 Cross Street Bo...     31245     468
# 10391  nyserda+0000144601+boiler-1+9-11 Greenridge Av...     31246     469
# 11299  nyserda+0000137940+boiler-1+105 E 29th Street ...     30465     461
# 12028  nyserda+0000163716+boiler-1+MHS.Boiler 1_Boile...     31871     479
# 12033  nyserda+0000163716+boiler-2+MHS.Boiler 2_Boile...     31872     479
# 12038  nyserda+0000163716+boiler-3+MHS.Boiler 3_Boile...     31873     479
# 12310  nyserda+0000137257+boiler-1+45-26 44th Street ...     31241     466
# 22430  nyserda+0000089522+boiler1+237 W 100th St Boil...     17367     111
# 22673  nyserda+0000137244+boiler-1+70 Prospect Park S...     30303     451
# 26107  nyserda+0000125921+boiler+1898 Belmont Avenue ...     18243     153
# 26109  nyserda+0000125921+boiler+1898 Belmont Avenue ...     18243     153
# 26548  nyserda+00000123771+boiler1+CB-29-1 (HWS - Boi...     30500     465
# 26552  nyserda+00000123771+boiler2+CB-29-2 (HWS - Boi...     30501     465
# 26559  nyserda+00000123771+boiler3+CB-29-3 (HWS - Boi...     30502     465
# 26566  nyserda+00000123771+boiler4+CB-29-4 (HWS - Boi...     30503     465
# 26573  nyserda+00000123771+boiler5+CB-29-5 (HWS - Boi...     30504     465
# 26580  nyserda+00000123771+boiler6+CB-29-6 (HWS - Boi...     30505     465
# 26587  nyserda+00000123771+boiler7+CB-29-7 (HWS - Boi...     30506     465
# 27436  nyserda+0000125854+boiler+1908 Belmont Avenue ...     18165     145
# 29787  nyserda+0000103622+boiler1+Boiler 1 HWR_Temper...     18541     169
# 29807  nyserda+0000103622+boiler2+Boiler 2 HWR_Temper...     18543     169
# 29812  nyserda+0000103622+boiler3+Boiler 3 HWR_Temper...     18544     169
# 30112  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 30113  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 30120  nyserda+0000090423+boiler1+220 East 54th St. M...     18674     181
# 31216  nyserda+0000112065+boiler-1+304 St Johns Place...     34987     180
# 31224  nyserda+0000112065+boiler+304 St Johns Boiler ...     34987     180
# 32254  nyserda+0000099291+boiler+100 Lawn Terrace Boi...     33923     232
# 32682  nyserda+0000082294+boiler1+Boiler 1_Heating HW...     19850     259
# 32702  nyserda+0000082294+boiler2+Boiler 2_Heating HW...     19851     259
# 32708  nyserda+0000082294+boiler3+Boiler 3_Heating HW...     19852     259
# 32722  nyserda+0000082294+boiler4+Boiler 4_Heating HW...     19853     259
# 34318  nyserda+0000125541+boiler+1871 7th Avenue Boil...     20245     278
# 34321  nyserda+0000125541+boiler+1871 7th Avenue Boil...     20245     278
# 36004  nyserda+0000125920+boiler+1900 Belmont Avenue ...     20519     298
# 36023  nyserda+0000099466+boiler-hotWaterPlant1+Roose...     20686     301
# 36028  nyserda+0000099466+boiler-hotWaterPlant2+Roose...     20687     301
# 36032  nyserda+0000099466+boiler-hotWaterPlant3+Roose...     20688     301
# 38715  nyserda+0000082140+boiler-steamPlant+Steam Pla...     21630     354
# 41313  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41315  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41317  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41318  nyserda+0000129887+boiler+905 Palmer Avenue Bo...     21813     357
# 41399  nyserda+0000096580+boiler1+Boiler 1_Heating HW...     22511     387
# 41437  nyserda+0000096580+boiler2+Boiler 2_Heating HW...     22513     387
# 41446  nyserda+0000096580+boiler3+Boiler 3_Heating HW...     22514     387
#
#       name_bdg equip_type_abbr  equip_type_name  area_served_desc  \
# 1763    129666             BLR           Boiler               NaN
# 2683     97789             BLR           Boiler               NaN
# 5345    139252             BLR           Boiler               NaN
# 7280    159109             BLR           Boiler               NaN
# 10391   144601             BLR           Boiler               NaN
# 11299   137940             BLR           Boiler               NaN
# 12028   163716             BLR           Boiler               NaN
# 12033   163716             BLR           Boiler               NaN
# 12038   163716             BLR           Boiler               NaN
# 12310   137257             BLR           Boiler               NaN
# 22430    89522             BLR           Boiler               NaN
# 22673   137244             BLR           Boiler               NaN
# 26107   125921             BLR           Boiler               NaN
# 26109   125921             BLR           Boiler               NaN
# 26548   123771             BLR           Boiler               NaN
# 26552   123771             BLR           Boiler               NaN
# 26559   123771             BLR           Boiler               NaN
# 26566   123771             BLR           Boiler               NaN
# 26573   123771             BLR           Boiler               NaN
# 26580   123771             BLR           Boiler               NaN
# 26587   123771             BLR           Boiler               NaN
# 27436   125854             BLR           Boiler               NaN
# 29787   103622             BLR           Boiler               NaN
# 29807   103622             BLR           Boiler               NaN
# 29812   103622             BLR           Boiler               NaN
# 30112    90423             BLR           Boiler               NaN
# 30113    90423             BLR           Boiler               NaN
# 30120    90423             BLR           Boiler               NaN
# 31216   112065             BLR           Boiler               NaN
# 31224   112065             BLR           Boiler               NaN
# 32254    99291             BLR           Boiler               NaN
# 32682    82294             BLR           Boiler               NaN
# 32702    82294             BLR           Boiler               NaN
# 32708    82294             BLR           Boiler               NaN
# 32722    82294             BLR           Boiler               NaN
# 34318   125541             BLR           Boiler               NaN
# 34321   125541             BLR           Boiler               NaN
# 36004   125920             BLR           Boiler               NaN
# 36023    99466             BLR           Boiler               NaN
# 36028    99466             BLR           Boiler               NaN
# 36032    99466             BLR           Boiler               NaN
# 38715    82140             BLR           Boiler               NaN
# 41313   129887             BLR           Boiler               NaN
# 41315   129887             BLR           Boiler               NaN
# 41317   129887             BLR           Boiler               NaN
# 41318   129887             BLR           Boiler               NaN
# 41399    96580             BLR           Boiler               NaN
# 41437    96580             BLR           Boiler               NaN
# 41446    96580             BLR           Boiler               NaN
#
#                                        tags
# 1763   ['boiler', 'hvac', 'hotWaterBoiler']
# 2683                     ['boiler', 'hvac']
# 5345                     ['boiler', 'hvac']
# 7280                     ['boiler', 'hvac']
# 10391                    ['boiler', 'hvac']
# 11299                    ['boiler', 'hvac']
# 12028                    ['boiler', 'hvac']
# 12033                    ['boiler', 'hvac']
# 12038                    ['boiler', 'hvac']
# 12310                    ['boiler', 'hvac']
# 22430                    ['boiler', 'hvac']
# 22673                    ['boiler', 'hvac']
# 26107                    ['boiler', 'hvac']
# 26109                    ['boiler', 'hvac']
# 26548                    ['boiler', 'hvac']
# 26552                    ['boiler', 'hvac']
# 26559                    ['boiler', 'hvac']
# 26566                    ['boiler', 'hvac']
# 26573                    ['boiler', 'hvac']
# 26580                    ['boiler', 'hvac']
# 26587                    ['boiler', 'hvac']
# 27436                    ['boiler', 'hvac']
# 29787                    ['boiler', 'hvac']
# 29807                    ['boiler', 'hvac']
# 29812                    ['boiler', 'hvac']
# 30112                    ['boiler', 'hvac']
# 30113                    ['boiler', 'hvac']
# 30120                    ['boiler', 'hvac']
# 31216  ['boiler', 'hvac', 'hotWaterBoiler']
# 31224  ['boiler', 'hvac', 'hotWaterBoiler']
# 32254                    ['boiler', 'hvac']
# 32682                    ['boiler', 'hvac']
# 32702                    ['boiler', 'hvac']
# 32708                    ['boiler', 'hvac']
# 32722                    ['boiler', 'hvac']
# 34318                    ['boiler', 'hvac']
# 34321                    ['boiler', 'hvac']
# 36004                    ['boiler', 'hvac']
# 36023  ['boiler', 'hvac', 'hotWaterBoiler']
# 36028  ['boiler', 'hvac', 'hotWaterBoiler']
# 36032  ['boiler', 'hvac', 'hotWaterBoiler']
# 38715     ['boiler', 'hvac', 'steamBoiler']
# 41313                    ['boiler', 'hvac']
# 41315                    ['boiler', 'hvac']
# 41317                    ['boiler', 'hvac']
# 41318                    ['boiler', 'hvac']
# 41399                    ['boiler', 'hvac']
# 41437                    ['boiler', 'hvac']
# 41446                    ['boiler', 'hvac']
#
# [49 rows x 24 columns]

# %% [markdown]
# # Querying time-series: Gas consumption

# %%
gas_consumption_points = list(gas_consumption_data.id_point)
gas_flow_points = list(gas_flow_data.id_point)

# %%
gas_consumption_data.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2020-07-06 13:15:00+0000', tz='UTC')

# %%
gas_consumption_data.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2021-05-13 17:45:00+0000', tz='UTC')

# %%
gas_flow_data.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2019-09-01 04:25:00+0000', tz='UTC')

# %%
gas_flow_data.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2020-08-31 15:55:00+0000', tz='UTC')

# %%
# Select your timezone
tz = pytz.timezone('UTC')

# Select your date and time (time is optional)
start = datetime(2020,7,6,0,0,0).replace(tzinfo=tz)
end = datetime(2021,5,13,0,0,0).replace(tzinfo=tz)

print(f"from {start} to {end}")
# Out:
# from 2020-07-06 00:00:00+00:00 to 2021-05-13 00:00:00+00:00

# %%
timeseries_query_gas_consumption = TimeseriesQuery(point_ids = gas_consumption_points, start = start, end = end)

# %%
# Select your date and time (time is optional)
start = datetime(2019,9,1,0,0,0).replace(tzinfo=tz)
end = datetime(2020,8,31,0,0,0).replace(tzinfo=tz)

print(f"from {start} to {end}")
# Out:
# from 2019-09-01 00:00:00+00:00 to 2020-08-31 00:00:00+00:00

# %%
timeseries_query_gas_flow = TimeseriesQuery(point_ids = gas_flow_points, start = start, end = end)

# %%
# Exceute query (will return and object)
query_results_gas_flow = client.stream_point_timeseries(timeseries_query_gas_flow)
query_results_gas_consumption = client.stream_point_timeseries(timeseries_query_gas_consumption)
# Convert to dataframe
data_gas_flow = points_df_from_streaming_timeseries(query_results_gas_flow)
data_gas_consumption = points_df_from_streaming_timeseries(query_results_gas_consumption)

# %%
data_gas_flow.to_csv("rtem_gas_flow_time_series.csv", index=False)
data_gas_consumption.to_csv("rtem_gas_consumption_time_series.csv", index=False)

# %% [markdown]
# # Cleansing Gas Data

# %%
# convert cfm to cfh
mislabel_gas = [359381,359384,194214,359386]
data_gas_flow[mislabel_gas] = 60*data_gas_flow[mislabel_gas]

# %%
data_gas_flow
# Out:
#                    timestamp      208550      208552      359381       359384  \
# 0       2019-09-01T04:25:00Z         NaN         NaN  4631.86795  2890.905504
# 1       2019-09-01T04:30:00Z         NaN         NaN  4631.86795  6960.393234
# 2       2019-09-01T04:35:00Z         NaN         NaN  4631.86795  2898.805405
# 3       2019-09-01T04:40:00Z         NaN         NaN  4631.86795  2915.593498
# 4       2019-09-01T04:45:00Z         NaN         NaN  4631.86795  6518.980068
# ...                      ...         ...         ...         ...          ...
# 104464  2020-08-30T23:35:00Z  201270.203  6958.11377         NaN          NaN
# 104465  2020-08-30T23:40:00Z  201909.094  7363.43311         NaN          NaN
# 104466  2020-08-30T23:45:00Z  202741.406  3095.67505         NaN          NaN
# 104467  2020-08-30T23:50:00Z  202741.406  3095.67505         NaN          NaN
# 104468  2020-08-30T23:55:00Z  202281.594     0.00000         NaN          NaN
#
#         194214       359386
# 0          NaN  6810.293106
# 1          NaN  2472.206455
# 2          NaN  6750.548958
# 3          NaN  2583.793394
# 4          NaN  2532.443536
# ...        ...          ...
# 104464     NaN          NaN
# 104465     NaN          NaN
# 104466     NaN          NaN
# 104467     NaN          NaN
# 104468     NaN          NaN
#
# [104469 rows x 7 columns]

# %%
data_gas_consumption[320457]
# Applying the condition
data_gas_consumption.loc[data_gas_consumption[320457] >= 10870, 320457] = data_gas_consumption[320457] / 10
max(data_gas_consumption[320457])
# Out:
# 1142.7043333333334

# %%
# find null column
for col in cols:
    sumZero = sum(~(data_gas[col].isin([np.nan, 0.0])))
    print(col, sumZero)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [96], in <cell line: 2>()
#       1 # find null column
#       2 for col in cols:
# ----> 3     sumZero = sum(~(data_gas[col].isin([np.nan, 0.0])))
#       4     print(col, sumZero)
#
# NameError: name 'data_gas' is not defined

# %% [markdown]
# # Resampling Gas Data

# %%
data_gas_consumption["timestamp"] = pd.to_datetime(data_gas_consumption['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')
data_gas_flow["timestamp"] = pd.to_datetime(data_gas_flow['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
data_gas_consumption.resample('H', on="timestamp").mean()
# Out:
#                            320458  358166    320455  320457
# timestamp
# 2020-07-06 13:00:00+00:00     NaN     NaN       NaN     0.0
# 2020-07-06 14:00:00+00:00     NaN     NaN       NaN     0.0
# 2020-07-06 15:00:00+00:00     NaN     NaN       NaN     0.0
# 2020-07-06 16:00:00+00:00     NaN     NaN       NaN     0.0
# 2020-07-06 17:00:00+00:00     NaN     NaN       NaN     0.0
# ...                           ...     ...       ...     ...
# 2021-05-12 19:00:00+00:00     NaN     NaN  5.858622     NaN
# 2021-05-12 20:00:00+00:00     NaN     NaN  0.732328     NaN
# 2021-05-12 21:00:00+00:00     NaN     NaN  4.393966     NaN
# 2021-05-12 22:00:00+00:00     NaN     NaN  5.126294     NaN
# 2021-05-12 23:00:00+00:00     NaN     NaN  3.661639     NaN
#
# [7451 rows x 4 columns]

# %%
data_gas_flow.resample('H', on="timestamp").mean()
# Out:
#                                   208550       208552       359381  \
# timestamp
# 2019-09-01 04:00:00+00:00            NaN          NaN  4631.867950
# 2019-09-01 05:00:00+00:00            NaN          NaN  4631.867950
# 2019-09-01 06:00:00+00:00            NaN          NaN  4627.300525
# 2019-09-01 07:00:00+00:00            NaN          NaN  4622.897815
# 2019-09-01 08:00:00+00:00            NaN          NaN  4618.783352
# ...                                  ...          ...          ...
# 2020-08-30 19:00:00+00:00  194430.816417  6080.442506          NaN
# 2020-08-30 20:00:00+00:00  194672.507833  6815.458416          NaN
# 2020-08-30 21:00:00+00:00  195062.500000  7117.857869          NaN
# 2020-08-30 22:00:00+00:00  195943.207083  6991.692404          NaN
# 2020-08-30 23:00:00+00:00  200489.774750  6267.206787          NaN
#
#                                 359384  194214       359386
# timestamp
# 2019-09-01 04:00:00+00:00  4629.751945     NaN  4362.633388
# 2019-09-01 05:00:00+00:00  3751.100490     NaN  4161.571219
# 2019-09-01 06:00:00+00:00  3527.801910     NaN  4116.845463
# 2019-09-01 07:00:00+00:00  3660.579540     NaN  4185.189000
# 2019-09-01 08:00:00+00:00  3808.581312     NaN  3818.373794
# ...                                ...     ...          ...
# 2020-08-30 19:00:00+00:00          NaN     NaN          NaN
# 2020-08-30 20:00:00+00:00          NaN     NaN          NaN
# 2020-08-30 21:00:00+00:00          NaN     NaN          NaN
# 2020-08-30 22:00:00+00:00          NaN     NaN          NaN
# 2020-08-30 23:00:00+00:00          NaN     NaN          NaN
#
# [8756 rows x 6 columns]

# %% [markdown]
# # Lineplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# This is for the visual stype, I like "ggplot"
plt.style.use('ggplot')

# This for the figure size
plt.rcParams["figure.figsize"] = (20,9)

# %%
# re-query: building_442: 320558 & 320455 - Using one start-end
# building_110: 258166: another
# building_442: 320457 another
# These are the sensors, one per column (first one is the timestamp)
cols = data_gas_consumption.columns[1:]

for col in cols:
    plt.figure()
    sns.lineplot(data=data_gas_consumption, x="timestamp", y=col, label=col)

# %%
cols = data_gas_consumption.columns[1:]
# convert from therm to MMbtu
data_gas_consumption_MMbtu = data_gas_consumption
data_gas_consumption_MMbtu[cols] = data_gas_consumption[cols] * 99976.1 / 1000000

# %%
for col in cols:
    plt.figure()
    sns.lineplot(data=data_gas_consumption_MMbtu, x="timestamp", y=col, label=col)

# %%
# These are the sensors, one per column (first one is the timestamp)
cols = data_gas_flow.columns[1:]
plt.figure()
for col in cols:
    sns.lineplot(data=data_gas_flow, x="timestamp", y=col, label=col)

# %%
# natural gas heat content in NY: 1032
cols = data_gas_flow.columns[1:]
data_gas_flow_to_MMbtu = data_gas_flow
data_gas_flow_to_MMbtu[cols] = data_gas_flow[cols] * 1032 / 1000000

# %%
for col in cols:
    plt.figure()
    sns.lineplot(data=data_gas_flow_to_MMbtu, x="timestamp", y=col, label=col)

# %% [markdown]
# # Querying time-series: Heating Hot Water Plant

# %% [markdown]
# First, create a list with the points to query. We already filtered our dataset, so it's all the points there:

# %%
hhwp_hhws_points = list(hhwp_hhws.id_point)
hhwp_hhwr_points = list(hhwp_hhwr.id_point)
hhwp_flow_points = list(hhwp_flow.id_point)

# %%
hhwp_hhws.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2017-12-01 05:00:00+0000', tz='UTC')

# %%
hhwp_hhws.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2020-12-01 04:45:00+0000', tz='UTC')

# %%
hhwp_hhwr.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2017-12-01 05:00:00+0000', tz='UTC')

# %%
hhwp_hhwr.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2020-12-01 04:45:00+0000', tz='UTC')

# %%
hhwp_flow.first_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).min()
# Out:
# Timestamp('2017-12-01 05:00:00+0000', tz='UTC')

# %%
hhwp_flow.last_updated.apply(lambda x: datetime.fromtimestamp(x/1000, timezone.utc)).max()
# Out:
# Timestamp('2020-12-01 04:45:00+0000', tz='UTC')

# %%
# Select your timezone
tz = pytz.timezone('UTC')

# Select your date and time (time is optional)
start = datetime(2017,12,2,0,0,0).replace(tzinfo=tz)
end = datetime(2020,12,1,0,0,0).replace(tzinfo=tz)

print(f"from {start} to {end}")
# Out:
# from 2017-12-02 00:00:00+00:00 to 2020-12-01 00:00:00+00:00

# %% [markdown]
# And create the query with all the parameters. Here we are saying "give me the readings fron 20 january 2017 to 20 january 2018 of the points in `points`":

# %%
timeseries_query_hhwp_hhws = TimeseriesQuery(point_ids = hhwp_hhws_points, start = start, end = end)
timeseries_query_hhwp_hhwr = TimeseriesQuery(point_ids = hhwp_hhwr_points, start = start, end = end)
timeseries_query_hhwp_flow = TimeseriesQuery(point_ids = hhwp_flow_points, start = start, end = end)

# %%
# Exceute query (will return and object)
query_results_hhwp_hhws = client.stream_point_timeseries(timeseries_query_hhwp_hhws)
query_results_hhwp_hhwr = client.stream_point_timeseries(timeseries_query_hhwp_hhwr)
query_results_hhwp_flow = client.stream_point_timeseries(timeseries_query_hhwp_flow)

# Convert to dataframe
data_hhwp_hhws = points_df_from_streaming_timeseries(query_results_hhwp_hhws)
data_hhwp_hhwr = points_df_from_streaming_timeseries(query_results_hhwp_hhwr)
data_hhwp_flow = points_df_from_streaming_timeseries(query_results_hhwp_flow)

# %%
data_hhwp_hhws
# Out:
#                    timestamp  344701  283441  343964
# 0       2017-12-02T00:15:00Z     NaN  159.45     NaN
# 1       2017-12-02T00:30:00Z     NaN  157.40     NaN
# 2       2017-12-02T00:45:00Z     NaN  157.64     NaN
# 3       2017-12-02T01:00:00Z     NaN  155.25     NaN
# 4       2017-12-02T01:15:00Z     NaN  161.37     NaN
# ...                      ...     ...     ...     ...
# 204740  2020-11-30T22:45:00Z     NaN  157.04     NaN
# 204741  2020-11-30T23:00:00Z     NaN  156.88     NaN
# 204742  2020-11-30T23:15:00Z     NaN  161.62     NaN
# 204743  2020-11-30T23:30:00Z     NaN  159.40     NaN
# 204744  2020-11-30T23:45:00Z     NaN  157.08     NaN
#
# [204745 rows x 4 columns]

# %%
data_hhwp_hhwr
# Out:
#                    timestamp  344700  283440  343963
# 0       2017-12-02T00:15:00Z     NaN  157.68     NaN
# 1       2017-12-02T00:30:00Z     NaN  155.45     NaN
# 2       2017-12-02T00:45:00Z     NaN  155.30     NaN
# 3       2017-12-02T01:00:00Z     NaN  153.60     NaN
# 4       2017-12-02T01:15:00Z     NaN  158.96     NaN
# ...                      ...     ...     ...     ...
# 204747  2020-11-30T22:45:00Z     NaN  156.28     NaN
# 204748  2020-11-30T23:00:00Z     NaN  156.37     NaN
# 204749  2020-11-30T23:15:00Z     NaN  159.39     NaN
# 204750  2020-11-30T23:30:00Z     NaN  157.92     NaN
# 204751  2020-11-30T23:45:00Z     NaN  155.71     NaN
#
# [204752 rows x 4 columns]

# %%
data_hhwp_flow
# Out:
#                    timestamp  344702  283439  343962
# 0       2017-12-02T00:15:00Z     NaN  190.93     NaN
# 1       2017-12-02T00:30:00Z     NaN  192.68     NaN
# 2       2017-12-02T00:45:00Z     NaN  187.49     NaN
# 3       2017-12-02T01:00:00Z     NaN  192.31     NaN
# 4       2017-12-02T01:15:00Z     NaN  191.83     NaN
# ...                      ...     ...     ...     ...
# 204741  2020-11-30T22:45:00Z     NaN  192.59     NaN
# 204742  2020-11-30T23:00:00Z     NaN  191.28     NaN
# 204743  2020-11-30T23:15:00Z     NaN  192.64     NaN
# 204744  2020-11-30T23:30:00Z     NaN  190.30     NaN
# 204745  2020-11-30T23:45:00Z     NaN  189.53     NaN
#
# [204746 rows x 4 columns]

# %% [markdown]
# # Resampling

# %%
data_hhwp_flow["timestamp"] = pd.to_datetime(data_hhwp_flow['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
data_hhwp_hhws["timestamp"] = pd.to_datetime(data_hhwp_hhws['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
data_hhwp_hhwr["timestamp"] = pd.to_datetime(data_hhwp_hhwr['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lineplots

# %%
# This is for the visual stype, I like "ggplot"
plt.style.use('ggplot')

# This for the figure size
plt.rcParams["figure.figsize"] = (20,9)

# %%
# These are the sensors, one per column (first one is the timestamp)
cols = data_hhwp_flow.columns[1:]
for col in cols:
    plt.figure()
    sns.lineplot(data=data_hhwp_flow, x="timestamp", y=col)

# %%
# These are the sensors, one per column (first one is the timestamp)
cols_s = data_hhwp_hhws.columns[1:]
cols_r = data_hhwp_hhwr.columns[1:]
# cols_f = data_hhwp_flow.columns[1:]

for i in range(0, len(cols_s)):
    plt.figure()
    col_s = cols_s[i]
    col_r = cols_r[i]
    # col_f = cols_f[i]
    sns.lineplot(data=data_hhwp_hhws, x="timestamp", y=col_s)
    sns.lineplot(data=data_hhwp_hhwr, x="timestamp", y=col_r)
    # sns.lineplot(data=data_hhwp_flow, x="timestamp", y=col_f)

# %%
# These are the sensors, one per column (first one is the timestamp)
data_delta_temp = data_hhwp_hhws.copy()
data_hhwp_MMBtu = data_delta_temp.copy()
# for col in cols:
#     plt.figure()
#     sns.lineplot(data=data_delta_temp, x="timestamp", y=col_s)

# These are the sensors, one per column (first one is the timestamp)
cols_s = data_hhwp_hhws.columns[1:]
cols_r = data_hhwp_hhwr.columns[1:]
cols_f = data_hhwp_flow.columns[1:]

for i in range(0, len(cols_s)):
    plt.figure()
    col_s = cols_s[i]
    col_r = cols_r[i]
    col_f = cols_f[i]
    data_delta_temp[col_s] = data_hhwp_hhws[col_s] - data_hhwp_hhwr[col_r]
    data_hhwp_MMBtu[col_s] = 500 * data_delta_temp[col_s] * data_hhwp_flow[col_f] / 1000000
    sns.lineplot(data=data_hhwp_MMBtu, x="timestamp", y=col_s)

# %% [markdown]
# # Resampling

# %% [markdown]
# Let's load the dataset we just exported just to learn one more trick:

# %%
data = pd.read_csv("./rtem_boiler_hhws_time_series.csv")

# %%
data.info()

# %% [markdown]
# The timestamp there is not a datetime object yet. We could have parsed it as date [using the parameter `parse_dates` while reading](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) the csv or we can do the following:

# %%
data["timestamp"] = pd.to_datetime(data['timestamp'], format='%Y-%m-%dT%H:%M:%S.%f')

# %%
type(data.timestamp[0])

# %% [markdown]
# See? now is a datetime object located in UTC timezone.
#
# One important thing when working with time-series data is knowing how to resample it. Let's inspect our data:

# %%
data.head(10)

# %% [markdown]
# looks like readings are each 15 minutes and we have some missing gaps there. What if we want the reading each hour, getting the average value in that period? We can do that easily with the `resample` method. You have to specify the frequency ("D" means 1 Day), on which column you will be resampling ("timestamp") and the aggregation function ("mean"). For applying this function is important to have your timestamp as a datetime type, otherwise it will do it by index and won't understand the frequency.

# %%
data.resample('D', on="timestamp").mean()

# %% [markdown]
# And you can do it with the frequency you want. Let's try 1 Hour ("H" is 1 Hour):

# %%
data.resample('H', on="timestamp").mean()

# %% [markdown]
# That weird "T" -that means "minutes"- is an [offset alias. You can check all of them out here](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases).

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Lineplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# This is for the visual stype, I like "ggplot"
plt.style.use('ggplot')

# This for the figure size
plt.rcParams["figure.figsize"] = (20,9)

# %% [markdown]
# We are going to explore our sensors data with some simple lineplots. We are going to use [*Seaborn*](https://seaborn.pydata.org/) which works on [*Matplotlib*](https://matplotlib.org/stable/users/index.html). Let's import them:

# %% [markdown]
# Let's plot the raw data of our sensors:

# %%
# These are the sensors, one per column (first one is the timestamp)
cols = data.columns[1:]
cols

# %%
for col in cols:
    plt.figure()
    sns.lineplot(data=data, x="timestamp", y=col)

# %% [markdown]
# We have a huge gap with no data and the rest it's noisy and difficult to see. Let's filter data from september 1st 2017:

# %%
data = data[data.timestamp >= "2017-09-01"]

# %% [markdown]
# One useful technique to deal with noisy data is to resample it by hour (or a longer time frequency) aggregating by the mean: this way we can visualize the hourly/daily behaviour more smoothed.
#
# But first, let's go deeper into our `timestamp` column. This is a datetime column, meaning that we have some functions to handle the dates better. With [this pandas method](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.html) we can access our date: we can get the date, the weekday, the hour, the seconds, the minutes; all the information in our date can be obtained.
#
# Let's try an example. This is our raw timestamp:

# %%
data.timestamp

# %% [markdown]
# We can get the date:

# %%
data.timestamp.dt.date

# %% [markdown]
# Even the he day of the week (with Monday=0, Sunday=6)

# %%
data.timestamp.dt.weekday

# %% [markdown]
# The hour

# %%
data.timestamp.dt.hour

# %% [markdown]
# Or the minutes

# %%
data.timestamp.dt.minute

# %% [markdown]
# Pretty simple! You have all the datetime information handy.
#
# Now let's smooth the data to plot it!

# %%
data_hour = data.resample('1H', on="timestamp").mean()
data_hour.head()

# %% [markdown]
# And we have the mean temperature by hour! Plotting it is simple with this data set:

# %%
fig = sns.lineplot(data=data_hour)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %% [markdown]
# Let's do it again but daily:

# %%
data_day = data.resample('24H', on="timestamp").mean()
data_day.head()

# %%
sns.lineplot(data=data_day)

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %% [markdown]
# ## Heatmaps

# %% [markdown]
# Lineplots are easy but still pretty diffcult to visualize. Instead, we can use [heatmaps](https://seaborn.pydata.org/generated/seaborn.heatmap.html), it's also really easy. Remember you can transpose your data to change the axis, like this:

# %%
data_hour.T

# %% [markdown]
# And super-easy to plot:

# %%
sns.heatmap(data_hour.T, cmap="hot_r")

# %%
sns.heatmap(data_day.T, cmap="hot_r")

# %% [markdown]
# With this kind of plot is pretty evident where we have gaps with no-readings.

# %% [markdown]
# # Summary stats

# %% [markdown]
# Usually is useful to get some summary stats from our data. Fortunately, pandas has a simple method to obtain them:

# %%
data.describe()

# %% [markdown]
# These stats are usually visualizes in boxplot and histograms; these two plots can be easily obtained with the plotting libraries we are using. But first I suggest processing a little the dataframe to be able to plot all sensors in the same figure. We are using the pandas method [melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html). We have the data in this way right now:

# %%
data.head()

# %% [markdown]
# If we use the `melt` method we can convert our columns in rows, creating a new one that indicates which column it was. Is easier seeing the results, check it out:

# %%
melted_data = data.melt(id_vars="timestamp", var_name="sensor", value_name="temperature")
melted_data

# %% [markdown]
# And now that we have the data in this shape, is easy to get a boxplot:

# %%
fig = sns.boxplot(y="temperature", x="sensor", data=melted_data)
labels = plt.xticks(rotation=90)

# %% [markdown]
# We can also plot an histogram, but with this number of sensors a boxplot is cleaner:

# %%
fig = sns.histplot(data=melted_data, x="temperature", hue="sensor", bins=20, kde=True, palette="Dark2")

# This is just for hiding the legend for now, there are a lot of labels and is difficult to see the plot
plt.legend([],[], frameon=False)

# %% [markdown]
# Finally, let's create a dataset with the stats.

# %%
stats_data = data.describe()
stats_data

# %% [markdown]
# We are transposing it and reseting the index to keep a column with the point id (was the name of the column):

# %%
stats_data = stats_data.T.reset_index().rename(columns={"index":"id_point"})
stats_data

# %% [markdown]
# And now let's convert the `id_point` column in our metadata set to string (is an int right now) so we are able to merge with `stats_data`:

# %%
metadata['id_point'] = metadata['id_point'].astype(str)

# %% [markdown]
# And merge!

# %%
stats_merged = pd.merge(stats_data, metadata, how="left", on="id_point")
stats_merged.head()

# %%
metadata.T

# %% [markdown]
# Finally, plot! we want to visualize the mean temperature of the points, colored by the building name.

# %%
fig = sns.barplot(data=stats_merged, x="id_point", y="mean", hue="name_bdg", dodge=False)
labels = plt.xticks(rotation=90)
